# %% [markdown]
# # TMDb Movie Data Analysis and Building a Movie Recommendation System
# * # Part 1: Data Cleaning/Transformation
# ### In this project, we will analyze movie data from the TMDB database, and try to extract some meaningful insight from it with Exploratory Data Analysis, visualization, and DataFrame manipulations. The first part of this project will focus on cleaning and manipulating the DataFrame, extracting any valuable information and removing any data that is not needed.
# ### The end result will be a movie recommendation system based on movie vector similarity.

# %% [markdown]
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %% [markdown]
# ## Loading the main libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ast import literal_eval
import urllib
import requests
import json
import gzip
import time
from tqdm import tqdm

pd.options.display.max_columns = 20

# %% [markdown]
# ## Getting all valid movie IDs from TMDB's Daily File Exports

# %%
def get_movie_ids():
    json_gz_path = 'http://files.tmdb.org/p/exports/movie_ids_10_28_2021.json.gz' # Path of compressed json file of movie ids.
    urllib.request.urlretrieve(json_gz_path,'movie_ids_10_28_2021.json.gz') # This will download the compressed json file which contains all movie ids.
    movie_ids = []
    with gzip.open('movie_ids_10_28_2021.json.gz', 'r') as f:
        for line in f:
            movie_ids.append(json.loads(line)['id'])
    return movie_ids

# %%
movie_ids = get_movie_ids()

# %%
print(f"First 10 movie ids: {movie_ids[:10]}")
print(f"# of movie ids: {format(len(movie_ids), ',d')}")
# Out:
# First 10 movie ids: [3924, 6124, 8773, 25449, 31975, 2, 3, 5, 6, 8]
# # of movie ids: 650,449

# %% [markdown]
# ## Downloading the movie dataset using TMDB's API

# %%
session = requests.Session()
session.headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.54 Safari/537.36",
    "Accept-Encoding": "*",
    "Connection": "keep-alive"
}

# %%
def retry(func, retries=10):
    def retry_wrapper(*args, **kwargs):
        attempts = 0
        while attempts < retries:
            try:
                return func(*args, **kwargs)
            except requests.exceptions.RequestException as e:
                print(e)
                time.sleep(5)
                attempts += 1
                
    return retry_wrapper

# %%
from api_key import api # Personal API key used to download the data.

failed_ids = []

@retry
def download_movie_data(movie_id, session=session):
    link = f'https://api.themoviedb.org/3/movie/{movie_id}?api_key={api}&language=en-US'
    response = session.get(link)
    if response.status_code == 200:
        return response.json()
    else:
        failed_ids.append(movie_id)
        return np.nan

# %%
movies = []
pbar = tqdm(total=len(movie_ids))
for movie_id in movie_ids:
    movies.append(download_movie_data(movie_id))
    pbar.update(1)
pbar.close()

# %%
len(movies)
# Out:
# 650643

# %%
len(failed_ids)
# Out:
# 194

# %% [markdown]
# ## Retrying failed movie requests

# %%
failed_movies = []
for failed_movie_id in failed_ids:
    failed_movies.append(download_movie_data(movie_id))

# %%
movies.extend(failed_movies)

# %%
len(movies)
# Out:
# 650643

# %% [markdown]
# ## Saving the resultant movies dataset

# %%
movies_series = pd.Series(movies).dropna()

# %%
df = pd.DataFrame.from_records(movies_series)

# %%
df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /dvQj1GBZAZirz1skEEZyWH2ZqQP.jpg
# 1  False                               NaN
# 2  False  /uJlc4aNPF3Y8yAqahJTKBwgwPVW.jpg
# 3  False                               NaN
# 4  False                               NaN
#
#                                belongs_to_collection  budget  \
# 0  {'id': 177062, 'name': 'Blondie Collection', '...       0
# 1                                                NaN       0
# 2                                                NaN       0
# 3  {'id': 425256, 'name': 'New World Disorder', '...       0
# 4                                                NaN       0
#
#                                               genres                 homepage  \
# 0                     [{'id': 35, 'name': 'Comedy'}]                      NaN
# 1                  [{'id': 12, 'name': 'Adventure'}]                      NaN
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...                      NaN
# 3                                                 []  http://www.nwdfilms.com
# 4                  [{'id': 10751, 'name': 'Family'}]                      NaN
#
#       id    imdb_id original_language                      original_title  \
# 0   3924  tt0029927                en                             Blondie
# 1   6124  tt0011436                de                 Der Mann ohne Namen
# 2   8773  tt0055747                fr                 L'amour à vingt ans
# 3  25449        NaN                en  New World Disorder 9: Never Enough
# 4  31975  tt1656746                en      Sesame Street: Elmo Loves You!
#
#    ... release_date  revenue runtime  \
# 0  ...   1938-11-30        0    70.0
# 1  ...   1921-01-01        0   420.0
# 2  ...   1962-06-22        0   110.0
# 3  ...   2008-12-08        0    69.0
# 4  ...   2010-01-05        0    46.0
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1                                                 []  Released
# 2  [{'english_name': 'German', 'iso_639_1': 'de',...  Released
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4                                                 []  Released
#
#                                 tagline                               title  \
# 0                                   NaN                             Blondie
# 1                                   NaN       Peter Voss, Thief of Millions
# 2  The Intimate Secrets of Young Lovers                      Love at Twenty
# 3                                   NaN  New World Disorder 9: Never Enough
# 4                                   NaN      Sesame Street: Elmo Loves You!
#
#    video vote_average vote_count
# 0  False          7.1          5
# 1  False          0.0          0
# 2  False          6.8         36
# 3  False          4.5          2
# 4   True          0.0          0
#
# [5 rows x 25 columns]

# %%
df.to_csv('movies_metadata.csv', index=False)

# %% [markdown]
# # Downloading credits datasets for each movie

# %%
failed_ids = []

@retry
def download_credits_data(movie_id, session=session):
    link = f'https://api.themoviedb.org/3/movie/{movie_id}/credits?api_key={api}&language=en-US'
    response = session.get(link)
    if response.status_code == 200:
        return response.json()
    else:
        failed_ids.append(movie_id)
        return np.nan

# %%
credits = []
pbar = tqdm(total=len(movie_ids))
for movie_id in movie_ids:
    credits.append(download_credits_data(movie_id))
    pbar.update(1)
pbar.close()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 650449/650449 [12:30:37<00:00, 14.44it/s]

# %%
credits_series = pd.Series(credits).dropna()

# %%
credits_df = pd.DataFrame(credits_series)
credits_df.to_csv('credits.csv', index=False)
del credits_df
# Out:
#                                                     0
# 0   {'id': 3924, 'cast': [{'adult': False, 'gender...
# 1   {'id': 6124, 'cast': [{'adult': False, 'gender...
# 2   {'id': 8773, 'cast': [{'adult': False, 'gender...
# 3   {'id': 25449, 'cast': [{'adult': False, 'gende...
# 4               {'id': 31975, 'cast': [], 'crew': []}
# 5   {'id': 2, 'cast': [{'adult': False, 'gender': ...
# 6   {'id': 3, 'cast': [{'adult': False, 'gender': ...
# 7   {'id': 5, 'cast': [{'adult': False, 'gender': ...
# 8   {'id': 6, 'cast': [{'adult': False, 'gender': ...
# 9   {'id': 8, 'cast': [], 'crew': [{'adult': False...
# 10  {'id': 9, 'cast': [{'adult': False, 'gender': ...
# 11  {'id': 11, 'cast': [{'adult': False, 'gender':...
# 12  {'id': 12, 'cast': [{'adult': False, 'gender':...
# 13  {'id': 13, 'cast': [{'adult': False, 'gender':...
# 14  {'id': 14, 'cast': [{'adult': False, 'gender':...
# 15  {'id': 15, 'cast': [{'adult': False, 'gender':...
# 16  {'id': 16, 'cast': [{'adult': False, 'gender':...
# 17  {'id': 17, 'cast': [{'adult': False, 'gender':...
# 18  {'id': 18, 'cast': [{'adult': False, 'gender':...
# 19  {'id': 19, 'cast': [{'adult': False, 'gender':...
# 20  {'id': 20, 'cast': [{'adult': False, 'gender':...
# 21  {'id': 21, 'cast': [{'adult': False, 'gender':...
# 22  {'id': 22, 'cast': [{'adult': False, 'gender':...
# 23  {'id': 24, 'cast': [{'adult': False, 'gender':...
# 24  {'id': 25, 'cast': [{'adult': False, 'gender':...
# 25  {'id': 26, 'cast': [{'adult': False, 'gender':...
# 26  {'id': 27, 'cast': [{'adult': False, 'gender':...
# 27  {'id': 28, 'cast': [{'adult': False, 'gender':...
# 28  {'id': 33, 'cast': [{'adult': False, 'gender':...
# 29  {'id': 35, 'cast': [{'adult': False, 'gender':...
# 30  {'id': 38, 'cast': [{'adult': False, 'gender':...
# 31  {'id': 55, 'cast': [{'adult': False, 'gender':...
# 32  {'id': 58, 'cast': [{'adult': False, 'gender':...
# 33  {'id': 59, 'cast': [{'adult': False, 'gender':...
# 34  {'id': 62, 'cast': [{'adult': False, 'gender':...
# 35  {'id': 63, 'cast': [{'adult': False, 'gender':...
# 36  {'id': 64, 'cast': [{'adult': False, 'gender':...
# 37  {'id': 65, 'cast': [{'adult': False, 'gender':...
# 38  {'id': 66, 'cast': [{'adult': False, 'gender':...
# 39  {'id': 67, 'cast': [{'adult': False, 'gender':...
# 40  {'id': 68, 'cast': [{'adult': False, 'gender':...
# 41  {'id': 69, 'cast': [{'adult': False, 'gender':...
# 42  {'id': 70, 'cast': [{'adult': False, 'gender':...
# 43  {'id': 71, 'cast': [{'adult': False, 'gender':...
# 44  {'id': 73, 'cast': [{'adult': False, 'gender':...
# 45  {'id': 74, 'cast': [{'adult': False, 'gender':...
# 46  {'id': 75, 'cast': [{'adult': False, 'gender':...
# 47  {'id': 76, 'cast': [{'adult': False, 'gender':...
# 48  {'id': 77, 'cast': [{'adult': False, 'gender':...
# 49  {'id': 78, 'cast': [{'adult': False, 'gender':...

# %% [markdown]
# ### • All of our data are downloaded and ready to view.

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Some of the data attributes are in json format, so we will have to extract the columns/variables from json dictionary strings.

# %%
df = pd.read_csv('movies_metadata.csv', low_memory=False)
df
# Out:
#         adult                     backdrop_path  \
# 0       False  /dvQj1GBZAZirz1skEEZyWH2ZqQP.jpg
# 1       False                               NaN
# 2       False  /uJlc4aNPF3Y8yAqahJTKBwgwPVW.jpg
# 3       False                               NaN
# 4       False                               NaN
# ...       ...                               ...
# 650444  False                               NaN
# 650445  False                               NaN
# 650446  False                               NaN
# 650447  False                               NaN
# 650448  False                               NaN
#
#                                     belongs_to_collection  budget  \
# 0       {'id': 177062, 'name': 'Blondie Collection', '...       0
# 1                                                     NaN       0
# 2                                                     NaN       0
# 3       {'id': 425256, 'name': 'New World Disorder', '...       0
# 4                                                     NaN       0
# ...                                                   ...     ...
# 650444                                                NaN       0
# 650445                                                NaN       0
# 650446                                                NaN       0
# 650447                                                NaN       0
# 650448                                                NaN       0
#
#                                                    genres  \
# 0                          [{'id': 35, 'name': 'Comedy'}]
# 1                       [{'id': 12, 'name': 'Adventure'}]
# 2       [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 3                                                      []
# 4                       [{'id': 10751, 'name': 'Family'}]
# ...                                                   ...
# 650444                [{'id': 99, 'name': 'Documentary'}]
# 650445                [{'id': 99, 'name': 'Documentary'}]
# 650446                [{'id': 99, 'name': 'Documentary'}]
# 650447                [{'id': 99, 'name': 'Documentary'}]
# 650448                [{'id': 99, 'name': 'Documentary'}]
#
#                        homepage      id    imdb_id original_language  \
# 0                           NaN    3924  tt0029927                en
# 1                           NaN    6124  tt0011436                de
# 2                           NaN    8773  tt0055747                fr
# 3       http://www.nwdfilms.com   25449        NaN                en
# 4                           NaN   31975  tt1656746                en
# ...                         ...     ...        ...               ...
# 650444                      NaN  890932        NaN                es
# 650445                      NaN  890932        NaN                es
# 650446                      NaN  890932        NaN                es
# 650447                      NaN  890932        NaN                es
# 650448                      NaN  890932        NaN                es
#
#                                         original_title  ... release_date  \
# 0                                              Blondie  ...   1938-11-30
# 1                                  Der Mann ohne Namen  ...   1921-01-01
# 2                                  L'amour à vingt ans  ...   1962-06-22
# 3                   New World Disorder 9: Never Enough  ...   2008-12-08
# 4                       Sesame Street: Elmo Loves You!  ...   2010-01-05
# ...                                                ...  ...          ...
# 650444  Palabra de fotógrafo - Testimonios sobre el 68  ...   2011-01-01
# 650445  Palabra de fotógrafo - Testimonios sobre el 68  ...   2011-01-01
# 650446  Palabra de fotógrafo - Testimonios sobre el 68  ...   2011-01-01
# 650447  Palabra de fotógrafo - Testimonios sobre el 68  ...   2011-01-01
# 650448  Palabra de fotógrafo - Testimonios sobre el 68  ...   2011-01-01
#
#         revenue runtime                                   spoken_languages  \
# 0             0    70.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1             0   420.0                                                 []
# 2             0   110.0  [{'english_name': 'German', 'iso_639_1': 'de',...
# 3             0    69.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4             0    46.0                                                 []
# ...         ...     ...                                                ...
# 650444        0    57.0  [{'english_name': 'Spanish', 'iso_639_1': 'es'...
# 650445        0    57.0  [{'english_name': 'Spanish', 'iso_639_1': 'es'...
# 650446        0    57.0  [{'english_name': 'Spanish', 'iso_639_1': 'es'...
# 650447        0    57.0  [{'english_name': 'Spanish', 'iso_639_1': 'es'...
# 650448        0    57.0  [{'english_name': 'Spanish', 'iso_639_1': 'es'...
#
#           status                               tagline  \
# 0       Released                                   NaN
# 1       Released                                   NaN
# 2       Released  The Intimate Secrets of Young Lovers
# 3       Released                                   NaN
# 4       Released                                   NaN
# ...          ...                                   ...
# 650444  Released                                   NaN
# 650445  Released                                   NaN
# 650446  Released                                   NaN
# 650447  Released                                   NaN
# 650448  Released                                   NaN
#
#                                          title  video vote_average vote_count
# 0                                      Blondie  False          7.1          5
# 1                Peter Voss, Thief of Millions  False          0.0          0
# 2                               Love at Twenty  False          6.8         36
# 3           New World Disorder 9: Never Enough  False          4.5          2
# 4               Sesame Street: Elmo Loves You!   True          0.0          0
# ...                                        ...    ...          ...        ...
# 650444  Photographer's Words - 68 Testimonials  False          0.0          0
# 650445  Photographer's Words - 68 Testimonials  False          0.0          0
# 650446  Photographer's Words - 68 Testimonials  False          0.0          0
# 650447  Photographer's Words - 68 Testimonials  False          0.0          0
# 650448  Photographer's Words - 68 Testimonials  False          0.0          0
#
# [650449 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650449 entries, 0 to 650448
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   adult                  650449 non-null  bool
#  1   backdrop_path          166759 non-null  object
#  2   belongs_to_collection  16176 non-null   object
#  3   budget                 650449 non-null  int64
#  4   genres                 650449 non-null  object
#  5   homepage               75382 non-null   object
#  6   id                     650449 non-null  int64
#  7   imdb_id                432724 non-null  object
#  8   original_language      650449 non-null  object
#  9   original_title         650446 non-null  object
#  10  overview               538518 non-null  object
#  11  popularity             650449 non-null  float64
#  12  poster_path            438992 non-null  object
#  13  production_companies   650449 non-null  object
#  14  production_countries   650449 non-null  object
#  15  release_date           590521 non-null  object
#  16  revenue                650449 non-null  int64
#  17  runtime                597471 non-null  float64
#  18  spoken_languages       650449 non-null  object
#  19  status                 650449 non-null  object
#  20  tagline                91811 non-null   object
#  21  title                  650446 non-null  object
#  22  video                  650449 non-null  bool
#  23  vote_average           650449 non-null  float64
#  24  vote_count             650449 non-null  int64
# dtypes: bool(2), float64(3), int64(4), object(16)
# memory usage: 115.4+ MB

# %% [markdown]
# ## Dropping irrelevant columns that will not be needed.

# %%
df.drop(columns=['adult', 'imdb_id', 'original_title', 'video', 'homepage', 'backdrop_path', 'original_title'], inplace=True)
df.head()
# Out:
#                                belongs_to_collection  budget  \
# 0  {'id': 177062, 'name': 'Blondie Collection', '...       0
# 1                                                NaN       0
# 2                                                NaN       0
# 3  {'id': 425256, 'name': 'New World Disorder', '...       0
# 4                                                NaN       0
#
#                                               genres     id original_language  \
# 0                     [{'id': 35, 'name': 'Comedy'}]   3924                en
# 1                  [{'id': 12, 'name': 'Adventure'}]   6124                de
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...   8773                fr
# 3                                                 []  25449                en
# 4                  [{'id': 10751, 'name': 'Family'}]  31975                en
#
#                                             overview  popularity  \
# 0  Blondie and Dagwood are about to celebrate the...       2.445
# 1  Der Mann ohne Namen is a German adventure movi...       0.600
# 2  Love at Twenty unites five directors from five...       4.985
# 3  Gee Atherton ripping the Worlds course the day...       1.337
# 4  Elmo is making a very, very super special surp...       0.600
#
#                         poster_path  \
# 0  /o6UMTE2LzQdlKVxRnFECPmtQjsJ.jpg
# 1  /6xUbUCvndklbGVYiljHr34NTxSl.jpg
# 2  /aup2QCYCsyEeQfpboXy0f4uj8aE.jpg
# 3  /okQY6jVmRU19CUbYPUZC77K3XBE.jpg
# 4  /qKWcCmvGr4g0dgXvhqAc4BAMCtk.jpg
#
#                                 production_companies  \
# 0  [{'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLu...
# 1                                                 []
# 2  [{'id': 38936, 'logo_path': '/ypvTqUeQOxORhFEF...
# 3                                                 []
# 4                                                 []
#
#                                 production_countries release_date  revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1938-11-30        0
# 1          [{'iso_3166_1': 'DE', 'name': 'Germany'}]   1921-01-01        0
# 2  [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...   1962-06-22        0
# 3                                                 []   2008-12-08        0
# 4                                                 []   2010-01-05        0
#
#    runtime                                   spoken_languages    status  \
# 0     70.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1    420.0                                                 []  Released
# 2    110.0  [{'english_name': 'German', 'iso_639_1': 'de',...  Released
# 3     69.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4     46.0                                                 []  Released
#
#                                 tagline                               title  \
# 0                                   NaN                             Blondie
# 1                                   NaN       Peter Voss, Thief of Millions
# 2  The Intimate Secrets of Young Lovers                      Love at Twenty
# 3                                   NaN  New World Disorder 9: Never Enough
# 4                                   NaN      Sesame Street: Elmo Loves You!
#
#    vote_average  vote_count
# 0           7.1           5
# 1           0.0           0
# 2           6.8          36
# 3           4.5           2
# 4           0.0           0

# %% [markdown]
# ## How to Handle Stringified JSON Columns
# ### Columns that contain dictionaries or lists are treated as strings in pandas.
# ### In order to access their entries, they will be converted to their appropriate form using the **ast** module.

# %%
import json
import ast

# %%
json_col = ['belongs_to_collection', 'genres', 'production_countries', 'production_companies', 'spoken_languages']

# %%
df[json_col].head()
# Out:
#                                belongs_to_collection  \
# 0  {'id': 177062, 'name': 'Blondie Collection', '...
# 1                                                NaN
# 2                                                NaN
# 3  {'id': 425256, 'name': 'New World Disorder', '...
# 4                                                NaN
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1                  [{'id': 12, 'name': 'Adventure'}]
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 3                                                 []
# 4                  [{'id': 10751, 'name': 'Family'}]
#
#                                 production_countries  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...
# 1          [{'iso_3166_1': 'DE', 'name': 'Germany'}]
# 2  [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...
# 3                                                 []
# 4                                                 []
#
#                                 production_companies  \
# 0  [{'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLu...
# 1                                                 []
# 2  [{'id': 38936, 'logo_path': '/ypvTqUeQOxORhFEF...
# 3                                                 []
# 4                                                 []
#
#                                     spoken_languages
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1                                                 []
# 2  [{'english_name': 'German', 'iso_639_1': 'de',...
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4                                                 []

# %%
def lit_eval(column):
    return column.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)

# %%
for column in json_col:
    print(f"\n{'='*40}\nColumn Name: {column}\nOriginal dtype: {type(df[column][0])}")
    df[column] = lit_eval(df[column])
    print(f"New dtype: {type(df[column][0])}")
# Out:
# ========================================
# Column Name: belongs_to_collection
# Original dtype: <class 'str'>
# New dtype: <class 'dict'>
#
# ========================================
# Column Name: genres
# Original dtype: <class 'str'>
# New dtype: <class 'list'>
#
# ========================================
# Column Name: production_countries
# Original dtype: <class 'str'>
# New dtype: <class 'list'>
#
# ========================================
# Column Name: production_companies
# Original dtype: <class 'str'>
# New dtype: <class 'list'>
#
# ========================================
# Column Name: spoken_languages
# Original dtype: <class 'str'>
# New dtype: <class 'list'>

# %% [markdown]
# ### The end result is that all of the JSON columns that were not accessible due to being treated as strings are now in the form of either a list or a dictionary, and are ready to be accessed/have their values extracted.

# %%
df.head()
# Out:
#                                belongs_to_collection  budget  \
# 0  {'id': 177062, 'name': 'Blondie Collection', '...       0
# 1                                                NaN       0
# 2                                                NaN       0
# 3  {'id': 425256, 'name': 'New World Disorder', '...       0
# 4                                                NaN       0
#
#                                               genres     id original_language  \
# 0                     [{'id': 35, 'name': 'Comedy'}]   3924                en
# 1                  [{'id': 12, 'name': 'Adventure'}]   6124                de
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...   8773                fr
# 3                                                 []  25449                en
# 4                  [{'id': 10751, 'name': 'Family'}]  31975                en
#
#                                             overview  popularity  \
# 0  Blondie and Dagwood are about to celebrate the...       2.445
# 1  Der Mann ohne Namen is a German adventure movi...       0.600
# 2  Love at Twenty unites five directors from five...       4.985
# 3  Gee Atherton ripping the Worlds course the day...       1.337
# 4  Elmo is making a very, very super special surp...       0.600
#
#                         poster_path  \
# 0  /o6UMTE2LzQdlKVxRnFECPmtQjsJ.jpg
# 1  /6xUbUCvndklbGVYiljHr34NTxSl.jpg
# 2  /aup2QCYCsyEeQfpboXy0f4uj8aE.jpg
# 3  /okQY6jVmRU19CUbYPUZC77K3XBE.jpg
# 4  /qKWcCmvGr4g0dgXvhqAc4BAMCtk.jpg
#
#                                 production_companies  \
# 0  [{'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLu...
# 1                                                 []
# 2  [{'id': 38936, 'logo_path': '/ypvTqUeQOxORhFEF...
# 3                                                 []
# 4                                                 []
#
#                                 production_countries release_date  revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1938-11-30        0
# 1          [{'iso_3166_1': 'DE', 'name': 'Germany'}]   1921-01-01        0
# 2  [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...   1962-06-22        0
# 3                                                 []   2008-12-08        0
# 4                                                 []   2010-01-05        0
#
#    runtime                                   spoken_languages    status  \
# 0     70.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1    420.0                                                 []  Released
# 2    110.0  [{'english_name': 'German', 'iso_639_1': 'de',...  Released
# 3     69.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4     46.0                                                 []  Released
#
#                                 tagline                               title  \
# 0                                   NaN                             Blondie
# 1                                   NaN       Peter Voss, Thief of Millions
# 2  The Intimate Secrets of Young Lovers                      Love at Twenty
# 3                                   NaN  New World Disorder 9: Never Enough
# 4                                   NaN      Sesame Street: Elmo Loves You!
#
#    vote_average  vote_count
# 0           7.1           5
# 1           0.0           0
# 2           6.8          36
# 3           4.5           2
# 4           0.0           0

# %% [markdown]
# ## Extracting the useful information from each JSON column.

# %% [markdown]
# ### Each one of the JSON columns has a "name" variable that is an attribute of each column. (ex. "Romance" under "genres", "en" under "spoken_languages", etc.)
# ### This for loop checks the data type of each column. If it's in dictionary format, there is going to be only one "name" key for that row/column.
# ### If it's in a dictionary format, then there might be multiple "name" keys for each dictionary in that list, which will be combined using a pipe ("|") symbol where applicable.

# %%
for column in json_col:
    if type(df[column][0]) == list:
            df[column] = df[column].apply(lambda x: '|'.join(i['name'] for i in x)  if isinstance(x, list) else np.nan)
    else:
           df[column] = df[column].apply(lambda x: x['name'] if isinstance(x, dict) else np.nan)

# %% [markdown]
# ### Here is the end result for a specific row and each column that was converted. (Compare to same code above)

# %%
for column in json_col:
    print(f'Column "{column}": {df[column][2]}\n{"="*100}')
# Out:
# Column "belongs_to_collection": nan
# ====================================================================================================
# Column "genres": Drama|Romance
# ====================================================================================================
# Column "production_countries": Germany|France|Italy|Japan|Poland
# ====================================================================================================
# Column "production_companies": Ulysse Productions|Unitec Films|Cinesecolo|Toho Co.|Beta Film|Film Polski|Zespół Filmowy "Kamera"
# ====================================================================================================
# Column "spoken_languages": Deutsch|Français|Italiano|日本語|Polski
# ====================================================================================================

# %% [markdown]
# ## Replacing blank entries with NaN

# %% [markdown]
# ### Some of the rows have empty strings for each column attribute.

# %%
for column in json_col:
    print(f"*** {column} ***")
    print(f"{df[column].value_counts(dropna=False).head()}\n{'='*50}")
# Out:
# *** belongs_to_collection ***
# NaN                                  634273
# Our Gang: The Roach/MGM talkies          80
# Hopalong Cassidy Collection              66
# Our Gang: The Roach/Pathé silents        66
# The Durango Kid Collection               65
# Name: belongs_to_collection, dtype: int64
# ==================================================
# *** genres ***
#                215618
# Documentary     79318
# Drama           67732
# Comedy          41816
# Music           16955
# Name: genres, dtype: int64
# ==================================================
# *** production_countries ***
#                             266260
# United States of America     95773
# Germany                      23767
# United Kingdom               21261
# France                       20550
# Name: production_countries, dtype: int64
# ==================================================
# *** production_companies ***
#                          371837
# Metro-Goldwyn-Mayer        1970
# Columbia Pictures          1758
# Warner Bros. Pictures      1670
# BBC                        1539
# Name: production_companies, dtype: int64
# ==================================================
# *** spoken_languages ***
#             272572
# English     129138
# Español      23604
# Français     21461
# 日本語          20586
# Name: spoken_languages, dtype: int64
# ==================================================

# %% [markdown]
# ### Using a simple for loop, each empty string will be replaced with NaN. The final result is below.

# %%
for column in json_col:
    df[column].replace('', np.nan, inplace=True)

# %%
for column in json_col:
    print(f"*** {column} ***")
    print(f"{df[column].value_counts(dropna=False).head()}\n{'='*50}")
# Out:
# *** belongs_to_collection ***
# NaN                                  634273
# Our Gang: The Roach/MGM talkies          80
# Hopalong Cassidy Collection              66
# Our Gang: The Roach/Pathé silents        66
# The Durango Kid Collection               65
# Name: belongs_to_collection, dtype: int64
# ==================================================
# *** genres ***
# NaN            215618
# Documentary     79318
# Drama           67732
# Comedy          41816
# Music           16955
# Name: genres, dtype: int64
# ==================================================
# *** production_countries ***
# NaN                         266260
# United States of America     95773
# Germany                      23767
# United Kingdom               21261
# France                       20550
# Name: production_countries, dtype: int64
# ==================================================
# *** production_companies ***
# NaN                      371837
# Metro-Goldwyn-Mayer        1970
# Columbia Pictures          1758
# Warner Bros. Pictures      1670
# BBC                        1539
# Name: production_companies, dtype: int64
# ==================================================
# *** spoken_languages ***
# NaN         272572
# English     129138
# Español      23604
# Français     21461
# 日本語          20586
# Name: spoken_languages, dtype: int64
# ==================================================

# %% [markdown]
# ## Replacing all zero values for "budget" and "revenue" with NaN
# ## Changing the scale of the data to millions USD

# %%
for column in ['budget', 'revenue']:
    df[column] = df[column].replace(0, np.nan)
    df[column] = df[column].div(1000000)
    df.rename(columns={column: column + '_musd'}, inplace=True)

# %% [markdown]
# ## Replacing all zero values for runtime with NaN

# %%
print(f"Original:\n{df.runtime.value_counts(dropna=False).head()}\n{'='*50}")
df.runtime.replace(0, np.nan, inplace=True)
print(f"New:\n{df.runtime.value_counts(dropna=False).head()}\n{'='*50}")
# Out:
# Original:
# 0.0     111613
# NaN      52978
# 90.0     21644
# 10.0      9944
# 7.0       9143
# Name: runtime, dtype: int64
# ==================================================
# New:
# NaN     164591
# 90.0     21644
# 10.0      9944
# 7.0       9143
# 6.0       8845
# Name: runtime, dtype: int64
# ==================================================

# %% [markdown]
# ## Replacing entries where vote_average equals zero with NaN

# %%
df.loc[df.vote_count == 0, 'vote_average'] = np.nan

# %% [markdown]
# ## Converting "release_date" column to datetime format

# %%
df['release_date'] = pd.to_datetime(df['release_date'])
df['release_date'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ## Creating a "year" column containing the release year

# %%
df['year'] = df['release_date'].apply(lambda x: str(x).split('-')[0] if len(str(x)) > 1 else np.nan)

# %%
df.year.value_counts()
# Out:
# NaT     59928
# 2019    28403
# 2020    27592
# 2018    25765
# 2017    24644
#         ...
# 1879        1
# 2030        1
# 1882        1
# 2050        1
# 2032        1
# Name: year, Length: 156, dtype: int64

# %% [markdown]
# ## Replacing entries in "overview" column where the entry explicates missing overview

# %%
df.overview.value_counts(dropna=False).head(30)
# Out:
# NaN                                                                                                                                                         111931
# No overview found.                                                                                                                                            1063
# Mexican feature film                                                                                                                                           952
# No overview found                                                                                                                                              309
# No synopsis                                                                                                                                                    303
# No Overview                                                                                                                                                    287
# Plot unknown.                                                                                                                                                  210
# Testimonies of seven prominent photographers active in the juncture of the student movement of 1968                                                            195
# Know what this is about?                                                                                                                                       171
# Documentary film.                                                                                                                                              169
# No Synopsis                                                                                                                                                    143
# What the movie has in store for you, wait and watch this space for more updates.                                                                               139
# Coming Soon                                                                                                                                                    131
# Overview Coming Soon...                                                                                                                                        124
# Feature film.                                                                                                                                                   97
# No description                                                                                                                                                  93
# Short film.                                                                                                                                                     89
# Mexican movie                                                                                                                                                   87
# Lift your butt, sculpt your core, and get an incredible total body transformation with 80 unique “real-time” workouts and a Timed-Nutrition Eating Plan.        82
#                                                                                                                                                                 77
# Transform :20 is a high-intensity, six-week workout and nutrition program that will help transform your body and mind in just 20 minutes a day.                 67
# No overview.                                                                                                                                                    62
# »                                                                                                                                                               59
# Add the plot.                                                                                                                                                   55
# coming soon..                                                                                                                                                   54
# Japanese comedy film.                                                                                                                                           53
# An Eternalism film.                                                                                                                                             52
# shaw production                                                                                                                                                 49
# A short animation by Shintaro Kago.                                                                                                                             49
# Combat Bulletin was a new reel type series keeping folks up-to-date with the combat of World War II.                                                            49
# Name: overview, dtype: int64

# %%
recurring_text = ['No overview found.', 'No overview found', 'No synopsis', 'No Overview', 'Plot unknown.', 'No Synopsis', 'Coming Soon',
                  'Overview Coming Soon...', 'Feature film.', 'No description', 'Short film.', 'No overview.', '»', 'Add the plot.', 'coming soon..', 
                  'No description.', 'not available']

df.replace(dict.fromkeys(recurring_text, np.nan), inplace=True)

# %% [markdown]
# ## Replacing all blank values in the dataset with NaN

# %%
df.replace(dict.fromkeys([' ', '  ', '   '], np.nan), inplace=True)

# %% [markdown]
# ## Removing duplicate entries from the dataset

# %%
print(f"Duplicate Rows:\n{df.duplicated(keep=False).value_counts()}")
# Out:
# Duplicate Rows:
# False    650254
# True        195
# dtype: int64

# %%
df[df.duplicated(keep=False)].sort_values(by='id')
# Out:
#        belongs_to_collection  budget_musd       genres      id  \
# 650254                   NaN          NaN  Documentary  890932
# 650378                   NaN          NaN  Documentary  890932
# 650379                   NaN          NaN  Documentary  890932
# 650380                   NaN          NaN  Documentary  890932
# 650381                   NaN          NaN  Documentary  890932
# ...                      ...          ...          ...     ...
# 650322                   NaN          NaN  Documentary  890932
# 650323                   NaN          NaN  Documentary  890932
# 650324                   NaN          NaN  Documentary  890932
# 650302                   NaN          NaN  Documentary  890932
# 650448                   NaN          NaN  Documentary  890932
#
#        original_language                                           overview  \
# 650254                es  Testimonies of seven prominent photographers a...
# 650378                es  Testimonies of seven prominent photographers a...
# 650379                es  Testimonies of seven prominent photographers a...
# 650380                es  Testimonies of seven prominent photographers a...
# 650381                es  Testimonies of seven prominent photographers a...
# ...                  ...                                                ...
# 650322                es  Testimonies of seven prominent photographers a...
# 650323                es  Testimonies of seven prominent photographers a...
# 650324                es  Testimonies of seven prominent photographers a...
# 650302                es  Testimonies of seven prominent photographers a...
# 650448                es  Testimonies of seven prominent photographers a...
#
#         popularity                       poster_path  \
# 650254         0.6  /wx3knW6HjO8Xv5UZC55XqRbSIpc.jpg
# 650378         0.6  /wx3knW6HjO8Xv5UZC55XqRbSIpc.jpg
# 650379         0.6  /wx3knW6HjO8Xv5UZC55XqRbSIpc.jpg
# 650380         0.6  /wx3knW6HjO8Xv5UZC55XqRbSIpc.jpg
# 650381         0.6  /wx3knW6HjO8Xv5UZC55XqRbSIpc.jpg
# ...            ...                               ...
# 650322         0.6  /wx3knW6HjO8Xv5UZC55XqRbSIpc.jpg
# 650323         0.6  /wx3knW6HjO8Xv5UZC55XqRbSIpc.jpg
# 650324         0.6  /wx3knW6HjO8Xv5UZC55XqRbSIpc.jpg
# 650302         0.6  /wx3knW6HjO8Xv5UZC55XqRbSIpc.jpg
# 650448         0.6  /wx3knW6HjO8Xv5UZC55XqRbSIpc.jpg
#
#                                      production_companies  \
# 650254  Centro Cultural Universitario Tlatelolco|Insti...
# 650378  Centro Cultural Universitario Tlatelolco|Insti...
# 650379  Centro Cultural Universitario Tlatelolco|Insti...
# 650380  Centro Cultural Universitario Tlatelolco|Insti...
# 650381  Centro Cultural Universitario Tlatelolco|Insti...
# ...                                                   ...
# 650322  Centro Cultural Universitario Tlatelolco|Insti...
# 650323  Centro Cultural Universitario Tlatelolco|Insti...
# 650324  Centro Cultural Universitario Tlatelolco|Insti...
# 650302  Centro Cultural Universitario Tlatelolco|Insti...
# 650448  Centro Cultural Universitario Tlatelolco|Insti...
#
#        production_countries release_date  revenue_musd  runtime  \
# 650254               Mexico   2011-01-01           NaN     57.0
# 650378               Mexico   2011-01-01           NaN     57.0
# 650379               Mexico   2011-01-01           NaN     57.0
# 650380               Mexico   2011-01-01           NaN     57.0
# 650381               Mexico   2011-01-01           NaN     57.0
# ...                     ...          ...           ...      ...
# 650322               Mexico   2011-01-01           NaN     57.0
# 650323               Mexico   2011-01-01           NaN     57.0
# 650324               Mexico   2011-01-01           NaN     57.0
# 650302               Mexico   2011-01-01           NaN     57.0
# 650448               Mexico   2011-01-01           NaN     57.0
#
#        spoken_languages    status tagline  \
# 650254          Español  Released     NaN
# 650378          Español  Released     NaN
# 650379          Español  Released     NaN
# 650380          Español  Released     NaN
# 650381          Español  Released     NaN
# ...                 ...       ...     ...
# 650322          Español  Released     NaN
# 650323          Español  Released     NaN
# 650324          Español  Released     NaN
# 650302          Español  Released     NaN
# 650448          Español  Released     NaN
#
#                                          title  vote_average  vote_count  year
# 650254  Photographer's Words - 68 Testimonials           NaN           0  2011
# 650378  Photographer's Words - 68 Testimonials           NaN           0  2011
# 650379  Photographer's Words - 68 Testimonials           NaN           0  2011
# 650380  Photographer's Words - 68 Testimonials           NaN           0  2011
# 650381  Photographer's Words - 68 Testimonials           NaN           0  2011
# ...                                        ...           ...         ...   ...
# 650322  Photographer's Words - 68 Testimonials           NaN           0  2011
# 650323  Photographer's Words - 68 Testimonials           NaN           0  2011
# 650324  Photographer's Words - 68 Testimonials           NaN           0  2011
# 650302  Photographer's Words - 68 Testimonials           NaN           0  2011
# 650448  Photographer's Words - 68 Testimonials           NaN           0  2011
#
# [195 rows x 20 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated(subset='id', keep=False)].sort_values(by='id')
# Out:
# Empty DataFrame
# Columns: [belongs_to_collection, budget_musd, genres, id, original_language, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue_musd, runtime, spoken_languages, status, tagline, title, vote_average, vote_count, year]
# Index: []

# %% [markdown]
# ## Handling Missing Values & Removing Observations

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 650255 entries, 0 to 650254
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   belongs_to_collection  16176 non-null   object
#  1   budget_musd            31064 non-null   float64
#  2   genres                 434637 non-null  object
#  3   id                     650255 non-null  int64
#  4   original_language      650255 non-null  object
#  5   overview               535077 non-null  object
#  6   popularity             650255 non-null  float64
#  7   poster_path            438798 non-null  object
#  8   production_companies   278418 non-null  object
#  9   production_countries   383995 non-null  object
#  10  release_date           590327 non-null  datetime64[ns]
#  11  revenue_musd           14732 non-null   float64
#  12  runtime                485664 non-null  float64
#  13  spoken_languages       377683 non-null  object
#  14  status                 650255 non-null  object
#  15  tagline                91771 non-null   object
#  16  title                  650244 non-null  object
#  17  vote_average           259878 non-null  float64
#  18  vote_count             650255 non-null  int64
#  19  year                   650255 non-null  object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(12)
# memory usage: 104.2+ MB

# %%
df.isna().sum()
# Out:
# belongs_to_collection    634079
# budget_musd              619191
# genres                   215618
# id                            0
# original_language             0
# overview                 115178
# popularity                    0
# poster_path              211457
# production_companies     371837
# production_countries     266260
# release_date              59928
# revenue_musd             635523
# runtime                  164591
# spoken_languages         272572
# status                        0
# tagline                  558484
# title                        11
# vote_average             390377
# vote_count                    0
# year                          0
# dtype: int64

# %% [markdown]
# ## Removing rows with no "title" values

# %%
df.dropna(subset=['title'], inplace=True)

# %% [markdown]
# ### All the rows that have less than 10 non-null values will be dropped from the DataFrame.

# %%
df.notna().sum(axis=1).hist(figsize=(8,5), bins=10)
# Out:
# <AxesSubplot:>

# %%
df.notna().sum(axis=1).value_counts()
# Out:
# 14    84147
# 16    81079
# 15    80786
# 13    77539
# 12    74197
# 11    72882
# 10    60670
# 9     42252
# 17    36637
# 8     18631
# 18     9407
# 19     5834
# 7      4615
# 20     1568
# dtype: int64

# %%
df = df.dropna(thresh=10).reset_index()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584746 entries, 0 to 584745
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   index                  584746 non-null  int64
#  1   belongs_to_collection  16130 non-null   object
#  2   budget_musd            30891 non-null   float64
#  3   genres                 430520 non-null  object
#  4   id                     584746 non-null  int64
#  5   original_language      584746 non-null  object
#  6   overview               502425 non-null  object
#  7   popularity             584746 non-null  float64
#  8   poster_path            423837 non-null  object
#  9   production_companies   278019 non-null  object
#  10  production_countries   382146 non-null  object
#  11  release_date           557774 non-null  datetime64[ns]
#  12  revenue_musd           14696 non-null   float64
#  13  runtime                475636 non-null  float64
#  14  spoken_languages       375259 non-null  object
#  15  status                 584746 non-null  object
#  16  tagline                91436 non-null   object
#  17  title                  584746 non-null  object
#  18  vote_average           256255 non-null  float64
#  19  vote_count             584746 non-null  int64
#  20  year                   584746 non-null  object
# dtypes: datetime64[ns](1), float64(5), int64(3), object(12)
# memory usage: 93.7+ MB

# %%
df.isna().sum()
# Out:
# index                         0
# belongs_to_collection    568616
# budget_musd              553855
# genres                   154226
# id                            0
# original_language             0
# overview                  82321
# popularity                    0
# poster_path              160909
# production_companies     306727
# production_countries     202600
# release_date              26972
# revenue_musd             570050
# runtime                  109110
# spoken_languages         209487
# status                        0
# tagline                  493310
# title                         0
# vote_average             328491
# vote_count                    0
# year                          0
# dtype: int64

# %% [markdown]
# ## Final Cleaning Steps

# %% [markdown]
# ### All rows that contain movies that are not released will be dropped, since we are only interested in analyzing released movies.

# %%
df.status.value_counts()
# Out:
# Released           578044
# In Production        2494
# Planned              2159
# Post Production      1849
# Rumored               117
# Canceled               83
# Name: status, dtype: int64

# %%
df = df.loc[df.status == 'Released'].copy()

# %%
df
# Out:
#          index belongs_to_collection  budget_musd                 genres  \
# 0            0    Blondie Collection          NaN                 Comedy
# 1            1                   NaN          NaN              Adventure
# 2            2                   NaN          NaN          Drama|Romance
# 3            3    New World Disorder          NaN                    NaN
# 4            4                   NaN          NaN                 Family
# ...        ...                   ...          ...                    ...
# 584741  650250                   NaN          NaN          Drama|Romance
# 584742  650251                   NaN          NaN                 Comedy
# 584743  650252                   NaN          NaN         Comedy|Fantasy
# 584744  650253                   NaN          NaN  Family|Comedy|Romance
# 584745  650254                   NaN          NaN            Documentary
#
#             id original_language  \
# 0         3924                en
# 1         6124                de
# 2         8773                fr
# 3        25449                en
# 4        31975                en
# ...        ...               ...
# 584741  890928                zh
# 584742  890929                zh
# 584743  890930                ru
# 584744  890931                te
# 584745  890932                es
#
#                                                  overview  popularity  \
# 0       Blondie and Dagwood are about to celebrate the...       2.445
# 1       Der Mann ohne Namen is a German adventure movi...       0.600
# 2       Love at Twenty unites five directors from five...       4.985
# 3       Gee Atherton ripping the Worlds course the day...       1.337
# 4       Elmo is making a very, very super special surp...       0.600
# ...                                                   ...         ...
# 584741                                                NaN       0.600
# 584742                                                NaN       0.600
# 584743                                                NaN       0.600
# 584744                      A romantic Family entertainer       7.531
# 584745  Testimonies of seven prominent photographers a...       0.600
#
#                              poster_path  \
# 0       /o6UMTE2LzQdlKVxRnFECPmtQjsJ.jpg
# 1       /6xUbUCvndklbGVYiljHr34NTxSl.jpg
# 2       /aup2QCYCsyEeQfpboXy0f4uj8aE.jpg
# 3       /okQY6jVmRU19CUbYPUZC77K3XBE.jpg
# 4       /qKWcCmvGr4g0dgXvhqAc4BAMCtk.jpg
# ...                                  ...
# 584741  /mLwFTBEOGONwSMRdLDl2H4Hgzfw.jpg
# 584742  /tEycQp9r0x3DceuVHcxpo8u8FcT.jpg
# 584743  /zNgaE41owqpNacE4zY9alYBb1nT.jpg
# 584744  /bVtHOP1oCePnS5FX6XhJ67p0Djg.jpg
# 584745  /wx3knW6HjO8Xv5UZC55XqRbSIpc.jpg
#
#                                      production_companies  ... release_date  \
# 0                                       Columbia Pictures  ...   1938-11-30
# 1                                                     NaN  ...   1921-01-01
# 2       Ulysse Productions|Unitec Films|Cinesecolo|Toh...  ...   1962-06-22
# 3                                                     NaN  ...   2008-12-08
# 4                                                     NaN  ...   2010-01-05
# ...                                                   ...  ...          ...
# 584741                                                NaN  ...   2018-04-30
# 584742                                                NaN  ...   2018-04-19
# 584743                          Tsentralnoye televideniye  ...   1979-03-11
# 584744                  UV Concepts|Mass Media Production  ...   2021-11-04
# 584745  Centro Cultural Universitario Tlatelolco|Insti...  ...   2011-01-01
#
#        revenue_musd  runtime                      spoken_languages    status  \
# 0               NaN     70.0                               English  Released
# 1               NaN    420.0                                   NaN  Released
# 2               NaN    110.0  Deutsch|Français|Italiano|日本語|Polski  Released
# 3               NaN     69.0                               English  Released
# 4               NaN     46.0                                   NaN  Released
# ...             ...      ...                                   ...       ...
# 584741          NaN      NaN                                   普通话  Released
# 584742          NaN      NaN                                   普通话  Released
# 584743          NaN      NaN                               Pусский  Released
# 584744          NaN    133.0                                తెలుగు  Released
# 584745          NaN     57.0                               Español  Released
#
#                                      tagline  \
# 0                                        NaN
# 1                                        NaN
# 2       The Intimate Secrets of Young Lovers
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 584741                                   NaN
# 584742                                   NaN
# 584743                                   NaN
# 584744                                   NaN
# 584745                                   NaN
#
#                                          title vote_average  vote_count  year
# 0                                      Blondie          7.1           5  1938
# 1                Peter Voss, Thief of Millions          NaN           0  1921
# 2                               Love at Twenty          6.8          36  1962
# 3           New World Disorder 9: Never Enough          4.5           2  2008
# 4               Sesame Street: Elmo Loves You!          NaN           0  2010
# ...                                        ...          ...         ...   ...
# 584741                                  拯救内衣少爷          NaN           0  2018
# 584742                                   妙探乌龙记          NaN           0  2018
# 584743                    Средство Макропулоса          NaN           0  1979
# 584744                      Manchi Rojulochaie          NaN           0  2021
# 584745  Photographer's Words - 68 Testimonials          NaN           0  2011
#
# [578044 rows x 21 columns]

# %%
df.drop('status', axis=1, inplace=True)

# %% [markdown]
# ## Concatenating the poster_path column values into full URL format and creating a HTML image tag column

# %%
df.poster_path[0:4]
# Out:
# 0    /o6UMTE2LzQdlKVxRnFECPmtQjsJ.jpg
# 1    /6xUbUCvndklbGVYiljHr34NTxSl.jpg
# 2    /aup2QCYCsyEeQfpboXy0f4uj8aE.jpg
# 3    /okQY6jVmRU19CUbYPUZC77K3XBE.jpg
# Name: poster_path, dtype: object

# %%
def html_poster_path(value, return_html=False):
    if type(value) == str:
        if return_html == False:

            return f"https://image.tmdb.org/t/p/w500{value}"
        else:
            return f"<img src='https://image.tmdb.org/t/p/w500{value}' style='height:100px;'>"
    else:
        return np.nan

# %%
df['html'] = df['poster_path'].apply(lambda x: html_poster_path(x, True))
df['poster_path'] = df['poster_path'].apply(lambda x: html_poster_path(x))

# %%
df[['html', 'poster_path']].head()
# Out:
#                                                 html  \
# 0  <img src='https://image.tmdb.org/t/p/w500/o6UM...
# 1  <img src='https://image.tmdb.org/t/p/w500/6xUb...
# 2  <img src='https://image.tmdb.org/t/p/w500/aup2...
# 3  <img src='https://image.tmdb.org/t/p/w500/okQY...
# 4  <img src='https://image.tmdb.org/t/p/w500/qKWc...
#
#                                          poster_path
# 0  https://image.tmdb.org/t/p/w500/o6UMTE2LzQdlKV...
# 1  https://image.tmdb.org/t/p/w500/6xUbUCvndklbGV...
# 2  https://image.tmdb.org/t/p/w500/aup2QCYCsyEeQf...
# 3  https://image.tmdb.org/t/p/w500/okQY6jVmRU19CU...
# 4  https://image.tmdb.org/t/p/w500/qKWcCmvGr4g0dg...

# %%
df.poster_path[0:4]
# Out:
# 0    https://image.tmdb.org/t/p/w500/o6UMTE2LzQdlKV...
# 1    https://image.tmdb.org/t/p/w500/6xUbUCvndklbGV...
# 2    https://image.tmdb.org/t/p/w500/aup2QCYCsyEeQf...
# 3    https://image.tmdb.org/t/p/w500/okQY6jVmRU19CU...
# Name: poster_path, dtype: object

# %% [markdown]
# ### Saving the cleaned DataFrame into a csv file.

# %% [markdown]
# ## Next, credits and cast information will be added to the DataFrame from the previously downloaded dataset.

# %%
credits = pd.read_csv('credits.csv', nrows=100)
credits
# Out:
#                                                     0
# 0   {'id': 3924, 'cast': [{'adult': False, 'gender...
# 1   {'id': 6124, 'cast': [{'adult': False, 'gender...
# 2   {'id': 8773, 'cast': [{'adult': False, 'gender...
# 3   {'id': 25449, 'cast': [{'adult': False, 'gende...
# 4               {'id': 31975, 'cast': [], 'crew': []}
# ..                                                ...
# 95  {'id': 126, 'cast': [{'adult': False, 'gender'...
# 96  {'id': 127, 'cast': [{'adult': False, 'gender'...
# 97  {'id': 128, 'cast': [{'adult': False, 'gender'...
# 98  {'id': 129, 'cast': [{'adult': False, 'gender'...
# 99  {'id': 132, 'cast': [{'adult': False, 'gender'...
#
# [100 rows x 1 columns]

# %% [markdown]
# ## Evaluating each value using literal_eval

# %%
credits['0'] = lit_eval(credits['0'])

# %%
credits = pd.json_normalize(credits['0'])
credits.head()
# Out:
#       id                                               cast  \
# 0   3924  [{'adult': False, 'gender': 1, 'id': 34178, 'k...
# 1   6124  [{'adult': False, 'gender': 2, 'id': 48038, 'k...
# 2   8773  [{'adult': False, 'gender': 2, 'id': 1653, 'kn...
# 3  25449  [{'adult': False, 'gender': 0, 'id': 84130, 'k...
# 4  31975                                                 []
#
#                                                 crew
# 0  [{'adult': False, 'gender': 0, 'id': 34170, 'k...
# 1  [{'adult': False, 'gender': 2, 'id': 2902, 'kn...
# 2  [{'adult': False, 'gender': 2, 'id': 1650, 'kn...
# 3  [{'adult': False, 'gender': 0, 'id': 112786, '...
# 4                                                 []

# %% [markdown]
# ## Replacing empty list entries with NaN

# %%
for column in ['cast', 'crew']:
    credits[column] = credits[column].apply(lambda x: np.nan if len(x) == 0 else x)

# %%
credits.isnull().sum()
# Out:
# id      0
# cast    3
# crew    1
# dtype: int64

# %%
credits.dropna(thresh=2, inplace=True)

# %% [raw]
# for i in range(len(credits))[:5]:
#     if type(credits.iloc[i,1]) == float and type(credits.iloc[i,2]) == float:

# %%
credits['cast_names'] = credits['cast'].apply(lambda x: '|'.join([i['name'] for i in x]) if type(x) == list else np.nan)
credits['crew_names'] = credits['crew'].apply(lambda x: '|'.join([i['name'] for i in x]) if type(x) == list else np.nan)

# %%
credits.head()
# Out:
#       id                                               cast  \
# 0   3924  [{'adult': False, 'gender': 1, 'id': 34178, 'k...
# 1   6124  [{'adult': False, 'gender': 2, 'id': 48038, 'k...
# 2   8773  [{'adult': False, 'gender': 2, 'id': 1653, 'kn...
# 3  25449  [{'adult': False, 'gender': 0, 'id': 84130, 'k...
# 4  31975                                                NaN
#
#                                                 crew  \
# 0  [{'adult': False, 'gender': 0, 'id': 34170, 'k...
# 1  [{'adult': False, 'gender': 2, 'id': 2902, 'kn...
# 2  [{'adult': False, 'gender': 2, 'id': 1650, 'kn...
# 3  [{'adult': False, 'gender': 0, 'id': 112786, '...
# 4                                                NaN
#
#                                           cast_names  \
# 0  Penny Singleton|Arthur Lake|Larry Simms|Daisy|...
# 1  Harry Liedtke|Georg Alexander|Mady Christians|...
# 2  Jean-Pierre Léaud|Marie-France Pisier|Patrick ...
# 3  Darren Berrecloth|Cameron McCaul|Paul Basagoit...
# 4                                                NaN
#
#                                           crew_names
# 0                  Frank R. Strayer|Richard Flournoy
# 1  Robert Liebmann|Frederik Fuglsang|Georg Jacoby...
# 2  François Truffaut|François Truffaut|Gérard Bra...
# 3                                   Derek Westerlund
# 4                                                NaN

# %%
x = pd.json_normalize(credits['cast'])
x.head()
# Out:
#                                                  0    \
# 0  {'adult': False, 'gender': 1, 'id': 34178, 'kn...
# 1  {'adult': False, 'gender': 2, 'id': 48038, 'kn...
# 2  {'adult': False, 'gender': 2, 'id': 1653, 'kno...
# 3  {'adult': False, 'gender': 0, 'id': 84130, 'kn...
# 4                                               None
#
#                                                  1    \
# 0  {'adult': False, 'gender': 2, 'id': 34179, 'kn...
# 1  {'adult': False, 'gender': 2, 'id': 28126, 'kn...
# 2  {'adult': False, 'gender': 1, 'id': 3536, 'kno...
# 3  {'adult': False, 'gender': 0, 'id': 84143, 'kn...
# 4                                               None
#
#                                                  2    \
# 0  {'adult': False, 'gender': 2, 'id': 30223, 'kn...
# 1  {'adult': False, 'gender': 1, 'id': 14357, 'kn...
# 2  {'adult': False, 'gender': 0, 'id': 1659, 'kno...
# 3  {'adult': False, 'gender': 0, 'id': 112801, 'k...
# 4                                               None
#
#                                                  3    \
# 0  {'adult': False, 'gender': 2, 'id': 34214, 'kn...
# 1  {'adult': False, 'gender': 2, 'id': 14131, 'kn...
# 2  {'adult': False, 'gender': 1, 'id': 3537, 'kno...
# 3  {'adult': False, 'gender': 0, 'id': 112818, 'k...
# 4                                               None
#
#                                                  4    \
# 0  {'adult': False, 'gender': 1, 'id': 2772, 'kno...
# 1                                               None
# 2  {'adult': False, 'gender': 2, 'id': 3518, 'kno...
# 3  {'adult': False, 'gender': 0, 'id': 115965, 'k...
# 4                                               None
#
#                                                  5    \
# 0  {'adult': False, 'gender': 1, 'id': 34183, 'kn...
# 1                                               None
# 2  {'adult': False, 'gender': 0, 'id': 3538, 'kno...
# 3  {'adult': False, 'gender': 0, 'id': 112793, 'k...
# 4                                               None
#
#                                                  6    \
# 0  {'adult': False, 'gender': 2, 'id': 30234, 'kn...
# 1                                               None
# 2  {'adult': False, 'gender': 2, 'id': 1003228, '...
# 3  {'adult': False, 'gender': 0, 'id': 112794, 'k...
# 4                                               None
#
#                                                  7    \
# 0  {'adult': False, 'gender': 2, 'id': 12502, 'kn...
# 1                                               None
# 2  {'adult': False, 'gender': 1, 'id': 237623, 'k...
# 3  {'adult': False, 'gender': 0, 'id': 112798, 'k...
# 4                                               None
#
#                                                  8    \
# 0  {'adult': False, 'gender': 0, 'id': 34180, 'kn...
# 1                                               None
# 2  {'adult': False, 'gender': 0, 'id': 1003229, '...
# 3                                               None
# 4                                               None
#
#                                                  9    ...   142   143   144  \
# 0  {'adult': False, 'gender': 2, 'id': 34181, 'kn...  ...  None  None  None
# 1                                               None  ...  None  None  None
# 2  {'adult': False, 'gender': 1, 'id': 25789, 'kn...  ...  None  None  None
# 3                                               None  ...  None  None  None
# 4                                               None  ...  None  None  None
#
#     145   146   147   148   149   150   151
# 0  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None
#
# [5 rows x 152 columns]

# %%
y = x.fillna(np.nan)

# %%
x.iloc[0,:].apply(lambda x: x['name'] if type(x) == dict else np.nan)
# Out:
# 0      Penny Singleton
# 1          Arthur Lake
# 2          Larry Simms
# 3                Daisy
# 4            Ann Doran
#             ...
# 147                NaN
# 148                NaN
# 149                NaN
# 150                NaN
# 151                NaN
# Name: 0, Length: 152, dtype: object

# %%
df[df.id == 34178]
# Out:
# Empty DataFrame
# Columns: [index, belongs_to_collection, budget_musd, genres, id, original_language, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue_musd, runtime, spoken_languages, tagline, title, vote_average, vote_count, year, html]
# Index: []
#
# [0 rows x 21 columns]

# %%
x.iloc[0,0]
# Out:
# {'adult': False,
#  'gender': 1,
#  'id': 34178,
#  'known_for_department': 'Acting',
#  'name': 'Penny Singleton',
#  'original_name': 'Penny Singleton',
#  'popularity': 0.985,
#  'profile_path': '/zdSAcjLWrwcnu9Aph8BcSwobAHR.jpg',
#  'cast_id': 2,
#  'character': 'Blondie',
#  'credit_id': '52fe43a6c3a36847f8064da1',
#  'order': 0}

# %%
cast = dict()
for entry in x.iloc[0,:]:
    if type(entry) == dict:
        
        cast[entry['id']] = dict()
        for key in ['cast_id', 'name', 'character', 'profile_path', 'popularity']:
            try:
                cast[entry['id']][key] = entry[key]
            except:
                cast[entry['id']][key] = np.nan

# %%
pd.DataFrame(cast).T
# Out:
#         cast_id                name                               character  \
# 34178         2     Penny Singleton                                 Blondie
# 34179         1         Arthur Lake                                 Dagwood
# 30223         3         Larry Simms                           Baby Dumpling
# 34214        17               Daisy                                   Daisy
# 2772         11           Ann Doran                            Elsie Hazlip
# 34183        14       Dorothy Moore                                 Dorothy
# 30234         4       Gene Lockhart                             C.P. Hazlip
# 12502         8       Jonathan Hale                             Mr. Dithers
# 34180        15       Gordon Oliver                          Chester Franey
# 34181         9       Danny Mummert                                   Alvin
# 34182        16   Kathleen Lockhart                             Mrs. Miller
# 34185        13         Willie Best                                  Porter
# 2782         12           Ian Wolfe                                   Judge
# 1292673      19  Eugene Anderson Jr                    Newsboy (uncredited)
# 34505        20     Stanley Andrews                  Mr. Hicks (uncredited)
# 121097       21      Hooper Atchley                 Man on Bus (uncredited)
# 34241        22       Stanley Brown        S.W. Carey Salesman (uncredited)
# 1173491      23     Mary Jane Carey                       Mary (uncredited)
# 153638       24         Dick Curtis     Daily Gazette Reporter (uncredited)
# 1240252      25       Edgar Dearing         Policeman at Hotel (uncredited)
# 34243        26       Richard Fiske                     Nelson (uncredited)
# 3262         27        James Flavin  Policeman in Accident Car (uncredited)
# 34184        28            Fay Helm                Mrs. Fuddle (uncredited)
# 106091       29      George Humbert               Pie Salesman (uncredited)
# 89615        30         Bud Jamison                Repossessor (uncredited)
# 29579        31        Charles Lane         Furniture Salesman (uncredited)
# 1005423      32       Harold Minjir               Mr. Phillips (uncredited)
# 942165       33        David Newell            First Draftsman (uncredited)
# 124875       34       Emory Parnell       Police Desk Sergeant (uncredited)
# 21310        35           John Rand                   Gardener (uncredited)
# 1420879      36        Bruce Sidney         Detective at Hotel (uncredited)
# 34270        37    Walter Soderling                 Mr. Morgan (uncredited)
# 135827       38        Larry Steers      Assistant Hotel Clerk (uncredited)
# 99376        39  Josephine Whittell   Woman Seeing Optometrist (uncredited)
# 30530        40        Irving Bacon                Mr. Beazley (uncredited)
#
#                              profile_path popularity
# 34178    /zdSAcjLWrwcnu9Aph8BcSwobAHR.jpg      0.985
# 34179    /6PSZ2Mpz70bOqWkiFvm5723bwwH.jpg       0.84
# 30223    /4BZZEo3KK3awodvEvB7ZjH5eKJB.jpg       1.96
# 34214    /rnonRe8I10nt4ZgnsT1q5QrusCB.jpg      0.989
# 2772     /t6q0svIGjotyJQgxr74pKz6462g.jpg      2.384
# 34183    /kT6X0anW36TeCcnEcUS8p6PLqZH.jpg       0.98
# 30234    /8lSQRefIA5kNylZOF7anexkDxqQ.jpg        1.4
# 12502    /fFj1Lhkn5FZWDbAGOJTRFsGYi1J.jpg        0.6
# 34180    /1f7YAGrlReAeBy7wWhRrANZRkw1.jpg        0.6
# 34181    /cELXh49xO4qau65l3B9xRXbaAjI.jpg      1.093
# 34182    /kIgyhuy3tFRz6XIyWdJss017go5.jpg      0.828
# 34185    /ss0Yb7eoHrjOLJ6ROJtBnHu6xtG.jpg      1.831
# 2782     /8Eum5GDti8Zh9ZyYSvWaoIHt8Wr.jpg      1.532
# 1292673                              None        0.6
# 34505    /2EGXOfg1TnTdLz4rTayHDanfI1d.jpg      1.477
# 121097                               None        0.6
# 34241    /5tZkikHz5Z7fPKMU6UpRz3dIkOk.jpg        0.6
# 1173491                              None        0.6
# 153638                               None        1.4
# 1240252  /gD7Fd6ksHRGNnWFOw0qv9v8QVmd.jpg        0.6
# 34243    /9HpRvRbP2tBF5hOmC5maqtCokLK.jpg        0.6
# 3262     /31fJGfekarwtB4OrMG7oGEBGgKm.jpg      1.553
# 34184    /mmfKcBTFF7Gf8klZyJn7iqlgTWx.jpg      1.273
# 106091   /qBKG1we50E5peg8FeS3WwVYtjDQ.jpg      0.648
# 89615    /AiiqQpcsDraQqYxkKwwKHmCU0QE.jpg       1.62
# 29579    /xKQ0LzsSKrJg7s3xqU4cUzaQ9m8.jpg      2.283
# 1005423  /c2BmgZjyd0OwgbfaMTaa7mUHoQM.jpg        0.6
# 942165   /tO7w2vzG1eiiVD2NwIF7WfjAjuf.jpg       0.98
# 124875   /sS6qfDabEwf1bLNpLi8EcRlVrmb.jpg      1.565
# 21310    /hVv5NHtoCvIPX7V4eYTj78cEzdF.jpg      0.649
# 1420879                              None        0.6
# 34270    /f1jnof2PntGKDA95AEjcjlkJoWi.jpg       1.38
# 135827                               None        1.4
# 99376     /WjyzxC8WsxcnfiZWPFSOfyWYEI.jpg      0.694
# 30530    /zgCDH4kRXESzKLOtqNu8Gk5KNxh.jpg      1.866

# %%
z
# Out:
#                                                   0    \
# 0   {'adult': False, 'gender': 0, 'id': 34170, 'kn...
# 1   {'adult': False, 'gender': 2, 'id': 2902, 'kno...
# 2   {'adult': False, 'gender': 2, 'id': 1650, 'kno...
# 3   {'adult': False, 'gender': 0, 'id': 112786, 'k...
# 4                                                None
# ..                                                ...
# 95  {'adult': False, 'gender': 2, 'id': 1126, 'kno...
# 96  {'adult': False, 'gender': 2, 'id': 1126, 'kno...
# 97  {'adult': False, 'gender': 2, 'id': 608, 'know...
# 98  {'adult': False, 'gender': 2, 'id': 608, 'know...
# 99  {'adult': False, 'gender': 2, 'id': 1418, 'kno...
#
#                                                   1    \
# 0   {'adult': False, 'gender': 2, 'id': 34171, 'kn...
# 1   {'adult': False, 'gender': 2, 'id': 29032, 'kn...
# 2   {'adult': False, 'gender': 2, 'id': 1650, 'kno...
# 3                                                None
# 4                                                None
# ..                                                ...
# 95  {'adult': False, 'gender': 2, 'id': 1126, 'kno...
# 96  {'adult': False, 'gender': 2, 'id': 1126, 'kno...
# 97  {'adult': False, 'gender': 2, 'id': 608, 'know...
# 98  {'adult': False, 'gender': 2, 'id': 608, 'know...
# 99  {'adult': False, 'gender': 2, 'id': 1418, 'kno...
#
#                                                   2    \
# 0                                                None
# 1   {'adult': False, 'gender': 2, 'id': 48035, 'kn...
# 2   {'adult': False, 'gender': 2, 'id': 2356, 'kno...
# 3                                                None
# 4                                                None
# ..                                                ...
# 95  {'adult': False, 'gender': 0, 'id': 1396, 'kno...
# 96  {'adult': False, 'gender': 0, 'id': 1380, 'kno...
# 97  {'adult': False, 'gender': 2, 'id': 636, 'know...
# 98  {'adult': False, 'gender': 2, 'id': 636, 'know...
# 99  {'adult': False, 'gender': 0, 'id': 1421, 'kno...
#
#                                                   3    \
# 0                                                None
# 1   {'adult': False, 'gender': 2, 'id': 48035, 'kn...
# 2   {'adult': False, 'gender': 2, 'id': 2801, 'kno...
# 3                                                None
# 4                                                None
# ..                                                ...
# 95  {'adult': False, 'gender': 0, 'id': 1396, 'kno...
# 96  {'adult': False, 'gender': 0, 'id': 1397, 'kno...
# 97  {'adult': False, 'gender': 2, 'id': 1417, 'kno...
# 98  {'adult': False, 'gender': 2, 'id': 1417, 'kno...
# 99  {'adult': False, 'gender': 0, 'id': 1423, 'kno...
#
#                                                   4    \
# 0                                                None
# 1                                                None
# 2   {'adult': False, 'gender': 2, 'id': 3535, 'kno...
# 3                                                None
# 4                                                None
# ..                                                ...
# 95  {'adult': False, 'gender': 0, 'id': 1397, 'kno...
# 96  {'adult': False, 'gender': 0, 'id': 1399, 'kno...
# 97  {'adult': False, 'gender': 2, 'id': 19596, 'kn...
# 98  {'adult': False, 'gender': 2, 'id': 19596, 'kn...
# 99  {'adult': False, 'gender': 0, 'id': 1425, 'kno...
#
#                                                   5    \
# 0                                                None
# 1                                                None
# 2   {'adult': False, 'gender': 0, 'id': 3539, 'kno...
# 3                                                None
# 4                                                None
# ..                                                ...
# 95  {'adult': False, 'gender': 0, 'id': 1398, 'kno...
# 96  {'adult': False, 'gender': 0, 'id': 1399, 'kno...
# 97  {'adult': False, 'gender': 2, 'id': 19596, 'kn...
# 98  {'adult': False, 'gender': 2, 'id': 1697, 'kno...
# 99  {'adult': False, 'gender': 0, 'id': 1426, 'kno...
#
#                                                   6    \
# 0                                                None
# 1                                                None
# 2   {'adult': False, 'gender': 2, 'id': 3540, 'kno...
# 3                                                None
# 4                                                None
# ..                                                ...
# 95  {'adult': False, 'gender': 0, 'id': 1399, 'kno...
# 96  {'adult': False, 'gender': 2, 'id': 1400, 'kno...
# 97  {'adult': False, 'gender': 2, 'id': 1697, 'kno...
# 98  {'adult': False, 'gender': 2, 'id': 19595, 'kn...
# 99  {'adult': False, 'gender': 0, 'id': 1427, 'kno...
#
#                                                   7    \
# 0                                                None
# 1                                                None
# 2   {'adult': False, 'gender': 1, 'id': 3583, 'kno...
# 3                                                None
# 4                                                None
# ..                                                ...
# 95  {'adult': False, 'gender': 0, 'id': 1399, 'kno...
# 96  {'adult': False, 'gender': 1, 'id': 1401, 'kno...
# 97  {'adult': False, 'gender': 2, 'id': 19595, 'kn...
# 98  {'adult': False, 'gender': 2, 'id': 19598, 'kn...
# 99  {'adult': False, 'gender': 1, 'id': 1477, 'kno...
#
#                                                   8    \
# 0                                                None
# 1                                                None
# 2   {'adult': False, 'gender': 1, 'id': 7103, 'kno...
# 3                                                None
# 4                                                None
# ..                                                ...
# 95  {'adult': False, 'gender': 1, 'id': 1401, 'kno...
# 96  {'adult': False, 'gender': 2, 'id': 1138666, '...
# 97  {'adult': False, 'gender': 2, 'id': 19598, 'kn...
# 98  {'adult': False, 'gender': 1, 'id': 19599, 'kn...
# 99  {'adult': False, 'gender': 2, 'id': 73784, 'kn...
#
#                                                   9    ...   409   410   411  \
# 0                                                None  ...  None  None  None
# 1                                                None  ...  None  None  None
# 2   {'adult': False, 'gender': 1, 'id': 18223, 'kn...  ...  None  None  None
# 3                                                None  ...  None  None  None
# 4                                                None  ...  None  None  None
# ..                                                ...  ...   ...   ...   ...
# 95  {'adult': False, 'gender': 0, 'id': 1544868, '...  ...  None  None  None
# 96  {'adult': False, 'gender': 0, 'id': 1138978, '...  ...  None  None  None
# 97  {'adult': False, 'gender': 1, 'id': 19601, 'kn...  ...  None  None  None
# 98  {'adult': False, 'gender': 1, 'id': 19601, 'kn...  ...  None  None  None
# 99  {'adult': False, 'gender': 2, 'id': 80482, 'kn...  ...  None  None  None
#
#      412   413   414   415   416   417   418
# 0   None  None  None  None  None  None  None
# 1   None  None  None  None  None  None  None
# 2   None  None  None  None  None  None  None
# 3   None  None  None  None  None  None  None
# 4   None  None  None  None  None  None  None
# ..   ...   ...   ...   ...   ...   ...   ...
# 95  None  None  None  None  None  None  None
# 96  None  None  None  None  None  None  None
# 97  None  None  None  None  None  None  None
# 98  None  None  None  None  None  None  None
# 99  None  None  None  None  None  None  None
#
# [100 rows x 419 columns]

# %%
for x in range(z.shape[0])[:3]:
    for y in range(z.shape[1]):
        try:
            print(z.iloc[x,y]['name'])
        except:
            break
# Out:
# Frank R. Strayer
# Richard Flournoy
# Robert Liebmann
# Frederik Fuglsang
# Georg Jacoby
# Georg Jacoby
# François Truffaut
# François Truffaut
# Gérard Brach
# Andrzej Wajda
# Georges Delerue
# Pierre Roustang
# Raoul Coutard
# Suzanne Schiffman
# Barbara Pec-Slesicka
# Claudine Bouché
# Marcel Ophüls
# Marcel Ophüls
# Charles L. Bitsch
# Guy Villette
# Mario Montuori
# Andrzej Żuławski
# Toru Takemitsu
# Jerzy Lipman
# Jerzy Matuszkiewicz
# Shintarō Ishihara
# Shintarō Ishihara
# Renzo Rossellini
# Renzo Rossellini
# Jerzy Stefan Stawiński
# Philippe Dussart
# Wolf Wirth
# Halina Nawrocka
# Shigeo Murata
# Yvon Samuel

# %%
html_poster_path(x['cast'][0]['profile_path'])
# Out:
# 'https://image.tmdb.org/t/p/w500/zdSAcjLWrwcnu9Aph8BcSwobAHR.jpg'

# %%
for i in z.iloc[0,:]:
    print(i)
# Out:
# {'adult': False, 'gender': 0, 'id': 34170, 'known_for_department': 'Directing', 'name': 'Frank R. Strayer', 'original_name': 'Frank R. Strayer', 'popularity': 0.98, 'profile_path': '/nVUNLnwGu6Ir7jV8ZUJRtn7jiT8.jpg', 'credit_id': '52fe43a6c3a36847f8064daf', 'department': 'Directing', 'job': 'Director'}
# {'adult': False, 'gender': 2, 'id': 34171, 'known_for_department': 'Writing', 'name': 'Richard Flournoy', 'original_name': 'Richard Flournoy', 'popularity': 0.764, 'profile_path': None, 'credit_id': '52fe43a6c3a36847f8064db5', 'department': 'Writing', 'job': 'Screenplay'}
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %% [markdown]
# ### credits DataFrame also contains duplicate entries, which will be removed.

# %%
credits[credits.duplicated(subset='id', keep=False)].sort_values('id')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3724/1766200368.py in <module>
# ----> 1 credits[credits.duplicated(subset='id', keep=False)].sort_values('id')
#
# D:\anaconda3\envs\my-env\lib\site-packages\pandas\core\frame.py in duplicated(self, subset, keep)
#    6195         diff = Index(subset).difference(self.columns)
#    6196         if not diff.empty:
# -> 6197             raise KeyError(diff)
#    6198
#    6199         vals = (col.values for name, col in self.items() if name in subset)
#
# KeyError: Index(['id'], dtype='object')

# %%
credits.drop_duplicates(subset='id', inplace=True)

# %%
df[~df.id.isin(credits.id)]
# Out:
# Empty DataFrame
# Columns: [id, title, tagline, release_date, genres, belongs_to_collection, original_language, budget_musd, revenue_musd, production_companies, production_countries, vote_count, vote_average, popularity, runtime, overview, spoken_languages, poster_path]
# Index: []

# %%
credits[~credits.id.isin(df.id)]
# Out:
#                                                     cast  \
# 189    [{'cast_id': 4, 'character': 'Himself', 'credi...
# 554    [{'cast_id': 3, 'character': '', 'credit_id': ...
# 682    [{'cast_id': 2, 'character': 'Eunice', 'credit...
# 685    [{'cast_id': 0, 'character': 'James Bird', 'cr...
# 711                                                   []
# ...                                                  ...
# 45320  [{'cast_id': 0, 'character': 'Mała metalowa dz...
# 45323  [{'cast_id': 0, 'character': 'Krzysiek Buk', '...
# 45348                                                 []
# 45420  [{'cast_id': 1, 'character': 'Aprel', 'credit_...
# 45452                                                 []
#
#                                                     crew      id
# 189                                                   []   56088
# 554    [{'credit_id': '52fe4e4dc3a368484e21952d', 'de...  218473
# 682    [{'credit_id': '52fe475cc3a36847f81317f7', 'de...   48260
# 685    [{'credit_id': '57a321c6c3a3683fa70013d8', 'de...  277270
# 711                                                   []  365371
# ...                                                  ...     ...
# 45320  [{'credit_id': '57ee6832c3a3682a2d003ccd', 'de...  418757
# 45323  [{'credit_id': '564fd6a59251414b01005a8a', 'de...  369444
# 45348                                                 []  335251
# 45420  [{'credit_id': '58d83051c3a368126f0567fe', 'de...  449131
# 45452  [{'credit_id': '52fe4684c3a36847f81034f3', 'de...   44330
#
# [741 rows x 3 columns]

# %% [markdown]
# ### Using a left join, both DataFrames will be joined based on the "id" column.

# %%
df = df.merge(credits, on='id', how='left')

# %%
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# 3      Comedy|Drama|Romance                             NaN                en
# 4                    Comedy  Father of the Bride Collection                en
#
#    budget_musd  revenue_musd  \
# 0         30.0    373.554033
# 1         65.0    262.797249
# 2          NaN           NaN
# 3         16.0     81.452156
# 4          NaN     76.578911
#
#                                 production_companies  \
# 0                            Pixar Animation Studios
# 1  TriStar Pictures|Teitler Film|Interscope Commu...
# 2                        Warner Bros.|Lancaster Gate
# 3             Twentieth Century Fox Film Corporation
# 4          Sandollar Productions|Touchstone Pictures
#
#        production_countries  vote_count  vote_average  popularity  runtime  \
# 0  United States of America      5415.0           7.7   21.946943     81.0
# 1  United States of America      2413.0           6.9   17.015539    104.0
# 2  United States of America        92.0           6.5   11.712900    101.0
# 3  United States of America        34.0           6.1    3.859495    127.0
# 4  United States of America       173.0           5.7    8.387519    106.0
#
#                                             overview  spoken_languages  \
# 0  Led by Woody, Andy's toys live happily in his ...           English
# 1  When siblings Judy and Peter discover an encha...  English|Français
# 2  A family wedding reignites the ancient feud be...           English
# 3  Cheated on, mistreated and stepped on, the wom...           English
# 4  Just when George Banks has recovered from his ...           English
#
#                                          poster_path  \
# 0  <img src='http://image.tmdb.org/t/p/w185//rhIR...
# 1  <img src='http://image.tmdb.org/t/p/w185//vzmL...
# 2  <img src='http://image.tmdb.org/t/p/w185//6ksm...
# 3  <img src='http://image.tmdb.org/t/p/w185//16XO...
# 4  <img src='http://image.tmdb.org/t/p/w185//e64s...
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...

# %% [markdown]
# ## Formatting stringified JSON into lists/dictionaries.

# %%
for column in ['cast', 'crew']:
    df[column] = df[column].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)

# %% [markdown]
# ## Getting cast and crew size for each movie.

# %%
df['cast_size'] = df.cast.apply(lambda x: len(x))
df['crew_size'] = df.crew.apply(lambda x: len(x))

# %%
df[['cast', 'crew', 'cast_size', 'crew_size']]
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': 'Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 44686  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 44687  [{'cast_id': 1002, 'character': 'Sister Angela...
# 44688  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 44689  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 44690                                                 []
#
#                                                     crew  cast_size  crew_size
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...         13        106
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...         26         16
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...          7          4
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...         10         10
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...         12          7
# ...                                                  ...        ...        ...
# 44686  [{'credit_id': '5894a97d925141426c00818c', 'de...          3          9
# 44687  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...         11          6
# 44688  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...         15          5
# 44689  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...          5          2
# 44690  [{'credit_id': '593e676c92514105b702e68e', 'de...          0          1
#
# [44691 rows x 4 columns]

# %% [markdown]
# ### Taking the "name" keys for cast/crew and joining them with a pipe ("|") symbol.

# %%
df.head(1)
# Out:
#     id      title tagline release_date                   genres  \
# 0  862  Toy Story     NaN   1995-10-30  Animation|Comedy|Family
#
#   belongs_to_collection original_language  budget_musd  revenue_musd  \
# 0  Toy Story Collection                en         30.0    373.554033
#
#       production_companies      production_countries  vote_count  \
# 0  Pixar Animation Studios  United States of America      5415.0
#
#    vote_average  popularity  runtime  \
# 0           7.7   21.946943     81.0
#
#                                             overview spoken_languages  \
# 0  Led by Woody, Andy's toys live happily in his ...          English
#
#                                          poster_path  \
# 0  <img src='http://image.tmdb.org/t/p/w185//rhIR...
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
#
#                                                 crew  cast_size  crew_size
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...         13        106

# %%
# Renaming the json columns for differentiation with the text columns
df.rename(columns={'cast': 'cast_json','crew':'crew_json'}, inplace=True)

df['cast'] = df.cast_json.apply(lambda x: '|'.join(i['name'] for i in x) if isinstance(x, list) else np.nan)
df['crew'] = df.crew_json.apply(lambda x: '|'.join(i['name'] for i in x) if isinstance(x, list) else np.nan)
# Out:
# C:\Users\Andrea\AppData\Local\Temp/ipykernel_11968/1766258599.py:4: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.cast = df.cast_json.apply(lambda x: '|'.join(i['name'] for i in x) if isinstance(x, list) else np.nan)
# C:\Users\Andrea\AppData\Local\Temp/ipykernel_11968/1766258599.py:5: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.crew = df.crew_json.apply(lambda x: '|'.join(i['name'] for i in x) if isinstance(x, list) else np.nan)

# %%
print(f"Cast Example:\n{df.cast[0]}")
print('='*180)
print(f"Crew Example:\n{df.crew[0]}")
# Out:
# Cast Example:
# Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette
# ====================================================================================================================================================================================
# Crew Example:
# John Lasseter|Joss Whedon|Andrew Stanton|Joel Cohen|Alec Sokolow|Bonnie Arnold|Ed Catmull|Ralph Guggenheim|Steve Jobs|Lee Unkrich|Ralph Eggleston|Robert Gordon|Mary Helen Leasman|Kim Blanchette|Marilyn McCoppen|Randy Newman|Dale E. Grahn|Robin Cooper|John Lasseter|Pete Docter|Joe Ranft|Patsy Bouge|Norm DeCarlo|Ash Brannon|Randy Newman|Roman Figun|Don Davis|James Flamberg|Mary Beth Smith|Rick Mackay|Susan Bradley|William Reeves|Randy Newman|Andrew Stanton|Pete Docter|Gary Rydstrom|Karen Robert Jackson|Chris Montan|Rich Quade|Michael Berenstein|Colin Brady|Davey Crockett Feiten|Angie Glocka|Rex Grignon|Tom K. Gurney|Jimmy Hayward|Hal T. Hickel|Karen Kiser|Anthony B. LaMolinara|Guionne Leroy|Bud Luckey|Les Major|Glenn McQueen|Mark Oftedal|Jeff Pidgeon|Jeff Pratt|Steve Rabatich|Roger Rose|Steve Segal|Doug Sheppeck|Alan Sperling|Doug Sweetland|David Tart|Ken Willard|Thomas Porter|Mark Thomas Henne|Oren Jacob|Darwyn Peachey|Mitch Prater|Brian M. Rosen|Sharon Calahan|Galyn Susman|William Cone|Shelley Daniels Lekven|Bob Pauley|Bud Luckey|Andrew Stanton|William Cone|Steve Johnson|Dan Haskett|Tom Holloway|Jean Gillmore|Desirée Mourad|Kelly O'Connell|Sonoko Konishi|Ann M. Rockwell|Julie M. McDonald|Robin Lee|Tom Freeman|Ada Cochavi|Dana Mulligan|Deirdre Morrison|Lori Lombardo|Ellen Devine|Lauren Beth Strogoff|Gary Rydstrom|Gary Summers|Tim Holland|Pat Jackson|Tom Myers|J.R. Grubbs|Susan Sanford|Susan Popovic|Dan Engstrom|Ruth Lambert|Mickie McGowan

# %% [markdown]
# ### Creating a "director" column from the crew JSON column.

# %%
def get_director(x):
    for i in x:
        if i['job'] == 'Director':
            return i['name']
    return np.nan

df['director'] = df.crew_json.apply(get_director)

# %%
df['director'].value_counts(dropna=False)
# Out:
# NaN                 731
# John Ford            66
# Michael Curtiz       65
# Werner Herzog        54
# Alfred Hitchcock     53
#                    ...
# Jason Osder           1
# John Alan Simon       1
# Jennifer Kent         1
# Hiroshi Ando          1
# Daisy Asquith         1
# Name: director, Length: 17350, dtype: int64

# %%
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# 3      Comedy|Drama|Romance                             NaN                en
# 4                    Comedy  Father of the Bride Collection                en
#
#    budget_musd  revenue_musd  \
# 0         30.0    373.554033
# 1         65.0    262.797249
# 2          NaN           NaN
# 3         16.0     81.452156
# 4          NaN     76.578911
#
#                                 production_companies  \
# 0                            Pixar Animation Studios
# 1  TriStar Pictures|Teitler Film|Interscope Commu...
# 2                        Warner Bros.|Lancaster Gate
# 3             Twentieth Century Fox Film Corporation
# 4          Sandollar Productions|Touchstone Pictures
#
#        production_countries  vote_count  vote_average  popularity  runtime  \
# 0  United States of America      5415.0           7.7   21.946943     81.0
# 1  United States of America      2413.0           6.9   17.015539    104.0
# 2  United States of America        92.0           6.5   11.712900    101.0
# 3  United States of America        34.0           6.1    3.859495    127.0
# 4  United States of America       173.0           5.7    8.387519    106.0
#
#                                             overview  spoken_languages  \
# 0  Led by Woody, Andy's toys live happily in his ...           English
# 1  When siblings Judy and Peter discover an encha...  English|Français
# 2  A family wedding reignites the ancient feud be...           English
# 3  Cheated on, mistreated and stepped on, the wom...           English
# 4  Just when George Banks has recovered from his ...           English
#
#                                          poster_path  \
# 0  <img src='http://image.tmdb.org/t/p/w185//rhIR...
# 1  <img src='http://image.tmdb.org/t/p/w185//vzmL...
# 2  <img src='http://image.tmdb.org/t/p/w185//6ksm...
# 3  <img src='http://image.tmdb.org/t/p/w185//16XO...
# 4  <img src='http://image.tmdb.org/t/p/w185//e64s...
#
#                                            cast_json  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': 'Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                            crew_json  cast_size  crew_size  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...         13        106
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...         26         16
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...          7          4
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...         10         10
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...         12          7
#
#           director
# 0    John Lasseter
# 1     Joe Johnston
# 2    Howard Deutch
# 3  Forest Whitaker
# 4    Charles Shyer

# %% [markdown]
# ### Saving the final DataFrame into a csv file.

# %%
df.to_csv('movies_complete.csv', index = False)

# %% [markdown]
# ### In Part 2 of this project, we will try and gain some insight from the cleaned data about what types of movies are more popular, the average budget and revenue of the most successful movies, what genres are more popular, and many more.

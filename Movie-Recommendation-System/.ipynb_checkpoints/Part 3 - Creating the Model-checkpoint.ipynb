# %% [markdown]
# # TMDb Movie Data Analysis and Building a Movie Recommendation System
# ## Part 3: Recommender System Through Content-Based Filtering

# %% [markdown]
# ### In this section, we will vectorize all relevant columns and create a cosine similarity matrix to use for our movie recommendation system.

# %% [markdown]
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %% [markdown]
# ## Loading the main libraries

# %%
import pandas as pd
import numpy as np
from ast import literal_eval
import scipy.sparse
pd.options.display.max_columns = 30
#pd.set_option('precision', 2)

# %% [markdown]
# ## Loading the Dataset

# %%
df = pd.read_csv('movies_complete.csv')
df.head()
# Out:
#   belongs_to_collection  budget_musd         genres     id original_language  \
# 0    Blondie Collection          NaN         Comedy   3924                en
# 1                   NaN          NaN      Adventure   6124                de
# 2                   NaN          NaN  Drama|Romance   8773                fr
# 3    New World Disorder          NaN            NaN  25449                en
# 4                   NaN          NaN         Family  31975                en
#
#                                             overview  popularity  \
# 0  Blondie and Dagwood are about to celebrate the...       2.445
# 1  Der Mann ohne Namen is a German adventure movi...       0.600
# 2  Love at Twenty unites five directors from five...       4.985
# 3  Gee Atherton ripping the Worlds course the day...       1.337
# 4  Elmo is making a very, very super special surp...       0.600
#
#                                          poster_path  \
# 0  https://image.tmdb.org/t/p/w500/o6UMTE2LzQdlKV...
# 1  https://image.tmdb.org/t/p/w500/6xUbUCvndklbGV...
# 2  https://image.tmdb.org/t/p/w500/aup2QCYCsyEeQf...
# 3  https://image.tmdb.org/t/p/w500/okQY6jVmRU19CU...
# 4  https://image.tmdb.org/t/p/w500/qKWcCmvGr4g0dg...
#
#                                 production_companies  \
# 0                                  Columbia Pictures
# 1                                                NaN
# 2  Ulysse Productions|Unitec Films|Cinesecolo|Toh...
# 3                                                NaN
# 4                                                NaN
#
#                 production_countries release_date  revenue_musd  runtime  \
# 0           United States of America   1938-11-30           NaN     70.0
# 1                            Germany   1921-01-01           NaN    420.0
# 2  Germany|France|Italy|Japan|Poland   1962-06-22           NaN    110.0
# 3                                NaN   2008-12-08           NaN     69.0
# 4                                NaN   2010-01-05           NaN     46.0
#
#                        spoken_languages                               tagline  \
# 0                               English                                   NaN
# 1                                   NaN                                   NaN
# 2  Deutsch|Français|Italiano|日本語|Polski  The Intimate Secrets of Young Lovers
# 3                               English                                   NaN
# 4                                   NaN                                   NaN
#
#                                 title  vote_average  vote_count    year  \
# 0                             Blondie           7.1           5  1938.0
# 1       Peter Voss, Thief of Millions           NaN           0  1921.0
# 2                      Love at Twenty           6.8          36  1962.0
# 3  New World Disorder 9: Never Enough           4.5           2  2008.0
# 4      Sesame Street: Elmo Loves You!           NaN           0  2010.0
#
#                                                 html  \
# 0  <img src='https://image.tmdb.org/t/p/w500/o6UM...
# 1  <img src='https://image.tmdb.org/t/p/w500/6xUb...
# 2  <img src='https://image.tmdb.org/t/p/w500/aup2...
# 3  <img src='https://image.tmdb.org/t/p/w500/okQY...
# 4  <img src='https://image.tmdb.org/t/p/w500/qKWc...
#
#                                           cast_names  \
# 0  Penny Singleton|Arthur Lake|Larry Simms|Daisy|...
# 1  Harry Liedtke|Georg Alexander|Mady Christians|...
# 2  Jean-Pierre Léaud|Marie-France Pisier|Patrick ...
# 3  Darren Berrecloth|Cameron McCaul|Paul Basagoit...
# 4                                                NaN
#
#                                           crew_names           director  \
# 0                  Frank R. Strayer|Richard Flournoy   Frank R. Strayer
# 1  Robert Liebmann|Frederik Fuglsang|Georg Jacoby...       Georg Jacoby
# 2  François Truffaut|François Truffaut|Gérard Bra...  François Truffaut
# 3                                   Derek Westerlund   Derek Westerlund
# 4                                                NaN                NaN
#
#    profit_musd  return_musd  runtime_hours    Franchise
# 0          NaN          NaN            1.0    Franchise
# 1          NaN          NaN            7.0  Stand-alone
# 2          NaN          NaN            1.0  Stand-alone
# 3          NaN          NaN            1.0    Franchise
# 4          NaN          NaN            0.0  Stand-alone

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 578038 entries, 0 to 578037
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   belongs_to_collection  15891 non-null   object
#  1   budget_musd            24889 non-null   float64
#  2   genres                 425057 non-null  object
#  3   id                     578038 non-null  int64
#  4   original_language      578038 non-null  object
#  5   overview               496799 non-null  object
#  6   popularity             578038 non-null  float64
#  7   poster_path            420706 non-null  object
#  8   production_companies   273625 non-null  object
#  9   production_countries   377206 non-null  object
#  10  release_date           556155 non-null  object
#  11  revenue_musd           13603 non-null   float64
#  12  runtime                474092 non-null  float64
#  13  spoken_languages       370286 non-null  object
#  14  tagline                90465 non-null   object
#  15  title                  578038 non-null  object
#  16  vote_average           256163 non-null  float64
#  17  vote_count             578038 non-null  int64
#  18  year                   556155 non-null  float64
#  19  html                   420706 non-null  object
#  20  cast_names             413840 non-null  object
#  21  crew_names             502382 non-null  object
#  22  director               494305 non-null  object
#  23  profit_musd            8952 non-null    float64
#  24  return_musd            8952 non-null    float64
#  25  runtime_hours          474092 non-null  float64
#  26  Franchise              578038 non-null  object
# dtypes: float64(9), int64(2), object(16)
# memory usage: 119.1+ MB

# %% [markdown]
# ## Dropping movies below a vote count threshold

# %%
min_votes = df.vote_count.quantile(0.98)
print(min_votes)
# Out:
# 145.0

# %%
movies = df.copy().loc[:,['id', 'title', 'year', 'vote_average', 'runtime', 'genres', 'cast_names', 'director', 'production_companies', 'overview', 'poster_path', 'html']].copy()
movies = movies.loc[df.vote_count >= min_votes].reset_index(drop=True)
print(f"Shape: {movies.shape}")
movies.head()
# Out:
# Shape: (11574, 12)
#    id                title    year  vote_average  runtime  \
# 0   2                Ariel  1988.0           6.8     73.0
# 1   3  Shadows in Paradise  1986.0           7.2     74.0
# 2   5           Four Rooms  1995.0           5.7     98.0
# 3   6       Judgment Night  1993.0           6.5    110.0
# 4  11            Star Wars  1977.0           8.2    121.0
#
#                              genres  \
# 0                Drama|Crime|Comedy
# 1                      Drama|Comedy
# 2                      Crime|Comedy
# 3             Action|Thriller|Crime
# 4  Adventure|Action|Science Fiction
#
#                                           cast_names         director  \
# 0  Turo Pajala|Susanna Haavisto|Matti Pellonpää|E...   Aki Kaurismäki
# 1  Matti Pellonpää|Kati Outinen|Sakari Kuosmanen|...   Aki Kaurismäki
# 2  Tim Roth|Jennifer Beals|Antonio Banderas|Valer...   Allison Anders
# 3  Emilio Estevez|Cuba Gooding Jr.|Denis Leary|St...  Stephen Hopkins
# 4  Mark Hamill|Harrison Ford|Carrie Fisher|Peter ...     George Lucas
#
#                          production_companies  \
# 0                   Villealfa Filmproductions
# 1                   Villealfa Filmproductions
# 2                        Miramax|A Band Apart
# 3  Universal Pictures|Largo Entertainment|JVC
# 4             Lucasfilm Ltd.|20th Century Fox
#
#                                             overview  \
# 0  Taisto Kasurinen is a Finnish coal miner whose...
# 1  An episode in the life of Nikander, a garbage ...
# 2  It's Ted the Bellhop's first night on the job....
# 3  While racing to a boxing match, Frank, Mike, J...
# 4  Princess Leia is captured and held hostage by ...
#
#                                          poster_path  \
# 0  https://image.tmdb.org/t/p/w500/ojDg0PGvs6R9xY...
# 1  https://image.tmdb.org/t/p/w500/nj01hspawPof0m...
# 2  https://image.tmdb.org/t/p/w500/75aHn1NOYXh4M7...
# 3  https://image.tmdb.org/t/p/w500/rYFAvSPlQUCeba...
# 4  https://image.tmdb.org/t/p/w500/6FfCtAuVAW8XJj...
#
#                                                 html
# 0  <img src='https://image.tmdb.org/t/p/w500/ojDg...
# 1  <img src='https://image.tmdb.org/t/p/w500/nj01...
# 2  <img src='https://image.tmdb.org/t/p/w500/75aH...
# 3  <img src='https://image.tmdb.org/t/p/w500/rYFA...
# 4  <img src='https://image.tmdb.org/t/p/w500/6FfC...

# %%
movies.isnull().sum()
# Out:
# id                        0
# title                     0
# year                      0
# vote_average              0
# runtime                  40
# genres                    6
# cast_names               21
# director                  3
# production_companies    159
# overview                 35
# poster_path               0
# html                      0
# dtype: int64

# %% [markdown]
# ## Removing rows with null values

# %%
movies = movies.dropna().reset_index(drop=True)
print(f"Shape: {movies.shape}")
# Out:
# Shape: (11349, 12)

# %% [markdown]
# ## Creating a "tags" column by concatenating relevant columns

# %%
movies['tags'] = movies.genres + '|' + movies.cast_names + '|' + movies.director + '|' + movies.production_companies
movies['tags'] = movies.tags.apply(lambda x: x.replace(' ', ''))

# %%
movies.tags
# Out:
# 0        Drama|Crime|Comedy|TuroPajala|SusannaHaavisto|...
# 1        Drama|Comedy|MattiPellonpää|KatiOutinen|Sakari...
# 2        Crime|Comedy|TimRoth|JenniferBeals|AntonioBand...
# 3        Action|Thriller|Crime|EmilioEstevez|CubaGoodin...
# 4        Adventure|Action|ScienceFiction|MarkHamill|Har...
#                                ...
# 11344    Animation|Comedy|Family|TomHiddleston|DanCaste...
# 11345    Action|ScienceFiction|Thriller|CourtneyLoggins...
# 11346    Thriller|DavidKross|HannoKoffler|MariaEhrich|R...
# 11347    Documentary|MichaelSchumacher|MickSchumacher|C...
# 11348    Thriller|Drama|Horror|KateSiegel|JasonO'Mara|D...
# Name: tags, Length: 11349, dtype: object

# %% [markdown]
# ## Vectorizing the "tags" column

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
#cv = CountVectorizer(ngram_range=(1,3))
cv = TfidfVectorizer(ngram_range=(1,3))
cv_matrix = cv.fit_transform(movies.tags)
print(f"cv_matrix.shape: {cv_matrix.shape}")
# Out:
# cv_matrix.shape: (11349, 956519)

# %% [markdown]
# ## Creating a cosine similarity matrix

# %%
from sklearn.metrics.pairwise import cosine_similarity
cs_matrix = cosine_similarity(cv_matrix, dense_output=False)#.astype('int16')
print(f"cs_matrix.shape: {cs_matrix.shape}")
# Out:
# cs_matrix.shape: (11349, 11349)

# %% [markdown]
# ## Creating a function that returns the most similar movies based on the title of a movie

# %%
from IPython.display import HTML
# Function that takes in movie title as input and outputs most similar movies
def recommendations(title, cosine_sim=cs_matrix):
    # Get the index of the movie that matches the title
    idx = movies.loc[movies.title == title].index[0]
    # Get the pairwise similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx].toarray()[0]))
    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    # Get the scores of the 10 most similar movies 
    sim_scores = sim_scores[1:11]
    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]
    
    # Return the top 10 most similar movies
    results = movies[['html', 'title']].iloc[movie_indices].set_index(np.arange(1,11)).rename(columns={'html': '', 'title': 'Top 10'})
    return HTML(results.to_html(escape=False))

# %%
recommendations('Star Wars')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Top 10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/2mObg4LWxo4BicFUykGm6oauxHt.jpg' style='height:100px;'></td>
#       <td>The Empire Strikes Back</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/mDCBQNhR6R0PVFucJl0O4Hp5klZ.jpg' style='height:100px;'></td>
#       <td>Return of the Jedi</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/1TY4OAkcHRovlHDxSLW7UDJlild.jpg' style='height:100px;'></td>
#       <td>The Star Wars Holiday Special</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/6wkfovpn7Eq8dYNKaG5PY3q2oq6.jpg' style='height:100px;'></td>
#       <td>Star Wars: Episode I - The Phantom Menace</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/xfSAoBEm9MNBjmlNcDYLvLSMlnq.jpg' style='height:100px;'></td>
#       <td>Star Wars: Episode III - Revenge of the Sith</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/awUGN7ZCNq2EUTdpVaHDX23anOZ.jpg' style='height:100px;'></td>
#       <td>Raiders of the Lost Ark</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/oZNPzxqM2s5DyVWab09NTQScDQt.jpg' style='height:100px;'></td>
#       <td>Star Wars: Episode II - Attack of the Clones</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/axtm6kuubdxaEUWOvv5vJACo8eV.jpg' style='height:100px;'></td>
#       <td>Rollerball</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/jfTpuQGMHinR3dc6mZ5bXq3mTKk.jpg' style='height:100px;'></td>
#       <td>Willow</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/rk2lKgEtjF9HO9N2UFMRc2cMGdj.jpg' style='height:100px;'></td>
#       <td>The Elephant Man</td>
#     </tr>
#   </tbody>
# </table>

# %%
recommendations('Toy Story')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Top 10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/eVGu0zsezaSCuN67zgNhzjeNI9Z.jpg' style='height:100px;'></td>
#       <td>Toy Story 2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/hFamOus53922agTlKxhcL7ngJ9h.jpg' style='height:100px;'></td>
#       <td>A Bug's Life</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/tByW10AkjWG0DtZwN2E2trT88DD.jpg' style='height:100px;'></td>
#       <td>Hawaiian Vacation</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/4cpGytCB0eqvRks4FAlJoUJiFPG.jpg' style='height:100px;'></td>
#       <td>Toy Story 3</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/yRjtvmRXgZoY8P9Ug28G9OITD9E.jpg' style='height:100px;'></td>
#       <td>Tin Toy</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/8siICxMft0JSWZDq9YrXh5U5PZx.jpg' style='height:100px;'></td>
#       <td>Small Fry</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/qa6HCwP4Z15l3hpsASz3auugEW6.jpg' style='height:100px;'></td>
#       <td>Cars</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/bMr9Ir2hCFu2R72pjCA43uRMT4r.jpg' style='height:100px;'></td>
#       <td>The Iron Giant</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/w9kR8qbmQ01HwnvK4alvnQ2ca0L.jpg' style='height:100px;'></td>
#       <td>Toy Story 4</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/3IXeVITL3FJ9CKpBK7lzULuw8Ts.jpg' style='height:100px;'></td>
#       <td>Buzz Lightyear of Star Command: The Adventure Begins</td>
#     </tr>
#   </tbody>
# </table>

# %%
recommendations('Cobra')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Top 10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/yo87I8MxzRf9ZsN6Awc2kM8vGwq.jpg' style='height:100px;'></td>
#       <td>Over the Top</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/jAYOY38TRDprIgu7vgES0FFJJSl.jpg' style='height:100px;'></td>
#       <td>Zorba the Greek</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/kO5o42Nln0Y3syiv46TrE22lJdM.jpg' style='height:100px;'></td>
#       <td>King Solomon's Mines</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/h6ygm9PATqRzxbp4G9M0MpB0Lpk.jpg' style='height:100px;'></td>
#       <td>American Ninja</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/iTknCjGmcVMLCvbAVyhHrFNDP2D.jpg' style='height:100px;'></td>
#       <td>Death Wish 4: The Crackdown</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/p98bF1IPBv3LVdJQqti9KFh46ka.jpg' style='height:100px;'></td>
#       <td>Death Wish II</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/cacSC9ThHlLncJ5qCnvi6U6fv77.jpg' style='height:100px;'></td>
#       <td>The Texas Chainsaw Massacre 2</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/sJNcoyKsqYGEFCCNsYsccikGePV.jpg' style='height:100px;'></td>
#       <td>Leviathan</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/rDY0Zckg9xgAkp0WEay46CwDmCO.jpg' style='height:100px;'></td>
#       <td>American Ninja 2: The Confrontation</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/arJfxShfuZPhqfBZZU6DkPZfnjn.jpg' style='height:100px;'></td>
#       <td>Bullet to the Head</td>
#     </tr>
#   </tbody>
# </table>

# %%
recommendations('The Godfather')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Top 10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg' style='height:100px;'></td>
#       <td>The Godfather: Part II</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/lm3pQ2QoQ16pextRsmnUbG2onES.jpg' style='height:100px;'></td>
#       <td>The Godfather: Part III</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/dhgW1uGaRj8vIgq54VnCP96X7Sv.jpg' style='height:100px;'></td>
#       <td>The Conversation</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/hf3r6PxyZliOxw0SPwEQi1OpHBu.jpg' style='height:100px;'></td>
#       <td>Hearts of Darkness: A Filmmaker's Apocalypse</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/2BWfpISXFso32Aokpmzw0ebaOLA.jpg' style='height:100px;'></td>
#       <td>The Freshman</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/bb9CND0WyfwdHOZY5XmP4Qn8taz.jpg' style='height:100px;'></td>
#       <td>Cruising</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/7A382nJnnS1YFqt19pWy8IDAqhI.jpg' style='height:100px;'></td>
#       <td>The Rainmaker</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/gQB8Y5RCMkv2zwzFHbUJX3kAhvA.jpg' style='height:100px;'></td>
#       <td>Apocalypse Now</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/mavrhr0ig2aCRR8d48yaxtD5aMQ.jpg' style='height:100px;'></td>
#       <td>Dog Day Afternoon</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/5XSGvIKl2yPvOkieFjc3rzLw7x0.jpg' style='height:100px;'></td>
#       <td>The French Connection</td>
#     </tr>
#   </tbody>
# </table>

# %%
recommendations('2001: A Space Odyssey')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Top 10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/4mD3LNkXayoI0q0qxNH5cXtc0em.jpg' style='height:100px;'></td>
#       <td>Fear and Desire</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/mEWKXuCMv7mFMxXVSTI3v8UOQuq.jpg' style='height:100px;'></td>
#       <td>2010</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/57r0TXlqV5GIn4h0Htgh81OZou9.jpg' style='height:100px;'></td>
#       <td>The Man in the Moon</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/x3BOzx2rUc5c3gG9UCelzSxv8n4.jpg' style='height:100px;'></td>
#       <td>The Time Machine</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/h5oXcjRu0EOiAxSxYuGq58897tu.jpg' style='height:100px;'></td>
#       <td>Into the Blue</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/2NTqe5MGx5YAXyQuMvwXSevNHeQ.jpg' style='height:100px;'></td>
#       <td>Untamed Heart</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/lPdCVPf0hkuCJc8mAGPCnHo05Z9.jpg' style='height:100px;'></td>
#       <td>Lolita</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/3iLs534dFCln579aawQW0YWD30s.jpg' style='height:100px;'></td>
#       <td>Zabriskie Point</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/fmpTnUKTcrpuxLSY23gQMUf9qu7.jpg' style='height:100px;'></td>
#       <td>The Haunting</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><img src='https://image.tmdb.org/t/p/w500/pLewUibOJLGISvMqB94mAMdjz2q.jpg' style='height:100px;'></td>
#       <td>Poltergeist III</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Saving the "movies" DataFrame to a csv file

# %%
movies.to_csv('movies_streamlit.csv', index=False)

# %% [markdown]
# ## Saving the cosine similarity matrix to an npz file

# %%
scipy.sparse.save_npz('cs_matrix.npz', cs_matrix)

# %% [markdown]
# ### We have everything we need to create our app and deploy the movie recommendation system.

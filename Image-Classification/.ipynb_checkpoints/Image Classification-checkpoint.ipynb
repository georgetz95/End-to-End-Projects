# %% [markdown]
# # End-to-End Image Classification Model
#
# ## For this project, we will be using a dataset containing 2,057 images of different animal classes and train a Stochastic Gradient Descent Classifier model using HOG extracted features.

# %% [markdown]
# ## Loading the main libraries

# %%
import numpy as np
import pandas as pd
from scipy import stats
from scipy.special import softmax
import matplotlib.pyplot as plt
import seaborn as sns

from  skimage.io import imread, ImageCollection
from skimage.color import rgb2gray, rgba2rgb
from skimage.feature import hog
from skimage.transform import resize

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score, train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, cohen_kappa_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline, make_pipeline


import os
import re
from glob import glob
import pickle
from collections import Counter
import warnings
warnings.filterwarnings('ignore', 
                        'Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.')

# %% [markdown]
# ## Finding all folders containing images and image paths

# %%
folders = os.listdir('data')
print(folders)
# Out:
# ['BearHead', 'CatHead', 'ChickenHead', 'CowHead', 'DeerHead', 'DogHead', 'DuckHead', 'EagleHead', 'ElephantHead', 'HumanHead', 'LionHead', 'MonkeyHead', 'MouseHead', 'Natural', 'PandaHead', 'PigeonHead', 'RabbitHead', 'SheepHead', 'TigerHead', 'WolfHead']

# %%
all_path = []
for folder in folders:
    all_path += glob(f"data/{folder}/*.jpg")

# %%
all_path
# Out:
# ['data/BearHead\\bearfrontal0001.jpg',
#  'data/BearHead\\bearfrontal0002.jpg',
#  'data/BearHead\\bearfrontal0003.jpg',
#  'data/BearHead\\bearfrontal0004.jpg',
#  'data/BearHead\\bearfrontal0005.jpg',
#  'data/BearHead\\bearfrontal0006.jpg',
#  'data/BearHead\\bearfrontal0007.jpg',
#  'data/BearHead\\bearfrontal0008.jpg',
#  'data/BearHead\\bearfrontal0009.jpg',
#  'data/BearHead\\bearfrontal0010.jpg',
#  'data/BearHead\\bearfrontal0011.jpg',
#  'data/BearHead\\bearfrontal0012.jpg',
#  'data/BearHead\\bearfrontal0013.jpg',
#  'data/BearHead\\bearfrontal0014.jpg',
#  'data/BearHead\\bearfrontal0015.jpg',
#  'data/BearHead\\bearfrontal0016.jpg',
#  'data/BearHead\\bearfrontal0017.jpg',
#  'data/BearHead\\bearfrontal0018.jpg',
#  'data/BearHead\\bearfrontal0019.jpg',
#  'data/BearHead\\bearfrontal0020.jpg',
#  'data/BearHead\\bearfrontal0021.jpg',
#  'data/BearHead\\bearfrontal0022.jpg',
#  'data/BearHead\\bearfrontal0023.jpg',
#  'data/BearHead\\bearfrontal0024.jpg',
#  'data/BearHead\\bearfrontal0025.jpg',
#  'data/BearHead\\bearfrontal0026.jpg',
#  'data/BearHead\\bearfrontal0027.jpg',
#  'data/BearHead\\bearfrontal0028.jpg',
#  'data/BearHead\\bearfrontal0029.jpg',
#  'data/BearHead\\bearfrontal0030.jpg',
#  'data/BearHead\\bearfrontal0031.jpg',
#  'data/BearHead\\bearfrontal0032.jpg',
#  'data/BearHead\\bearfrontal0033.jpg',
#  'data/BearHead\\bearfrontal0034.jpg',
#  'data/BearHead\\bearfrontal0035.jpg',
#  'data/BearHead\\bearfrontal0036.jpg',
#  'data/BearHead\\bearfrontal0037.jpg',
#  'data/BearHead\\bearfrontal0038.jpg',
#  'data/BearHead\\bearfrontal0039.jpg',
#  'data/BearHead\\bearfrontal0040.jpg',
#  'data/BearHead\\bearfrontal0041.jpg',
#  'data/BearHead\\bearfrontal0042.jpg',
#  'data/BearHead\\bearfrontal0043.jpg',
#  'data/BearHead\\bearfrontal0044.jpg',
#  'data/BearHead\\bearfrontal0045.jpg',
#  'data/BearHead\\bearfrontal0046.jpg',
#  'data/BearHead\\bearfrontal0047.jpg',
#  'data/BearHead\\bearfrontal0048.jpg',
#  'data/BearHead\\bearfrontal0049.jpg',
#  'data/BearHead\\bearfrontal0050.jpg',
#  'data/BearHead\\bearfrontal0051.jpg',
#  'data/BearHead\\bearfrontal0052.jpg',
#  'data/BearHead\\bearfrontal0053.jpg',
#  'data/BearHead\\bearfrontal0054.jpg',
#  'data/BearHead\\bearfrontal0055.jpg',
#  'data/BearHead\\bearfrontal0056.jpg',
#  'data/BearHead\\bearfrontal0057.jpg',
#  'data/BearHead\\bearfrontal0058.jpg',
#  'data/BearHead\\bearfrontal0059.jpg',
#  'data/BearHead\\bearfrontal0060.jpg',
#  'data/BearHead\\bearfrontal0061.jpg',
#  'data/BearHead\\bearfrontal0062.jpg',
#  'data/BearHead\\bearfrontal0063.jpg',
#  'data/BearHead\\bearfrontal0064.jpg',
#  'data/BearHead\\bearfrontal0065.jpg',
#  'data/BearHead\\bearfrontal0066.jpg',
#  'data/BearHead\\bearfrontal0067.jpg',
#  'data/BearHead\\bearfrontal0068.jpg',
#  'data/BearHead\\bearfrontal0069.jpg',
#  'data/BearHead\\bearfrontal0070.jpg',
#  'data/BearHead\\bearfrontal0071.jpg',
#  'data/BearHead\\bearfrontal0072.jpg',
#  'data/BearHead\\bearfrontal0073.jpg',
#  'data/BearHead\\bearfrontal0074.jpg',
#  'data/BearHead\\bearfrontal0075.jpg',
#  'data/BearHead\\bearfrontal0076.jpg',
#  'data/BearHead\\bearfrontal0077.jpg',
#  'data/BearHead\\bearfrontal0078.jpg',
#  'data/BearHead\\bearfrontal0079.jpg',
#  'data/BearHead\\bearfrontal0080.jpg',
#  'data/BearHead\\bearfrontal0081.jpg',
#  'data/BearHead\\bearfrontal0082.jpg',
#  'data/BearHead\\bearfrontal0083.jpg',
#  'data/BearHead\\bearfrontal0084.jpg',
#  'data/BearHead\\bearfrontal0085.jpg',
#  'data/BearHead\\bearfrontal0086.jpg',
#  'data/BearHead\\bearfrontal0087.jpg',
#  'data/BearHead\\bearfrontal0088.jpg',
#  'data/BearHead\\bearfrontal0089.jpg',
#  'data/BearHead\\bearfrontal0090.jpg',
#  'data/BearHead\\bearfrontal0091.jpg',
#  'data/BearHead\\bearfrontal0092.jpg',
#  'data/BearHead\\bearfrontal0093.jpg',
#  'data/BearHead\\bearfrontal0094.jpg',
#  'data/BearHead\\bearfrontal0095.jpg',
#  'data/BearHead\\bearfrontal0096.jpg',
#  'data/BearHead\\bearfrontal0097.jpg',
#  'data/BearHead\\bearfrontal0098.jpg',
#  'data/BearHead\\bearfrontal0099.jpg',
#  'data/BearHead\\black-bear.jpg',
#  'data/BearHead\\polar-bear-tongue.jpg',
#  'data/CatHead\\cat000852.jpg',
#  'data/CatHead\\cat000908.jpg',
#  'data/CatHead\\cat000929.jpg',
#  'data/CatHead\\cat000960.jpg',
#  'data/CatHead\\cat000967.jpg',
#  'data/CatHead\\cat1004a.jpg',
#  'data/CatHead\\cat1012a.jpg',
#  'data/CatHead\\cat1013a.jpg',
#  'data/CatHead\\cat1015a.jpg',
#  'data/CatHead\\cat1020b.jpg',
#  'data/CatHead\\cat1021a.jpg',
#  'data/CatHead\\cat1022a.jpg',
#  'data/CatHead\\cat1024a.jpg',
#  'data/CatHead\\cat1027a.jpg',
#  'data/CatHead\\cat1031b.jpg',
#  'data/CatHead\\cat1033a.jpg',
#  'data/CatHead\\cat1040a.jpg',
#  'data/CatHead\\cat1051a.jpg',
#  'data/CatHead\\cat1053a.jpg',
#  'data/CatHead\\cat1054a.jpg',
#  'data/CatHead\\cat1057a.jpg',
#  'data/CatHead\\cat1058a.jpg',
#  'data/CatHead\\cat450a.jpg',
#  'data/CatHead\\cat453a.jpg',
#  'data/CatHead\\cat454a.jpg',
#  'data/CatHead\\cat457a.jpg',
#  'data/CatHead\\cat459a.jpg',
#  'data/CatHead\\cat460a.jpg',
#  'data/CatHead\\cat468a.jpg',
#  'data/CatHead\\cat469a.jpg',
#  'data/CatHead\\cat471a.jpg',
#  'data/CatHead\\cat472a.jpg',
#  'data/CatHead\\cat474a.jpg',
#  'data/CatHead\\cat479a.jpg',
#  'data/CatHead\\cat485a.jpg',
#  'data/CatHead\\cat489a.jpg',
#  'data/CatHead\\cat491a.jpg',
#  'data/CatHead\\cat492a.jpg',
#  'data/CatHead\\cat497a.jpg',
#  'data/CatHead\\cat498a.jpg',
#  'data/CatHead\\cat503a.jpg',
#  'data/CatHead\\cat504a.jpg',
#  'data/CatHead\\cat512a.jpg',
#  'data/CatHead\\cat513a.jpg',
#  'data/CatHead\\cat515a.jpg',
#  'data/CatHead\\cat516a.jpg',
#  'data/CatHead\\cat517a.jpg',
#  'data/CatHead\\cat518a.jpg',
#  'data/CatHead\\cat519a.jpg',
#  'data/CatHead\\cat520a.jpg',
#  'data/CatHead\\cat521a.jpg',
#  'data/CatHead\\cat527a.jpg',
#  'data/CatHead\\cat528a.jpg',
#  'data/CatHead\\cat536a.jpg',
#  'data/CatHead\\cat536d.jpg',
#  'data/CatHead\\cat536e.jpg',
#  'data/CatHead\\cat537a.jpg',
#  'data/CatHead\\cat547a.jpg',
#  'data/CatHead\\cat547b.jpg',
#  'data/CatHead\\cat549a.jpg',
#  'data/CatHead\\cat562a.jpg',
#  'data/CatHead\\cat564a.jpg',
#  'data/CatHead\\cat565a.jpg',
#  'data/CatHead\\cat570a.jpg',
#  'data/CatHead\\cat606a.jpg',
#  'data/CatHead\\cat610a.jpg',
#  'data/CatHead\\cat615a.jpg',
#  'data/CatHead\\cat645a.jpg',
#  'data/CatHead\\cat646a.jpg',
#  'data/CatHead\\cat647a.jpg',
#  'data/CatHead\\cat663a.jpg',
#  'data/CatHead\\cat664a.jpg',
#  'data/CatHead\\cat665a.jpg',
#  'data/CatHead\\cat673a.jpg',
#  'data/CatHead\\cat684a.jpg',
#  'data/CatHead\\cat689a.jpg',
#  'data/CatHead\\cat694a.jpg',
#  'data/CatHead\\cat696a.jpg',
#  'data/CatHead\\cat697a.jpg',
#  'data/CatHead\\cat702a.jpg',
#  'data/CatHead\\cat707a.jpg',
#  'data/CatHead\\cat710a.jpg',
#  'data/CatHead\\cat714a.jpg',
#  'data/CatHead\\cat716a.jpg',
#  'data/CatHead\\cat717a.jpg',
#  'data/CatHead\\cat723a.jpg',
#  'data/CatHead\\cat728a.jpg',
#  'data/CatHead\\cat730a.jpg',
#  'data/CatHead\\cat736a.jpg',
#  'data/CatHead\\cat738a..jpg',
#  'data/CatHead\\cat739a.jpg',
#  'data/CatHead\\cat744a.jpg',
#  'data/CatHead\\cat746a.jpg',
#  'data/CatHead\\cat747a.jpg',
#  'data/CatHead\\cat748a.jpg',
#  'data/CatHead\\cat749a.jpg',
#  'data/CatHead\\cat750a.jpg',
#  'data/CatHead\\cat751a.jpg',
#  'data/CatHead\\cat751b.jpg',
#  'data/CatHead\\cat754a.jpg',
#  'data/CatHead\\cat756a.jpg',
#  'data/CatHead\\cat760a.jpg',
#  'data/CatHead\\cat764a.jpg',
#  'data/CatHead\\cat765a.jpg',
#  'data/CatHead\\cat770a.jpg',
#  'data/CatHead\\cat771b.jpg',
#  'data/CatHead\\cat774b.jpg',
#  'data/CatHead\\cat775a.jpg',
#  'data/CatHead\\cat776a.jpg',
#  'data/CatHead\\cat776b.jpg',
#  'data/CatHead\\cat777a.jpg',
#  'data/CatHead\\cat778a.jpg',
#  'data/CatHead\\cat779ajpg.jpg',
#  'data/CatHead\\cat780a.jpg',
#  'data/CatHead\\cat781a.jpg',
#  'data/CatHead\\cat781b.jpg',
#  'data/CatHead\\cat781c.jpg',
#  'data/CatHead\\cat782a.jpg',
#  'data/CatHead\\cat784a.jpg',
#  'data/CatHead\\cat785a.jpg',
#  'data/CatHead\\cat786a.jpg',
#  'data/CatHead\\cat786d.jpg',
#  'data/CatHead\\cat795a.jpg',
#  'data/CatHead\\cat801b.jpg',
#  'data/CatHead\\cat805a.jpg',
#  'data/CatHead\\cat816a.jpg',
#  'data/CatHead\\cat820b.jpg',
#  'data/CatHead\\cat830a.jpg',
#  'data/CatHead\\cat843a.jpg',
#  'data/CatHead\\cat844a.jpg',
#  'data/CatHead\\cat846a.jpg',
#  'data/CatHead\\cat848a.jpg',
#  'data/CatHead\\cat849a.jpg',
#  'data/CatHead\\cat860a.jpg',
#  'data/CatHead\\cat861a.jpg',
#  'data/CatHead\\cat861b.jpg',
#  'data/CatHead\\cat862a.jpg',
#  'data/CatHead\\cat863a.jpg',
#  'data/CatHead\\cat864a.jpg',
#  'data/CatHead\\cat865a.jpg',
#  'data/CatHead\\cat866.jpg',
#  'data/CatHead\\cat869a.jpg',
#  'data/CatHead\\cat872a.jpg',
#  'data/CatHead\\cat873a.jpg',
#  'data/CatHead\\cat878a.jpg',
#  'data/CatHead\\cat879a.jpg',
#  'data/CatHead\\cat886c.jpg',
#  'data/CatHead\\cat893a.jpg',
#  'data/CatHead\\cat893b.jpg',
#  'data/CatHead\\cat913a.jpg',
#  'data/CatHead\\cat924a.jpg',
#  'data/CatHead\\cat931a.jpg',
#  'data/CatHead\\cat958a.jpg',
#  'data/CatHead\\cat965a.jpg',
#  'data/CatHead\\cat985a.jpg',
#  'data/CatHead\\cat986a.jpg',
#  'data/CatHead\\cat990a.jpg',
#  'data/CatHead\\cat992a.jpg',
#  'data/CatHead\\cat995a.jpg',
#  'data/ChickenHead\\chickenside0001.jpg',
#  'data/ChickenHead\\chickenside0002.jpg',
#  'data/ChickenHead\\chickenside0003.jpg',
#  'data/ChickenHead\\chickenside0004.jpg',
#  'data/ChickenHead\\chickenside0005.jpg',
#  'data/ChickenHead\\chickenside0006.jpg',
#  'data/ChickenHead\\chickenside0007.jpg',
#  'data/ChickenHead\\chickenside0008.jpg',
#  'data/ChickenHead\\chickenside0009.jpg',
#  'data/ChickenHead\\chickenside0010.jpg',
#  'data/ChickenHead\\chickenside0011.jpg',
#  'data/ChickenHead\\chickenside0012.jpg',
#  'data/ChickenHead\\chickenside0013.jpg',
#  'data/ChickenHead\\chickenside0014.jpg',
#  'data/ChickenHead\\chickenside0015.jpg',
#  'data/ChickenHead\\chickenside0016.jpg',
#  'data/ChickenHead\\chickenside0017.jpg',
#  'data/ChickenHead\\chickenside0018.jpg',
#  'data/ChickenHead\\chickenside0019.jpg',
#  'data/ChickenHead\\chickenside0020.jpg',
#  'data/ChickenHead\\chickenside0021.jpg',
#  'data/ChickenHead\\chickenside0022.jpg',
#  'data/ChickenHead\\chickenside0023.jpg',
#  'data/ChickenHead\\chickenside0024.jpg',
#  'data/ChickenHead\\chickenside0025.jpg',
#  'data/ChickenHead\\chickenside0026.jpg',
#  'data/ChickenHead\\chickenside0027.jpg',
#  'data/ChickenHead\\chickenside0028.jpg',
#  'data/ChickenHead\\chickenside0029.jpg',
#  'data/ChickenHead\\chickenside0030.jpg',
#  'data/ChickenHead\\chickenside0031.jpg',
#  'data/ChickenHead\\chickenside0032.jpg',
#  'data/ChickenHead\\chickenside0033.jpg',
#  'data/ChickenHead\\chickenside0034.jpg',
#  'data/ChickenHead\\chickenside0035.jpg',
#  'data/ChickenHead\\chickenside0036.jpg',
#  'data/ChickenHead\\chickenside0037.jpg',
#  'data/ChickenHead\\chickenside0038.jpg',
#  'data/ChickenHead\\chickenside0039.jpg',
#  'data/ChickenHead\\chickenside0040.jpg',
#  'data/ChickenHead\\chickenside0041.jpg',
#  'data/ChickenHead\\chickenside0042.jpg',
#  'data/ChickenHead\\chickenside0043.jpg',
#  'data/ChickenHead\\chickenside0044.jpg',
#  'data/ChickenHead\\chickenside0045.jpg',
#  'data/ChickenHead\\chickenside0046.jpg',
#  'data/ChickenHead\\chickenside0047.jpg',
#  'data/ChickenHead\\chickenside0048.jpg',
#  'data/ChickenHead\\chickenside0049.jpg',
#  'data/ChickenHead\\chickenside0050.jpg',
#  'data/ChickenHead\\chickenside0051.jpg',
#  'data/ChickenHead\\chickenside0052.jpg',
#  'data/ChickenHead\\chickenside0053.jpg',
#  'data/ChickenHead\\chickenside0054.jpg',
#  'data/ChickenHead\\chickenside0055.jpg',
#  'data/ChickenHead\\chickenside0056.jpg',
#  'data/ChickenHead\\chickenside0057.jpg',
#  'data/ChickenHead\\chickenside0058.jpg',
#  'data/ChickenHead\\chickenside0059.jpg',
#  'data/ChickenHead\\chickenside0060.jpg',
#  'data/ChickenHead\\chickenside0061.jpg',
#  'data/ChickenHead\\chickenside0062.jpg',
#  'data/ChickenHead\\chickenside0063.jpg',
#  'data/ChickenHead\\chickenside0064.jpg',
#  'data/ChickenHead\\chickenside0065.jpg',
#  'data/ChickenHead\\chickenside0066.jpg',
#  'data/ChickenHead\\chickenside0067.jpg',
#  'data/ChickenHead\\chickenside0068.jpg',
#  'data/ChickenHead\\chickenside0069.jpg',
#  'data/ChickenHead\\chickenside0070.jpg',
#  'data/ChickenHead\\chickenside0071.jpg',
#  'data/ChickenHead\\chickenside0072.jpg',
#  'data/ChickenHead\\chickenside0073.jpg',
#  'data/ChickenHead\\chickenside0074.jpg',
#  'data/ChickenHead\\chickenside0075.jpg',
#  'data/ChickenHead\\chickenside0076.jpg',
#  'data/ChickenHead\\chickenside0077.jpg',
#  'data/ChickenHead\\chickenside0078.jpg',
#  'data/ChickenHead\\chickenside0079.jpg',
#  'data/ChickenHead\\chickenside0080.jpg',
#  'data/ChickenHead\\chickenside0081.jpg',
#  'data/ChickenHead\\chickenside0082.jpg',
#  'data/ChickenHead\\chickenside0083.jpg',
#  'data/ChickenHead\\chickenside0084.jpg',
#  'data/ChickenHead\\chickenside0085.jpg',
#  'data/ChickenHead\\chickenside0086.jpg',
#  'data/ChickenHead\\chickenside0087.jpg',
#  'data/ChickenHead\\chickenside0088.jpg',
#  'data/ChickenHead\\chickenside0089.jpg',
#  'data/ChickenHead\\chickenside0090.jpg',
#  'data/ChickenHead\\chickenside0091.jpg',
#  'data/ChickenHead\\chickenside0092.jpg',
#  'data/ChickenHead\\chickenside0093.jpg',
#  'data/ChickenHead\\chickenside0094.jpg',
#  'data/ChickenHead\\chickenside0095.jpg',
#  'data/ChickenHead\\chickenside0096.jpg',
#  'data/ChickenHead\\chickenside0097.jpg',
#  'data/ChickenHead\\chickenside0098.jpg',
#  'data/ChickenHead\\chickenside0099.jpg',
#  'data/ChickenHead\\chickenside0100.jpg',
#  'data/CowHead\\01_05_21---Cow_web.jpg',
#  'data/CowHead\\050963A.JPG',
#  'data/CowHead\\1-brown-cow-louise-magno.jpg',
#  'data/CowHead\\1846375599_f0190f706a.jpg',
#  'data/CowHead\\542696674_1a7a164508.jpg',
#  'data/CowHead\\73870944qUylUu_fs.jpg',
#  'data/CowHead\\A22A0X.jpg',
#  'data/CowHead\\brown cow 2.jpg',
#  'data/CowHead\\cattlefrontal0001.jpg',
#  'data/CowHead\\cattlefrontal0002.jpg',
#  'data/CowHead\\cattlefrontal0003.jpg',
#  'data/CowHead\\cattlefrontal0004.jpg',
#  'data/CowHead\\cattlefrontal0005.jpg',
#  'data/CowHead\\cattlefrontal0007.jpg',
#  'data/CowHead\\cattlefrontal0010.jpg',
#  'data/CowHead\\cattlefrontal0011.jpg',
#  'data/CowHead\\cattlefrontal0013.jpg',
#  'data/CowHead\\cattlefrontal0014.jpg',
#  'data/CowHead\\cattlefrontal0015.jpg',
#  'data/CowHead\\cattlefrontal0016.jpg',
#  'data/CowHead\\cattlefrontal0017.jpg',
#  'data/CowHead\\cattlefrontal0018.jpg',
#  'data/CowHead\\cattlefrontal0019.jpg',
#  'data/CowHead\\cattlefrontal0020.jpg',
#  'data/CowHead\\cattlefrontal0021.jpg',
#  'data/CowHead\\cattlefrontal0022.jpg',
#  'data/CowHead\\cattlefrontal0023.jpg',
#  'data/CowHead\\cattlefrontal0024.jpg',
#  'data/CowHead\\cattlefrontal0025.jpg',
#  'data/CowHead\\cattlefrontal0027.jpg',
#  'data/CowHead\\cattlefrontal0028.jpg',
#  'data/CowHead\\cattlefrontal0029.jpg',
#  'data/CowHead\\cattlefrontal0031.jpg',
#  'data/CowHead\\cattlefrontal0033.jpg',
#  'data/CowHead\\cattlefrontal0034.jpg',
#  'data/CowHead\\cattlefrontal0035.jpg',
#  'data/CowHead\\cattlefrontal0036.jpg',
#  'data/CowHead\\cattlefrontal0037.jpg',
#  'data/CowHead\\cattlefrontal0039.jpg',
#  'data/CowHead\\cattlefrontal0040.jpg',
#  'data/CowHead\\cattlefrontal0041.jpg',
#  'data/CowHead\\cattlefrontal0043.jpg',
#  'data/CowHead\\cattlefrontal0044.jpg',
#  'data/CowHead\\cattlefrontal0045.jpg',
#  'data/CowHead\\cattlefrontal0046.jpg',
#  'data/CowHead\\cattlefrontal0047.jpg',
#  'data/CowHead\\cattlefrontal0049.jpg',
#  'data/CowHead\\cattlefrontal0051.jpg',
#  'data/CowHead\\cattlefrontal0052.jpg',
#  'data/CowHead\\cattlefrontal0053.jpg',
#  'data/CowHead\\cattlefrontal0054.jpg',
#  'data/CowHead\\cattlefrontal0055.jpg',
#  'data/CowHead\\cattlefrontal0058.jpg',
#  'data/CowHead\\cattlefrontal0059.jpg',
#  'data/CowHead\\cattlefrontal0060.jpg',
#  'data/CowHead\\cattlefrontal0061.jpg',
#  'data/CowHead\\cattlefrontal0062.jpg',
#  'data/CowHead\\cattlefrontal0063.jpg',
#  'data/CowHead\\cattlefrontal0064.jpg',
#  'data/CowHead\\cattlefrontal0065.jpg',
#  'data/CowHead\\cattlefrontal0066.jpg',
#  'data/CowHead\\cattlefrontal0067.jpg',
#  'data/CowHead\\cattlefrontal0068.jpg',
#  'data/CowHead\\cattlefrontal0069.jpg',
#  'data/CowHead\\cattlefrontal0071.jpg',
#  'data/CowHead\\cattlefrontal0072.jpg',
#  'data/CowHead\\cattlefrontal0073.jpg',
#  'data/CowHead\\cattlefrontal0074.jpg',
#  'data/CowHead\\cattlefrontal0075.jpg',
#  'data/CowHead\\cattlefrontal0077.jpg',
#  'data/CowHead\\cattlefrontal0082.jpg',
#  'data/CowHead\\cattlefrontal0084.jpg',
#  'data/CowHead\\cattlefrontal0085.jpg',
#  'data/CowHead\\cattlefrontal0086.jpg',
#  'data/CowHead\\cattlefrontal0087.jpg',
#  'data/CowHead\\cattlefrontal0089.jpg',
#  'data/CowHead\\cattlefrontal0090.jpg',
#  'data/CowHead\\cattlefrontal0091.jpg',
#  'data/CowHead\\cattlefrontal0092.jpg',
#  'data/CowHead\\cattlefrontal0093.jpg',
#  'data/CowHead\\cattlefrontal0094.jpg',
#  'data/CowHead\\cattlefrontal0095.jpg',
#  'data/CowHead\\cattlefrontal0096.jpg',
#  'data/CowHead\\cattlefrontal0097.jpg',
#  'data/CowHead\\cattlefrontal0098.jpg',
#  'data/CowHead\\cattlefrontal0099.jpg',
#  'data/CowHead\\cattlefrontal0100.jpg',
#  'data/CowHead\\cow (1).jpg',
#  'data/CowHead\\COW (2).jpg',
#  'data/CowHead\\cow (3).jpg',
#  'data/CowHead\\Cow 13.jpg',
#  'data/CowHead\\cow-black.jpg',
#  'data/CowHead\\cow-gross-outs.jpg',
#  'data/CowHead\\cow.jpg',
#  'data/CowHead\\cow1.jpg',
#  'data/CowHead\\cows-324x205.jpg',
#  'data/CowHead\\Cow_rt6_web_edited-1.jpg',
#  'data/CowHead\\Cow_With_RFID_Tag.jpg',
#  'data/CowHead\\GSP0001140_P.JPG',
#  'data/CowHead\\Highland_Cow.jpg',
#  'data/CowHead\\k3219916.jpg',
#  'data/CowHead\\pd2197652.jpg',
#  'data/CowHead\\Sussex_cow_4.jpg',
#  'data/DeerHead\\0000000001.jpg',
#  'data/DeerHead\\0000000002.jpg',
#  'data/DeerHead\\0000000003.jpg',
#  'data/DeerHead\\0000000004.jpg',
#  'data/DeerHead\\0000000005.jpg',
#  'data/DeerHead\\0000000006.jpg',
#  'data/DeerHead\\0000000007.jpg',
#  'data/DeerHead\\0000000008.jpg',
#  'data/DeerHead\\0000000009.jpg',
#  'data/DeerHead\\0000000010.jpg',
#  'data/DeerHead\\0000000011.jpg',
#  'data/DeerHead\\0000000012.jpg',
#  'data/DeerHead\\0000000013.jpg',
#  'data/DeerHead\\0000000014.jpg',
#  'data/DeerHead\\0000000015.jpg',
#  'data/DeerHead\\0000000016.jpg',
#  'data/DeerHead\\0000000017.jpg',
#  'data/DeerHead\\0000000018.jpg',
#  'data/DeerHead\\0000000019.jpg',
#  'data/DeerHead\\0000000020.jpg',
#  'data/DeerHead\\0000000021.jpg',
#  'data/DeerHead\\0000000022.jpg',
#  'data/DeerHead\\0000000023.jpg',
#  'data/DeerHead\\0000000024.jpg',
#  'data/DeerHead\\0000000025.jpg',
#  'data/DeerHead\\0000000026.jpg',
#  'data/DeerHead\\0000000027.jpg',
#  'data/DeerHead\\0000000028.jpg',
#  'data/DeerHead\\0000000029.jpg',
#  'data/DeerHead\\0000000030.jpg',
#  'data/DeerHead\\0000000031.jpg',
#  'data/DeerHead\\0000000032.jpg',
#  'data/DeerHead\\0000000033.jpg',
#  'data/DeerHead\\0000000034.jpg',
#  'data/DeerHead\\0000000035.jpg',
#  'data/DeerHead\\0000000036.jpg',
#  'data/DeerHead\\0000000037.jpg',
#  'data/DeerHead\\0000000038.jpg',
#  'data/DeerHead\\0000000039.jpg',
#  'data/DeerHead\\0000000040.jpg',
#  'data/DeerHead\\0000000041.jpg',
#  'data/DeerHead\\0000000042.jpg',
#  'data/DeerHead\\0000000043.jpg',
#  'data/DeerHead\\0000000044.jpg',
#  'data/DeerHead\\0000000045.jpg',
#  'data/DeerHead\\0000000046.jpg',
#  'data/DeerHead\\0000000047.jpg',
#  'data/DeerHead\\0000000048.jpg',
#  'data/DeerHead\\0000000049.jpg',
#  'data/DeerHead\\0000000050.jpg',
#  'data/DeerHead\\0000000051.jpg',
#  'data/DeerHead\\0000000052.jpg',
#  'data/DeerHead\\0000000053.jpg',
#  'data/DeerHead\\0000000054.jpg',
#  'data/DeerHead\\0000000055.jpg',
#  'data/DeerHead\\0000000056.jpg',
#  'data/DeerHead\\0000000057.jpg',
#  'data/DeerHead\\0000000058.jpg',
#  'data/DeerHead\\0000000059.jpg',
#  'data/DeerHead\\0000000060.jpg',
#  'data/DeerHead\\0000000061.jpg',
#  'data/DeerHead\\0000000062.jpg',
#  'data/DeerHead\\09 - deer.jpg',
#  'data/DeerHead\\1862192640_446d2e87a5.jpg',
#  'data/DeerHead\\2_deer.jpg',
#  'data/DeerHead\\3141220334_2684d5fd25_b.jpg',
#  'data/DeerHead\\ALBINO DEER FAWN1.JPG',
#  'data/DeerHead\\antler-development-in-deer.jpg',
#  'data/DeerHead\\deer (1).jpg',
#  'data/DeerHead\\deer (2).jpg',
#  'data/DeerHead\\deer-1206jpg-c9b41862d094e540_large.jpg',
#  'data/DeerHead\\deer-antler-development-02.jpg',
#  'data/DeerHead\\deer-in-grass-web.jpg',
#  'data/DeerHead\\deer.jpg',
#  'data/DeerHead\\Deer01.jpg',
#  'data/DeerHead\\deerBucks5.jpg',
#  'data/DeerHead\\deerEvaLookingIn1.jpg',
#  'data/DeerHead\\deer_5.jpg',
#  'data/DeerHead\\fallow-deer-2516.jpg',
#  'data/DeerHead\\Fallow-Deer-43.jpg',
#  'data/DeerHead\\Fallow-Deer-50.jpg',
#  'data/DeerHead\\Fallow-Deer-55-crop.jpg',
#  'data/DeerHead\\Fallow-Deer-57-crop.jpg',
#  'data/DeerHead\\Fallow-Deer-57-crop2.jpg',
#  'data/DeerHead\\fallow-deer_28354.jpg',
#  'data/DeerHead\\group-of-white-deer-copy.jpg',
#  'data/DeerHead\\large_deer.jpg',
#  'data/DeerHead\\Muntjac-Deer-1.jpg',
#  'data/DeerHead\\Muntjac-Deer-2.jpg',
#  'data/DeerHead\\Muntjac_Deer_cpt_Clare_Gray.JPG',
#  'data/DeerHead\\Red-Deer-54.jpg',
#  'data/DeerHead\\Resting deer.jpg',
#  'data/DeerHead\\Roe-Deer-12-crop.jpg',
#  'data/DeerHead\\unicorn-deer.jpg',
#  'data/DeerHead\\Urban deer by road.jpg',
#  'data/DeerHead\\Urban deer resting.jpg',
#  'data/DeerHead\\Urban deer.jpg',
#  'data/DeerHead\\White-Tailed-Deer 2.jpg',
#  'data/DeerHead\\White-Tailed-Deer-2.jpg',
#  'data/DeerHead\\White-Tailed-Deer.jpg',
#  'data/DeerHead\\whitetail_deer.jpg',
#  'data/DeerHead\\whitetail_deer_lg.jpg',
#  'data/DeerHead\\Young deer.jpg',
#  'data/DogHead\\dog000001c.jpg',
#  'data/DogHead\\dog000002a.jpg',
#  'data/DogHead\\dog000003a.jpg',
#  'data/DogHead\\dog000004a.jpg',
#  'data/DogHead\\dog000006a.jpg',
#  'data/DogHead\\dog000006b.jpg',
#  'data/DogHead\\dog000012a.jpg',
#  'data/DogHead\\dog000013a.jpg',
#  'data/DogHead\\dog000014a.jpg',
#  'data/DogHead\\dog000018a.jpg',
#  'data/DogHead\\dog000019a.jpg',
#  'data/DogHead\\dog000023a.jpg',
#  'data/DogHead\\dog000024a.jpg',
#  'data/DogHead\\dog000027a.jpg',
#  'data/DogHead\\dog000028a.jpg',
#  'data/DogHead\\dog000029a.jpg',
#  'data/DogHead\\dog000030a.jpg',
#  'data/DogHead\\dog000031a.jpg',
#  'data/DogHead\\dog000032a.jpg',
#  'data/DogHead\\dog000033a.jpg',
#  'data/DogHead\\dog000034a.jpg',
#  'data/DogHead\\dog000035a.jpg',
#  'data/DogHead\\dog000036a.jpg',
#  'data/DogHead\\dog000037a.jpg',
#  'data/DogHead\\dog000038a.jpg',
#  'data/DogHead\\dog000038b.jpg',
#  'data/DogHead\\dog000038c.jpg',
#  'data/DogHead\\dog000038d.jpg',
#  'data/DogHead\\dog000039a.jpg',
#  'data/DogHead\\dog000039b.jpg',
#  'data/DogHead\\dog000043a.jpg',
#  'data/DogHead\\dog000044a.jpg',
#  'data/DogHead\\dog000046a.jpg',
#  'data/DogHead\\dog000048a.jpg',
#  'data/DogHead\\dog000049a.jpg',
#  'data/DogHead\\dog000049b.jpg',
#  'data/DogHead\\dog000050a.jpg',
#  'data/DogHead\\dog000052a.jpg',
#  'data/DogHead\\dog000053a.jpg',
#  'data/DogHead\\dog000054a.jpg',
#  'data/DogHead\\dog000055a.jpg',
#  'data/DogHead\\dog000059a.jpg',
#  'data/DogHead\\dog000060a.jpg',
#  'data/DogHead\\dog000063a.jpg',
#  'data/DogHead\\dog000064a.jpg',
#  'data/DogHead\\dog000065a.jpg',
#  'data/DogHead\\dog000068a.jpg',
#  'data/DogHead\\dog000071a.jpg',
#  'data/DogHead\\dog000072a.jpg',
#  'data/DogHead\\dog000073a.jpg',
#  'data/DogHead\\dog000076a.jpg',
#  'data/DogHead\\dog000077a.jpg',
#  'data/DogHead\\dog000079b.jpg',
#  'data/DogHead\\dog000079d.jpg',
#  'data/DogHead\\dog000080a.jpg',
#  'data/DogHead\\dog000082a.jpg',
#  'data/DogHead\\dog000084a.jpg',
#  'data/DogHead\\dog000087b.jpg',
#  'data/DogHead\\dog000088a.jpg',
#  'data/DogHead\\dog000095a.jpg',
#  'data/DogHead\\dog000099a.jpg',
#  'data/DogHead\\dog000100a.jpg',
#  'data/DogHead\\dog000101a.jpg',
#  'data/DogHead\\dog000101b.jpg',
#  'data/DogHead\\dog000103a.jpg',
#  'data/DogHead\\dog000105a.jpg',
#  'data/DogHead\\dog000106a.jpg',
#  'data/DogHead\\dog000107a.jpg',
#  'data/DogHead\\dog000108a.jpg',
#  'data/DogHead\\dog000108b.jpg',
#  'data/DogHead\\dog000108c.jpg',
#  'data/DogHead\\dog000109a.jpg',
#  'data/DogHead\\dog000110a.jpg',
#  'data/DogHead\\dog000111a.jpg',
#  'data/DogHead\\dog000114a.jpg',
#  'data/DogHead\\dog000114b.jpg',
#  'data/DogHead\\dog000118a.jpg',
#  'data/DogHead\\dog000120a.jpg',
#  'data/DogHead\\dog000121a.jpg',
#  'data/DogHead\\dog000121c.jpg',
#  'data/DogHead\\dog000129a.jpg',
#  'data/DogHead\\dog000133a.jpg',
#  'data/DogHead\\dog000133c.jpg',
#  'data/DogHead\\dog000136a.jpg',
#  'data/DogHead\\dog000137a.jpg',
#  'data/DogHead\\dog000138a.jpg',
#  'data/DogHead\\dog000140a.jpg',
#  'data/DogHead\\dog000141a.jpg',
#  'data/DogHead\\dog000143a.jpg',
#  'data/DogHead\\dog000149a.jpg',
#  'data/DogHead\\dog000150a.jpg',
#  'data/DogHead\\dog000150b.jpg',
#  'data/DogHead\\dog000155a.jpg',
#  'data/DogHead\\dog000157a.jpg',
#  'data/DogHead\\dog000158a.jpg',
#  'data/DogHead\\dog000158b.jpg',
#  'data/DogHead\\dog000159b.jpg',
#  'data/DogHead\\dog000161a.jpg',
#  'data/DogHead\\dog000162a.jpg',
#  'data/DogHead\\dog000166a.jpg',
#  'data/DogHead\\dog000171a.jpg',
#  'data/DogHead\\dog000175a.jpg',
#  'data/DogHead\\dog000176a.jpg',
#  'data/DogHead\\dog000177a.jpg',
#  'data/DogHead\\dog000178b.jpg',
#  'data/DogHead\\dog000178c.jpg',
#  'data/DogHead\\dog000178f.jpg',
#  'data/DogHead\\dog000179a.jpg',
#  'data/DogHead\\dog000183a.jpg',
#  'data/DogHead\\dog000185a.jpg',
#  'data/DogHead\\dog000187a.jpg',
#  'data/DogHead\\dog000190a.jpg',
#  'data/DogHead\\dog000191a.jpg',
#  'data/DogHead\\dog000192a.jpg',
#  'data/DogHead\\dog000201a.jpg',
#  'data/DogHead\\dog000201b.jpg',
#  'data/DogHead\\dog000201c.jpg',
#  'data/DogHead\\dog000201d.jpg',
#  'data/DogHead\\dog000203a.jpg',
#  'data/DogHead\\dog000204a.jpg',
#  'data/DogHead\\dog000206a.jpg',
#  'data/DogHead\\dog000208a.jpg',
#  'data/DogHead\\dog000210a.jpg',
#  'data/DogHead\\dog000211a.jpg',
#  'data/DogHead\\dog000213a.jpg',
#  'data/DogHead\\dog000215a.jpg',
#  'data/DogHead\\dog000218a.jpg',
#  'data/DogHead\\dog000219a.jpg',
#  'data/DogHead\\dog000225a.jpg',
#  'data/DogHead\\dog000232a.jpg',
#  'data/DogHead\\dog000234a.jpg',
#  'data/DogHead\\dog000235a.jpg',
#  'data/DuckHead\\01_08_18---Duck_web.jpg',
#  'data/DuckHead\\duck-02.jpg',
#  'data/DuckHead\\Duck.jpg',
#  'data/DuckHead\\duck5.jpg',
#  'data/DuckHead\\ducks1.jpg',
#  'data/DuckHead\\ducks2.jpg',
#  'data/DuckHead\\ducks3.jpg',
#  'data/DuckHead\\duckside0001.jpg',
#  'data/DuckHead\\duckside0002.jpg',
#  'data/DuckHead\\duckside0003.jpg',
#  'data/DuckHead\\duckside0004.jpg',
#  'data/DuckHead\\duckside0005.jpg',
#  'data/DuckHead\\duckside0006.jpg',
#  'data/DuckHead\\duckside0009.jpg',
#  'data/DuckHead\\duckside0010.jpg',
#  'data/DuckHead\\duckside0011.jpg',
#  'data/DuckHead\\duckside0012.jpg',
#  'data/DuckHead\\duckside0013.jpg',
#  'data/DuckHead\\duckside0014.jpg',
#  'data/DuckHead\\duckside0015.jpg',
#  'data/DuckHead\\duckside0016.jpg',
#  'data/DuckHead\\duckside0017.jpg',
#  'data/DuckHead\\duckside0018.jpg',
#  'data/DuckHead\\duckside0019.jpg',
#  'data/DuckHead\\duckside0020.jpg',
#  'data/DuckHead\\duckside0021.jpg',
#  'data/DuckHead\\duckside0024.jpg',
#  'data/DuckHead\\duckside0025.jpg',
#  'data/DuckHead\\duckside0026.jpg',
#  'data/DuckHead\\duckside0029.jpg',
#  'data/DuckHead\\duckside0030.jpg',
#  'data/DuckHead\\duckside0031.jpg',
#  'data/DuckHead\\duckside0032.jpg',
#  'data/DuckHead\\duckside0033.jpg',
#  'data/DuckHead\\duckside0034.jpg',
#  'data/DuckHead\\duckside0035.jpg',
#  'data/DuckHead\\duckside0036.jpg',
#  'data/DuckHead\\duckside0037.jpg',
#  'data/DuckHead\\duckside0038.jpg',
#  'data/DuckHead\\duckside0039.jpg',
#  'data/DuckHead\\duckside0040.jpg',
#  'data/DuckHead\\duckside0041.jpg',
#  'data/DuckHead\\duckside0042.jpg',
#  'data/DuckHead\\duckside0043.jpg',
#  'data/DuckHead\\duckside0044.jpg',
#  'data/DuckHead\\duckside0045.jpg',
#  'data/DuckHead\\duckside0046.jpg',
#  'data/DuckHead\\duckside0047.jpg',
#  'data/DuckHead\\duckside0048.jpg',
#  'data/DuckHead\\duckside0049.jpg',
#  'data/DuckHead\\duckside0050.jpg',
#  'data/DuckHead\\duckside0051.jpg',
#  'data/DuckHead\\duckside0052.jpg',
#  'data/DuckHead\\duckside0053.jpg',
#  'data/DuckHead\\duckside0054.jpg',
#  'data/DuckHead\\duckside0055.jpg',
#  'data/DuckHead\\duckside0056.jpg',
#  'data/DuckHead\\duckside0057.jpg',
#  'data/DuckHead\\duckside0058.jpg',
#  'data/DuckHead\\duckside0059.jpg',
#  'data/DuckHead\\duckside0060.jpg',
#  'data/DuckHead\\duckside0061.jpg',
#  'data/DuckHead\\duckside0062.jpg',
#  'data/DuckHead\\duckside0063.jpg',
#  'data/DuckHead\\duckside0064.jpg',
#  'data/DuckHead\\duckside0066.jpg',
#  'data/DuckHead\\duckside0067.jpg',
#  'data/DuckHead\\duckside0069.jpg',
#  'data/DuckHead\\duckside0070.jpg',
#  'data/DuckHead\\duckside0071.jpg',
#  'data/DuckHead\\duckside0072.jpg',
#  'data/DuckHead\\duckside0073.jpg',
#  'data/DuckHead\\duckside0074.jpg',
#  'data/DuckHead\\duckside0075.jpg',
#  'data/DuckHead\\duckside0076.jpg',
#  'data/DuckHead\\duckside0077.jpg',
#  'data/DuckHead\\duckside0078.jpg',
#  'data/DuckHead\\duckside0080.jpg',
#  'data/DuckHead\\duckside0081.jpg',
#  'data/DuckHead\\duckside0083.jpg',
#  'data/DuckHead\\duckside0084.jpg',
#  'data/DuckHead\\duckside0085.jpg',
#  'data/DuckHead\\duckside0087.jpg',
#  'data/DuckHead\\duckside0088.jpg',
#  'data/DuckHead\\duckside0089.jpg',
#  'data/DuckHead\\duckside0090.jpg',
#  'data/DuckHead\\duckside0091.jpg',
#  'data/DuckHead\\duckside0092.jpg',
#  'data/DuckHead\\duckside0093.jpg',
#  'data/DuckHead\\duckside0094.jpg',
#  'data/DuckHead\\duckside0095.jpg',
#  'data/DuckHead\\duckside0096.jpg',
#  'data/DuckHead\\duckside0097.jpg',
#  'data/DuckHead\\duckside0098.jpg',
#  'data/DuckHead\\duckside0099.jpg',
#  'data/DuckHead\\duckside0100.jpg',
#  'data/DuckHead\\Duck_head.JPG',
#  'data/DuckHead\\fulvous-whistling-duck.jpg',
#  'data/DuckHead\\fulvous_whistling_duck-2.jpg',
#  'data/DuckHead\\Knobbilled Duck 268010.jpg',
#  'data/DuckHead\\LongTailedDuck.jpg',
#  'data/DuckHead\\LongTailedDuck2.jpg',
#  'data/DuckHead\\Yellowbilled Duck 268012.jpg',
#  'data/EagleHead\\040305-098..jpg',
#  'data/EagleHead\\06eagle00.jpg',
#  'data/EagleHead\\3169423808_37abc30470.jpg',
#  'data/EagleHead\\3187888843_1ec507fe17.jpg',
#  'data/EagleHead\\320-golden-eagle-c3648.jpg',
#  'data/EagleHead\\3218816697_a707f90e8e.jpg',
#  'data/EagleHead\\3242107126_65347ffea0.jpg',
#  'data/EagleHead\\3419031818_b646e7089d.jpg',
#  'data/EagleHead\\3754929724_dd9b748e59.jpg',
#  'data/EagleHead\\393291573_a11aabb7fd.jpg',
#  'data/EagleHead\\4376095748_cabe4d2596.jpg',
#  'data/EagleHead\\4380084217_ed0a4c8499.jpg',
#  'data/EagleHead\\5456eagle.jpg',
#  'data/EagleHead\\714eagle.jpg',
#  'data/EagleHead\\african_fish_eagle_1.jpg',
#  'data/EagleHead\\bald-eagle-good-catch.jpg',
#  'data/EagleHead\\bald-eagle-perching3.jpg',
#  'data/EagleHead\\bald-eagle-timothywolcott.jpg',
#  'data/EagleHead\\bald-eagle-wings-soar.jpg',
#  'data/EagleHead\\BaldEagle.jpg',
#  'data/EagleHead\\BaldEagle_LillianStokes.jpg',
#  'data/EagleHead\\bald_eagle-0.jpg',
#  'data/EagleHead\\bald_eagle.jpg',
#  'data/EagleHead\\Bald_Eagle_42041_small.jpg',
#  'data/EagleHead\\Bald_Eagle_42042_small.jpg',
#  'data/EagleHead\\Bald_Eagle_471021_small.jpg',
#  'data/EagleHead\\bald_eagle_fly.jpg',
#  'data/EagleHead\\Bald_Eagle_Landing-1280x1024.jpg',
#  'data/EagleHead\\b_philippine_eagle_2.jpg.jpg',
#  'data/EagleHead\\eagle (1).jpg',
#  'data/EagleHead\\eagle (2).jpg',
#  'data/EagleHead\\EAGLE (3).JPG',
#  'data/EagleHead\\eagle-beak.jpg',
#  'data/EagleHead\\Eagle-pesticide-pardon.JPG',
#  'data/EagleHead\\eagle005.jpg',
#  'data/EagleHead\\eagle034.jpg',
#  'data/EagleHead\\eagle037flipped.jpg',
#  'data/EagleHead\\eagle038.jpg',
#  'data/EagleHead\\eagle040.jpg',
#  'data/EagleHead\\eagle09_0727.jpg',
#  'data/EagleHead\\eagle09_1790.jpg',
#  'data/EagleHead\\eagle09_1834.jpg',
#  'data/EagleHead\\eagle09_2001.jpg',
#  'data/EagleHead\\eagle09_2138.jpg',
#  'data/EagleHead\\eagle1024x768_009.jpg',
#  'data/EagleHead\\eagle1024x768_022.jpg',
#  'data/EagleHead\\eagle1024x768_024.jpg',
#  'data/EagleHead\\eagle1024x768_067.jpg',
#  'data/EagleHead\\eagle14_Photograph.108195404_large.jpg',
#  'data/EagleHead\\Eagle1_Photograph.108195648_large.jpg',
#  'data/EagleHead\\eagle2.jpg',
#  'data/EagleHead\\eagle248-2004-12-15-10-31-566137.jpg',
#  'data/EagleHead\\eagle248-2004-12-15-10-31-577419flipped.jpg',
#  'data/EagleHead\\eagle248-2004-12-15-10-31-597786.jpg',
#  'data/EagleHead\\eagle248-2004-12-15-10-32-003328.jpg',
#  'data/EagleHead\\eagle81629233_2978fe5e96flipped.jpg',
#  'data/EagleHead\\eaglebald_eagle_02tkflipped.jpg',
#  'data/EagleHead\\eaglebald_eagle_06tkflipped.jpg',
#  'data/EagleHead\\eaglebeak.jpg',
#  'data/EagleHead\\eagleb_200482017054515flipped.jpg',
#  'data/EagleHead\\eagleb_200482017103011flipped.jpg',
#  'data/EagleHead\\eagleB_IQWOTURE.jpg',
#  'data/EagleHead\\eagleB_QWYTUYP.jpg',
#  'data/EagleHead\\eagleB_TPTYTUUY.jpg',
#  'data/EagleHead\\eagleB_TRPTTUUT.jpg',
#  'data/EagleHead\\eagleB_WUIUTUYUflipped.jpg',
#  'data/EagleHead\\eagles_F76T7901.jpg',
#  'data/EagleHead\\eagles_have_landed.jpg',
#  'data/EagleHead\\eagle_ perched.jpg',
#  'data/EagleHead\\eagle_B7B7149.JPG',
#  'data/EagleHead\\eagle_B7B8015.JPG',
#  'data/EagleHead\\eagle_Head_Shotflipped.jpg',
#  'data/EagleHead\\Eagle_Photo_for_zazzle.10693731_large.jpg',
#  'data/EagleHead\\eagle_usfws380.jpg',
#  'data/EagleHead\\eagle_with_sushi.jpg',
#  'data/EagleHead\\endangered-bald-eagle-100.jpg',
#  'data/EagleHead\\fish-eagle_abop-0132.jpg',
#  'data/EagleHead\\fish-eagle_knp-7590.jpg',
#  'data/EagleHead\\fish-eagle_santa-4425.jpg',
#  'data/EagleHead\\fishing-bald-eagle-114.jpg',
#  'data/EagleHead\\Golden Eagle (1).jpg',
#  'data/EagleHead\\Golden Eagle.jpg',
#  'data/EagleHead\\golden-eagle-2524.jpg',
#  'data/EagleHead\\golden-eagle1.jpg',
#  'data/EagleHead\\golden_eagle (1).jpg',
#  'data/EagleHead\\golden_eagle-0.jpg',
#  'data/EagleHead\\golden_eagle.jpg',
#  'data/EagleHead\\grizzly_bear_and_bald_eagle-1280x10243.jpg',
#  'data/EagleHead\\homer-eagles-3488-1.jpg',
#  'data/EagleHead\\j0178767.jpg',
#  'data/EagleHead\\JuvenileSouthernBaldEagle.jpg',
#  'data/EagleHead\\Kanopolis-Bald-Eagle_imagelarge.jpg',
#  'data/EagleHead\\magnificent-eagle-01.jpg',
#  'data/EagleHead\\male_eagle.jpg',
#  'data/EagleHead\\Sea Eagle.jpg',
#  'data/EagleHead\\steller-sea-eagle_724_600x450.jpg',
#  'data/EagleHead\\steppe-eagle-1878.jpg',
#  'data/EagleHead\\White-tailed Eagle0071.jpg',
#  'data/EagleHead\\White-tailed-eagle-plunging-for-fish.jpg',
#  'data/EagleHead\\white-tailed_eagle_1.jpg',
#  'data/ElephantHead\\0000000001.jpg',
#  'data/ElephantHead\\0000000002.jpg',
#  'data/ElephantHead\\0000000003.jpg',
#  'data/ElephantHead\\0000000004.jpg',
#  'data/ElephantHead\\0000000005.jpg',
#  'data/ElephantHead\\0000000006.jpg',
#  'data/ElephantHead\\0000000007.jpg',
#  'data/ElephantHead\\0000000008.jpg',
#  'data/ElephantHead\\0000000009.jpg',
#  'data/ElephantHead\\0000000010.jpg',
#  'data/ElephantHead\\0000000011.jpg',
#  'data/ElephantHead\\0000000012.jpg',
#  'data/ElephantHead\\0000000013.jpg',
#  'data/ElephantHead\\0000000014.jpg',
#  'data/ElephantHead\\0000000015.jpg',
#  'data/ElephantHead\\0000000016.jpg',
#  'data/ElephantHead\\0000000017.jpg',
#  'data/ElephantHead\\0000000018.jpg',
#  'data/ElephantHead\\0000000019.jpg',
#  'data/ElephantHead\\0000000020.jpg',
#  'data/ElephantHead\\0000000021.jpg',
#  'data/ElephantHead\\0000000022.jpg',
#  'data/ElephantHead\\0000000023.jpg',
#  'data/ElephantHead\\0000000024.jpg',
#  'data/ElephantHead\\0000000025.jpg',
#  'data/ElephantHead\\0000000026.jpg',
#  'data/ElephantHead\\0000000027.jpg',
#  'data/ElephantHead\\0000000028.jpg',
#  'data/ElephantHead\\0000000029.jpg',
#  'data/ElephantHead\\0000000030.jpg',
#  'data/ElephantHead\\0000000031.jpg',
#  'data/ElephantHead\\0000000032.jpg',
#  'data/ElephantHead\\0000000033.jpg',
#  'data/ElephantHead\\0000000034.jpg',
#  'data/ElephantHead\\0000000035.jpg',
#  'data/ElephantHead\\0000000036.jpg',
#  'data/ElephantHead\\0000000037.jpg',
#  'data/ElephantHead\\0000000038.jpg',
#  'data/ElephantHead\\0000000039.jpg',
#  'data/ElephantHead\\0000000040.jpg',
#  'data/ElephantHead\\0000000041.jpg',
#  'data/ElephantHead\\0000000042.jpg',
#  'data/ElephantHead\\0000000043.jpg',
#  'data/ElephantHead\\0000000044.jpg',
#  'data/ElephantHead\\0000000045.jpg',
#  'data/ElephantHead\\0000000046.jpg',
#  'data/ElephantHead\\0000000047.jpg',
#  'data/ElephantHead\\0000000048.jpg',
#  'data/ElephantHead\\0000000049.jpg',
#  'data/ElephantHead\\0000000050.jpg',
#  'data/ElephantHead\\0000000051.jpg',
#  'data/ElephantHead\\0000000052.jpg',
#  'data/ElephantHead\\0000000053.jpg',
#  'data/ElephantHead\\0000000054.jpg',
#  'data/ElephantHead\\0000000055.jpg',
#  'data/ElephantHead\\0000000056.jpg',
#  'data/ElephantHead\\0000000057.jpg',
#  'data/ElephantHead\\0000000058.jpg',
#  'data/ElephantHead\\0000000059.jpg',
#  'data/ElephantHead\\0000000060.jpg',
#  'data/ElephantHead\\0000000061.jpg',
#  'data/ElephantHead\\0000000062.jpg',
#  'data/ElephantHead\\0000000063.jpg',
#  'data/ElephantHead\\0000000064.jpg',
#  'data/ElephantHead\\0000000065.jpg',
#  'data/ElephantHead\\0000000066.jpg',
#  'data/ElephantHead\\0000000067.jpg',
#  'data/ElephantHead\\0000000068.jpg',
#  'data/ElephantHead\\0000000069.jpg',
#  'data/ElephantHead\\0000000070.jpg',
#  'data/ElephantHead\\0000000071.jpg',
#  'data/ElephantHead\\0000000072.jpg',
#  'data/ElephantHead\\0000000073.jpg',
#  'data/ElephantHead\\0000000074.jpg',
#  'data/ElephantHead\\0000000075.jpg',
#  'data/ElephantHead\\0000000076.jpg',
#  'data/ElephantHead\\0000000077.jpg',
#  'data/ElephantHead\\0000000078.jpg',
#  'data/ElephantHead\\0000000079.jpg',
#  'data/ElephantHead\\0000000080.jpg',
#  'data/ElephantHead\\0000000081.jpg',
#  'data/ElephantHead\\0000000082.jpg',
#  'data/ElephantHead\\0000000083.jpg',
#  'data/ElephantHead\\0000000084.jpg',
#  'data/ElephantHead\\0000000085.jpg',
#  'data/ElephantHead\\0000000086.jpg',
#  'data/ElephantHead\\0000000087.jpg',
#  'data/ElephantHead\\0000000088.jpg',
#  'data/ElephantHead\\0000000089.jpg',
#  'data/ElephantHead\\0000000090.jpg',
#  'data/ElephantHead\\0000000091.jpg',
#  'data/ElephantHead\\0000000092.jpg',
#  'data/ElephantHead\\0000000093.jpg',
#  'data/ElephantHead\\0000000094.jpg',
#  'data/ElephantHead\\0000000095.jpg',
#  'data/ElephantHead\\0000000096.jpg',
#  'data/ElephantHead\\0000000097.jpg',
#  'data/ElephantHead\\0000000098.jpg',
#  'data/ElephantHead\\0000000099.jpg',
#  ...]

# %%
img_all = ImageCollection(all_path)
len(img_all)
# Out:
# 2057

# %% [markdown]
# ## Labeling all images

# %%
def extract_label(text):
    try:
        label = re.search(r'data/(.*?)Head\\', text).group(1)
    except:
        label = re.search(r'data/(.*?)\\', text).group(1)
    return label

# %%
labels = list(map(extract_label, img_all.files))
print(len(labels))
print(labels)
# Out:
# 2057
# ['Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Bear', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Chicken', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Cow', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', 'Deer', ' ...

# %%
pd.Series(labels).unique()
# Out:
# array(['Bear', 'Cat', 'Chicken', 'Cow', 'Deer', 'Dog', 'Duck', 'Eagle',
#        'Elephant', 'Human', 'Lion', 'Monkey', 'Mouse', 'Natural', 'Panda',
#        'Pigeon', 'Rabbit', 'Sheep', 'Tiger', 'Wolf'], dtype=object)

# %% [markdown]
# ## Combining all images into one array

# %%
def buffer(io):
    return io

img_all_arrs = np.array(list(map(buffer, img_all)))
img_all_arrs.shape
# Out:
# (2057, 80, 80, 3)

# %% [markdown]
# ## Creating a dataset dictionary

# %%
data = dict()
data['description'] = 'There are 20 classes and 2,057 total images with shape of (80,80,3) each.'
data['data'] = img_all_arrs
data['target'] = labels
data['labels'] = set(labels)
data
# Out:
# {'description': 'There are 20 classes and 2,057 total images with shape of (80,80,3) each.',
#  'data': array([[[[196, 214, 188],
#           [196, 214, 188],
#           [196, 214, 188],
#           ...,
#           [ 81,  76,  80],
#           [ 81,  76,  80],
#           [ 69,  64,  68]],
#
#          [[196, 214, 188],
#           [196, 214, 188],
#           [196, 215, 187],
#           ...,
#           [ 82,  77,  81],
#           [ 83,  78,  82],
#           [ 77,  72,  76]],
#
#          [[193, 213, 185],
#           [194, 214, 186],
#           [194, 214, 186],
#           ...,
#           [ 82,  77,  81],
#           [ 81,  76,  80],
#           [ 78,  73,  77]],
#
#          ...,
#
#          [[254, 254, 254],
#           [254, 254, 254],
#           [254, 254, 254],
#           ...,
#           [ 70,  65,  69],
#           [ 65,  60,  64],
#           [ 62,  57,  63]],
#
#          [[254, 254, 254],
#           [254, 254, 254],
#           [254, 254, 254],
#           ...,
#           [ 66,  61,  65],
#           [ 62,  57,  61],
#           [ 64,  59,  65]],
#
#          [[254, 254, 254],
#           [254, 254, 254],
#           [254, 254, 254],
#           ...,
#           [ 56,  51,  55],
#           [ 79,  74,  78],
#           [ 70,  63,  70]]],
#
#
#         [[[  4,   2,   3],
#           [  7,   5,   6],
#           [  6,   5,   3],
#           ...,
#           [ 42,  31,  25],
#           [ 46,  35,  29],
#           [ 45,  32,  26]],
#
#          [[  7,   5,   6],
#           [  5,   4,   2],
#           [  2,   1,   0],
#           ...,
#           [ 22,  11,   5],
#           [ 43,  32,  26],
#           [ 47,  36,  30]],
#
#          [[  6,   5,   3],
#           [  3,   2,   0],
#           [  2,   1,   0],
#           ...,
#           [ 33,  24,  17],
#           [ 48,  39,  32],
#           [ 54,  45,  38]],
#
#          ...,
#
#          [[ 24,  29,   6],
#           [ 24,  30,   4],
#           [ 25,  31,   5],
#           ...,
#           [116, 116,  80],
#           [115, 117,  80],
#           [127, 129,  92]],
#
#          [[ 22,  27,   4],
#           [ 23,  28,   5],
#           [ 24,  29,   6],
#           ...,
#           [112, 112,  76],
#           [115, 117,  80],
#           [128, 130,  93]],
#
#          [[ 22,  27,   5],
#           [ 22,  27,   4],
#           [ 22,  27,   4],
#           ...,
#           [106, 106,  70],
#           [112, 114,  77],
#           [126, 128,  91]]],
#
#
#         [[[104, 109, 102],
#           [104, 111, 103],
#           [108, 115, 107],
#           ...,
#           [130, 126, 127],
#           [122, 117, 121],
#           [123, 118, 122]],
#
#          [[113, 118, 111],
#           [ 97, 104,  96],
#           [103, 110, 102],
#           ...,
#           [111, 107, 108],
#           [129, 124, 128],
#           [150, 145, 149]],
#
#          [[126, 133, 125],
#           [112, 119, 111],
#           [110, 117, 109],
#           ...,
#           [139, 135, 136],
#           [162, 157, 161],
#           [163, 158, 162]],
#
#          ...,
#
#          [[214, 214, 202],
#           [206, 206, 194],
#           [202, 200, 187],
#           ...,
#           [164, 162, 150],
#           [173, 173, 163],
#           [187, 187, 179]],
#
#          [[219, 219, 207],
#           [210, 210, 198],
#           [205, 203, 190],
#           ...,
#           [170, 168, 156],
#           [174, 174, 164],
#           [188, 188, 180]],
#
#          [[214, 214, 202],
#           [201, 201, 189],
#           [198, 196, 183],
#           ...,
#           [172, 170, 158],
#           [179, 179, 169],
#           [184, 184, 176]]],
#
#
#         ...,
#
#
#         [[[147, 154, 113],
#           [145, 152, 111],
#           [146, 153, 112],
#           ...,
#           [102, 109,  58],
#           [118, 121,  74],
#           [128, 131,  86]],
#
#          [[148, 155, 114],
#           [146, 153, 112],
#           [145, 152, 111],
#           ...,
#           [120, 128,  71],
#           [138, 142,  91],
#           [151, 155, 105]],
#
#          [[147, 154, 112],
#           [146, 153, 111],
#           [144, 151, 109],
#           ...,
#           [136, 142,  80],
#           [143, 151,  91],
#           [150, 158,  99]],
#
#          ...,
#
#          [[137, 142,  88],
#           [146, 150,  99],
#           [145, 148, 101],
#           ...,
#           [143, 138, 100],
#           [148, 143, 103],
#           [158, 150, 111]],
#
#          [[133, 138,  82],
#           [128, 133,  79],
#           [129, 133,  83],
#           ...,
#           [158, 153, 115],
#           [157, 152, 112],
#           [154, 149, 109]],
#
#          [[130, 135,  79],
#           [128, 133,  79],
#           [135, 139,  88],
#           ...,
#           [160, 155, 115],
#           [157, 152, 112],
#           [150, 145, 105]]],
#
#
#         [[[246, 250, 249],
#           [247, 251, 250],
#           [252, 254, 253],
#           ...,
#           [136, 118, 114],
#           [143, 124, 118],
#           [145, 126, 120]],
#
#          [[244, 248, 247],
#           [252, 255, 255],
#           [243, 245, 244],
#           ...,
#           [139, 124, 117],
#           [135, 120, 113],
#           [156, 141, 134]],
#
#          [[238, 242, 241],
#           [248, 252, 251],
#           [246, 248, 247],
#           ...,
#           [128, 118, 109],
#           [128, 118, 109],
#           [141, 131, 122]],
#
#          ...,
#
#          [[236, 233, 224],
#           [230, 226, 217],
#           [228, 224, 215],
#           ...,
#           [159, 142, 126],
#           [152, 135, 119],
#           [150, 133, 117]],
#
#          [[234, 231, 222],
#           [233, 230, 221],
#           [229, 225, 216],
#           ...,
#           [185, 169, 154],
#           [165, 149, 134],
#           [169, 153, 138]],
#
#          [[242, 239, 232],
#           [236, 233, 224],
#           [229, 225, 216],
#           ...,
#           [193, 177, 162],
#           [185, 169, 154],
#           [175, 159, 144]]],
#
#
#         [[[ 85,  78,  32],
#           [ 79,  72,  26],
#           [ 79,  72,  26],
#           ...,
#           [ 80,  73,  27],
#           [ 76,  69,  23],
#           [ 74,  67,  21]],
#
#          [[ 82,  78,  31],
#           [ 79,  72,  26],
#           [ 78,  71,  25],
#           ...,
#           [ 78,  71,  25],
#           [ 75,  68,  24],
#           [ 71,  64,  20]],
#
#          [[ 81,  77,  30],
#           [ 80,  73,  27],
#           [ 77,  70,  24],
#           ...,
#           [ 78,  71,  27],
#           [ 76,  69,  25],
#           [ 71,  64,  20]],
#
#          ...,
#
#          [[ 85,  55,  17],
#           [ 92,  60,  22],
#           [ 90,  58,  20],
#           ...,
#           [103, 101,  53],
#           [ 99,  97,  49],
#           [ 96,  94,  46]],
#
#          [[ 87,  57,  19],
#           [ 82,  50,  11],
#           [ 88,  56,  17],
#           ...,
#           [104, 100,  53],
#           [101,  97,  50],
#           [ 98,  94,  47]],
#
#          [[ 82,  53,  13],
#           [ 83,  51,  12],
#           [ 92,  60,  21],
#           ...,
#           [101,  94,  48],
#           [100,  93,  47],
#           [ 98,  91,  45]]]], dtype=uint8),
#  'target': ['Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   ...],
#  'labels': {'Bear',
#   'Cat',
#   'Chicken',
#   'Cow',
#   'Deer',
#   'Dog',
#   'Duck',
#   'Eagle',
#   'Elephant',
#   'Human',
#   'Lion',
#   'Monkey',
#   'Mouse',
#   'Natural',
#   'Panda',
#   'Pigeon',
#   'Rabbit',
#   'Sheep',
#   'Tiger',
#   'Wolf'}}

# %% [markdown]
# ## Saving the dataset into a pickle file

# %%
pickle.dump(data, open('data_20.pkl', 'wb'))

# %%
counter = Counter(data['target'])
x = list(counter.keys())
y = list(counter.values())
fig, ax = plt.subplots(figsize=(15,8))
ax.barh(x,y, color=sns.color_palette())
ax.tick_params(labelsize=13)
for i in range(len(x)):
    ax.text(y[i]+1, i-0.27, y[i], fontsize=15)
    
ax.set_title('Images by Label Name', fontsize=30, fontweight='semibold')
ax.set_xlabel('Count', fontsize=15)
ax.set_ylabel('Label', fontsize=15)
plt.show()

# %% [markdown]
# ### • The fost frequent label in the dataset is "Cat", followed by "Dog" and "Panda".
# ### • The least frequent label in the dataset is "Natural".

# %% [markdown]
# # Visualizing all classes

# %%
label_pos = [[i, data['target'].index(i)] for i in data['labels']]
index = 0
fig, ax = plt.subplots(4,5,figsize=(15,8))

for x in range(4):
    for y in range(5):
        ax[x,y].imshow(data['data'][label_pos[index][1]])
        ax[x,y].set_title(label_pos[index][0], fontsize=20)
        ax[x,y].set_axis_off()
        index += 1
fig.suptitle('Image Example of Each Target Class', fontsize=35, fontweight='semibold', y=1)
fig.tight_layout() 
plt.show()

# %% [markdown]
# # Building the first model

# %%
data = pickle.load(open('data_20.pkl', 'rb'))
data
# Out:
# {'description': 'There are 20 classes and 2,057 total images with shape of (80,80,3) each.',
#  'data': array([[[[196, 214, 188],
#           [196, 214, 188],
#           [196, 214, 188],
#           ...,
#           [ 81,  76,  80],
#           [ 81,  76,  80],
#           [ 69,  64,  68]],
#
#          [[196, 214, 188],
#           [196, 214, 188],
#           [196, 215, 187],
#           ...,
#           [ 82,  77,  81],
#           [ 83,  78,  82],
#           [ 77,  72,  76]],
#
#          [[193, 213, 185],
#           [194, 214, 186],
#           [194, 214, 186],
#           ...,
#           [ 82,  77,  81],
#           [ 81,  76,  80],
#           [ 78,  73,  77]],
#
#          ...,
#
#          [[254, 254, 254],
#           [254, 254, 254],
#           [254, 254, 254],
#           ...,
#           [ 70,  65,  69],
#           [ 65,  60,  64],
#           [ 62,  57,  63]],
#
#          [[254, 254, 254],
#           [254, 254, 254],
#           [254, 254, 254],
#           ...,
#           [ 66,  61,  65],
#           [ 62,  57,  61],
#           [ 64,  59,  65]],
#
#          [[254, 254, 254],
#           [254, 254, 254],
#           [254, 254, 254],
#           ...,
#           [ 56,  51,  55],
#           [ 79,  74,  78],
#           [ 70,  63,  70]]],
#
#
#         [[[  4,   2,   3],
#           [  7,   5,   6],
#           [  6,   5,   3],
#           ...,
#           [ 42,  31,  25],
#           [ 46,  35,  29],
#           [ 45,  32,  26]],
#
#          [[  7,   5,   6],
#           [  5,   4,   2],
#           [  2,   1,   0],
#           ...,
#           [ 22,  11,   5],
#           [ 43,  32,  26],
#           [ 47,  36,  30]],
#
#          [[  6,   5,   3],
#           [  3,   2,   0],
#           [  2,   1,   0],
#           ...,
#           [ 33,  24,  17],
#           [ 48,  39,  32],
#           [ 54,  45,  38]],
#
#          ...,
#
#          [[ 24,  29,   6],
#           [ 24,  30,   4],
#           [ 25,  31,   5],
#           ...,
#           [116, 116,  80],
#           [115, 117,  80],
#           [127, 129,  92]],
#
#          [[ 22,  27,   4],
#           [ 23,  28,   5],
#           [ 24,  29,   6],
#           ...,
#           [112, 112,  76],
#           [115, 117,  80],
#           [128, 130,  93]],
#
#          [[ 22,  27,   5],
#           [ 22,  27,   4],
#           [ 22,  27,   4],
#           ...,
#           [106, 106,  70],
#           [112, 114,  77],
#           [126, 128,  91]]],
#
#
#         [[[104, 109, 102],
#           [104, 111, 103],
#           [108, 115, 107],
#           ...,
#           [130, 126, 127],
#           [122, 117, 121],
#           [123, 118, 122]],
#
#          [[113, 118, 111],
#           [ 97, 104,  96],
#           [103, 110, 102],
#           ...,
#           [111, 107, 108],
#           [129, 124, 128],
#           [150, 145, 149]],
#
#          [[126, 133, 125],
#           [112, 119, 111],
#           [110, 117, 109],
#           ...,
#           [139, 135, 136],
#           [162, 157, 161],
#           [163, 158, 162]],
#
#          ...,
#
#          [[214, 214, 202],
#           [206, 206, 194],
#           [202, 200, 187],
#           ...,
#           [164, 162, 150],
#           [173, 173, 163],
#           [187, 187, 179]],
#
#          [[219, 219, 207],
#           [210, 210, 198],
#           [205, 203, 190],
#           ...,
#           [170, 168, 156],
#           [174, 174, 164],
#           [188, 188, 180]],
#
#          [[214, 214, 202],
#           [201, 201, 189],
#           [198, 196, 183],
#           ...,
#           [172, 170, 158],
#           [179, 179, 169],
#           [184, 184, 176]]],
#
#
#         ...,
#
#
#         [[[147, 154, 113],
#           [145, 152, 111],
#           [146, 153, 112],
#           ...,
#           [102, 109,  58],
#           [118, 121,  74],
#           [128, 131,  86]],
#
#          [[148, 155, 114],
#           [146, 153, 112],
#           [145, 152, 111],
#           ...,
#           [120, 128,  71],
#           [138, 142,  91],
#           [151, 155, 105]],
#
#          [[147, 154, 112],
#           [146, 153, 111],
#           [144, 151, 109],
#           ...,
#           [136, 142,  80],
#           [143, 151,  91],
#           [150, 158,  99]],
#
#          ...,
#
#          [[137, 142,  88],
#           [146, 150,  99],
#           [145, 148, 101],
#           ...,
#           [143, 138, 100],
#           [148, 143, 103],
#           [158, 150, 111]],
#
#          [[133, 138,  82],
#           [128, 133,  79],
#           [129, 133,  83],
#           ...,
#           [158, 153, 115],
#           [157, 152, 112],
#           [154, 149, 109]],
#
#          [[130, 135,  79],
#           [128, 133,  79],
#           [135, 139,  88],
#           ...,
#           [160, 155, 115],
#           [157, 152, 112],
#           [150, 145, 105]]],
#
#
#         [[[246, 250, 249],
#           [247, 251, 250],
#           [252, 254, 253],
#           ...,
#           [136, 118, 114],
#           [143, 124, 118],
#           [145, 126, 120]],
#
#          [[244, 248, 247],
#           [252, 255, 255],
#           [243, 245, 244],
#           ...,
#           [139, 124, 117],
#           [135, 120, 113],
#           [156, 141, 134]],
#
#          [[238, 242, 241],
#           [248, 252, 251],
#           [246, 248, 247],
#           ...,
#           [128, 118, 109],
#           [128, 118, 109],
#           [141, 131, 122]],
#
#          ...,
#
#          [[236, 233, 224],
#           [230, 226, 217],
#           [228, 224, 215],
#           ...,
#           [159, 142, 126],
#           [152, 135, 119],
#           [150, 133, 117]],
#
#          [[234, 231, 222],
#           [233, 230, 221],
#           [229, 225, 216],
#           ...,
#           [185, 169, 154],
#           [165, 149, 134],
#           [169, 153, 138]],
#
#          [[242, 239, 232],
#           [236, 233, 224],
#           [229, 225, 216],
#           ...,
#           [193, 177, 162],
#           [185, 169, 154],
#           [175, 159, 144]]],
#
#
#         [[[ 85,  78,  32],
#           [ 79,  72,  26],
#           [ 79,  72,  26],
#           ...,
#           [ 80,  73,  27],
#           [ 76,  69,  23],
#           [ 74,  67,  21]],
#
#          [[ 82,  78,  31],
#           [ 79,  72,  26],
#           [ 78,  71,  25],
#           ...,
#           [ 78,  71,  25],
#           [ 75,  68,  24],
#           [ 71,  64,  20]],
#
#          [[ 81,  77,  30],
#           [ 80,  73,  27],
#           [ 77,  70,  24],
#           ...,
#           [ 78,  71,  27],
#           [ 76,  69,  25],
#           [ 71,  64,  20]],
#
#          ...,
#
#          [[ 85,  55,  17],
#           [ 92,  60,  22],
#           [ 90,  58,  20],
#           ...,
#           [103, 101,  53],
#           [ 99,  97,  49],
#           [ 96,  94,  46]],
#
#          [[ 87,  57,  19],
#           [ 82,  50,  11],
#           [ 88,  56,  17],
#           ...,
#           [104, 100,  53],
#           [101,  97,  50],
#           [ 98,  94,  47]],
#
#          [[ 82,  53,  13],
#           [ 83,  51,  12],
#           [ 92,  60,  21],
#           ...,
#           [101,  94,  48],
#           [100,  93,  47],
#           [ 98,  91,  45]]]], dtype=uint8),
#  'target': ['Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Bear',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Cat',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Chicken',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Cow',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Deer',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Dog',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Duck',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Eagle',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   'Elephant',
#   ...],
#  'labels': {'Bear',
#   'Cat',
#   'Chicken',
#   'Cow',
#   'Deer',
#   'Dog',
#   'Duck',
#   'Eagle',
#   'Elephant',
#   'Human',
#   'Lion',
#   'Monkey',
#   'Mouse',
#   'Natural',
#   'Panda',
#   'Pigeon',
#   'Rabbit',
#   'Sheep',
#   'Tiger',
#   'Wolf'}}

# %% [markdown]
# # Splitting the Data into Train/Test

# %%
X = data['data']
y = np.array(data['target'])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=1)
print(f"X_train.shape: {X_train.shape}")
print(f"y_train.shape: {y_train.shape}")
print(f"X_test.shape: {X_test.shape}")
print(f"y_test.shape: {y_test.shape}")
# Out:
# X_train.shape: (1645, 80, 80, 3)
# y_train.shape: (1645,)
# X_test.shape: (412, 80, 80, 3)
# y_test.shape: (412,)

# %% [markdown]
# # Creating a class to transform the images into grayscale

# %%
class rgb2gray_transform(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
    def fit(self, X, y=None):
        return self
    def transform(self, X, y=None):
        return np.array([rgb2gray(x) for x in X])

# %%
rgb_2gray = rgb2gray_transform()
X_train_gray = rgb_2gray.fit_transform(X_train)
X_test_gray = rgb_2gray.fit_transform(X_test)

# %%
fig, ax = plt.subplots(2,5,figsize=(15,7))
for y in range(5):
    ax[0,y].imshow(X_train[y])
    ax[1,y].imshow(X_train_gray[y], cmap='gray')
    ax[0,y].set_axis_off()
    ax[1,y].set_axis_off()
fig.suptitle('Sample Images Before and After Grayscale Transformation', fontsize=30, fontweight='semibold')
fig.tight_layout()
plt.show()

# %% [markdown]
# # Creating a class to Hog-Transform the grayscale images

# %%
class hogtransformer(BaseEstimator, TransformerMixin):
    def __init__(self, orientations=9, pixels_per_cell=(10,10), cells_per_block=(3,3), visualize=False):
        self.orientations = orientations
        self.pixels_per_cell = pixels_per_cell
        self.cells_per_block = cells_per_block
        self.visualize = visualize
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        def local_hog(img):
            hog_features = hog(img, orientations=self.orientations, 
                                               pixels_per_cell=self.pixels_per_cell, cells_per_block=self.cells_per_block, visualize=self.visualize)
            return hog_features
        
        features = []
        hog_images = []
        for x in X:
            results = local_hog(x)
            if self.visualize:
                features.append(results[0])
                hog_images.append(results[1])
            else:
                features.append(results)
                
        if self.visualize:
            return features, hog_images
        else:
            return features

# %%
_, sample_hogs = hogtransformer(visualize=True).fit_transform(X_train_gray[:5])

fig, ax = plt.subplots(3,5,figsize=(15,8))
for y in range(5):
    ax[0,y].imshow(X_train[y])
    ax[1,y].imshow(X_train_gray[y], cmap='gray')
    ax[2,y].imshow(sample_hogs[y], cmap='gray')
    ax[0,y].set_axis_off()
    ax[1,y].set_axis_off()
    ax[2,y].set_axis_off()
fig.suptitle('Sample Images Before and After Hog Transformation', fontsize=30, fontweight='semibold')
fig.tight_layout()
plt.show()

# %% [markdown]
# # Training Machine Learning Model

# %%
sgd = SGDClassifier(loss='hinge', learning_rate='adaptive', early_stopping=True, eta0=0.1)

# %% [markdown]
# # Defining the Pipeline

# %%
rgb_2gray = rgb2gray_transform()
hog_transform = hogtransformer()
scaler = StandardScaler()
# Step 1: Convert into grayscale
X_train_gray = rgb_2gray.fit_transform(X_train)
X_test_gray = rgb_2gray.fit_transform(X_test)
# Step 2: Extract the HOG features
X_train_hog = hog_transform.fit_transform(X_train_gray)
X_test_hog = hog_transform.fit_transform(X_test_gray)
# Step 3: Standardize the data
X_train_scaled = scaler.fit_transform(X_train_hog)
X_test_scaled = scaler.transform(X_test_hog)

# %%
sgd.fit(X_train_scaled, y_train)
# Out:
# SGDClassifier(early_stopping=True, eta0=0.1, learning_rate='adaptive')

# %%
sgd_pred = sgd.predict(X_test_scaled)

# %% [markdown]
# # Model Evaluation

# %%
pd.DataFrame(classification_report(y_test, sgd_pred, output_dict=True)).T
# Out:
#               precision    recall  f1-score     support
# Bear           0.545455  0.600000  0.571429   20.000000
# Cat            0.595238  0.781250  0.675676   32.000000
# Chicken        0.571429  0.600000  0.585366   20.000000
# Cow            0.523810  0.523810  0.523810   21.000000
# Deer           0.684211  0.619048  0.650000   21.000000
# Dog            0.764706  0.500000  0.604651   26.000000
# Duck           0.736842  0.666667  0.700000   21.000000
# Eagle          0.571429  0.600000  0.585366   20.000000
# Elephant       0.520000  0.650000  0.577778   20.000000
# Human          0.730769  0.950000  0.826087   20.000000
# Lion           0.600000  0.600000  0.600000   20.000000
# Monkey         0.625000  0.500000  0.555556   20.000000
# Mouse          0.266667  0.200000  0.228571   20.000000
# Natural        0.000000  0.000000  0.000000    1.000000
# Panda          0.678571  0.791667  0.730769   24.000000
# Pigeon         0.695652  0.695652  0.695652   23.000000
# Rabbit         0.578947  0.550000  0.564103   20.000000
# Sheep          0.428571  0.300000  0.352941   20.000000
# Tiger          0.708333  0.739130  0.723404   23.000000
# Wolf           0.588235  0.500000  0.540541   20.000000
# accuracy       0.604369  0.604369  0.604369    0.604369
# macro avg      0.570693  0.568361  0.564585  412.000000
# weighted avg   0.604076  0.604369  0.598602  412.000000

# %%
accuracy_score(y_test, sgd_pred)
# Out:
# 0.6043689320388349

# %%
cohen_kappa_score(y_test, sgd_pred)
# Out:
# 0.5819550182703261

# %% [markdown]
# # Creating a data pipeline for the final classification

# %%
model_pipeline = Pipeline([
    ('Grayscale Transform', rgb2gray_transform()),
    ('HOG Transform', hogtransformer()),
    ('Standardization', StandardScaler()),
    ('SGD Classifier', SGDClassifier(loss='hinge', learning_rate='adaptive', early_stopping=True, eta0=0.1))
])

# %%
model_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('Grayscale Transform', rgb2gray_transform()),
#                 ('HOG Transform', hogtransformer()),
#                 ('Standardization', StandardScaler()),
#                 ('SGD Classifier',
#                  SGDClassifier(early_stopping=True, eta0=0.1,
#                                learning_rate='adaptive'))])

# %%
y_pred = model_pipeline.predict(X_test)

# %%
pd.DataFrame(classification_report(y_test, y_pred, output_dict=True)).T
# Out:
#               precision    recall  f1-score     support
# Bear           0.571429  0.600000  0.585366   20.000000
# Cat            0.657895  0.781250  0.714286   32.000000
# Chicken        0.608696  0.700000  0.651163   20.000000
# Cow            0.785714  0.523810  0.628571   21.000000
# Deer           0.772727  0.809524  0.790698   21.000000
# Dog            0.782609  0.692308  0.734694   26.000000
# Duck           0.750000  0.714286  0.731707   21.000000
# Eagle          0.647059  0.550000  0.594595   20.000000
# Elephant       0.652174  0.750000  0.697674   20.000000
# Human          0.730769  0.950000  0.826087   20.000000
# Lion           0.692308  0.450000  0.545455   20.000000
# Monkey         0.440000  0.550000  0.488889   20.000000
# Mouse          0.333333  0.250000  0.285714   20.000000
# Natural        0.000000  0.000000  0.000000    1.000000
# Panda          0.708333  0.708333  0.708333   24.000000
# Pigeon         0.600000  0.652174  0.625000   23.000000
# Rabbit         0.550000  0.550000  0.550000   20.000000
# Sheep          0.600000  0.450000  0.514286   20.000000
# Tiger          0.666667  0.869565  0.754717   23.000000
# Wolf           0.611111  0.550000  0.578947   20.000000
# accuracy       0.643204  0.643204  0.643204    0.643204
# macro avg      0.608041  0.605062  0.600309  412.000000
# weighted avg   0.642594  0.643204  0.636473  412.000000

# %% [markdown]
# # Hyperparameter Tuning with GridSearchCV

# %%
param_grid = {
    'HOG Transform__orientations': [7,8,9],
    'HOG Transform__pixels_per_cell': [(7,7), (8,8), (9,9)],
    'HOG Transform__cells_per_block': [(2,2), (3,3)],
    'SGD Classifier__loss': ['hinge', 'perceptron'],
    'SGD Classifier__learning_rate': ['optimal', 'adaptive'],
    'SGD Classifier__eta0': [0.001, 0.01],
    'SGD Classifier__alpha': [0.0001, 0.001]
    

}

model_grid = GridSearchCV(estimator=model_pipeline, param_grid=param_grid, scoring='accuracy', cv=3, verbose=2)

# %%
model_grid.fit(X_train, y_train)

# %%
print(model_grid.best_score_)
# Out:
# 0.7142914123888158

# %%
model_best = model_grid.best_estimator_
model_best
# Out:
# Pipeline(steps=[('Grayscale Transform', rgb2gray_transform()),
#                 ('HOG Transform',
#                  hogtransformer(cells_per_block=(2, 2), orientations=8)),
#                 ('Standardization', StandardScaler()),
#                 ('SGD Classifier',
#                  SGDClassifier(alpha=0.001, early_stopping=True, eta0=0.01,
#                                loss='perceptron'))])

# %%
y_pred = model_best.predict(X_test)

# %%
pd.DataFrame(classification_report(y_test, y_pred, output_dict=True)).T
# Out:
#               precision    recall  f1-score     support
# Bear           0.882353  0.750000  0.810811   20.000000
# Cat            0.848485  0.875000  0.861538   32.000000
# Chicken        0.869565  1.000000  0.930233   20.000000
# Cow            0.826087  0.904762  0.863636   21.000000
# Deer           0.833333  0.952381  0.888889   21.000000
# Dog            0.529412  0.692308  0.600000   26.000000
# Duck           0.842105  0.761905  0.800000   21.000000
# Eagle          0.750000  0.600000  0.666667   20.000000
# Elephant       0.888889  0.800000  0.842105   20.000000
# Human          0.947368  0.900000  0.923077   20.000000
# Lion           0.700000  0.700000  0.700000   20.000000
# Monkey         0.625000  0.500000  0.555556   20.000000
# Mouse          0.600000  0.600000  0.600000   20.000000
# Natural        0.000000  0.000000  0.000000    1.000000
# Panda          0.916667  0.916667  0.916667   24.000000
# Pigeon         0.769231  0.869565  0.816327   23.000000
# Rabbit         0.571429  0.400000  0.470588   20.000000
# Sheep          0.681818  0.750000  0.714286   20.000000
# Tiger          0.800000  0.869565  0.833333   23.000000
# Wolf           0.789474  0.750000  0.769231   20.000000
# accuracy       0.771845  0.771845  0.771845    0.771845
# macro avg      0.733561  0.729608  0.728147  412.000000
# weighted avg   0.771016  0.771845  0.767877  412.000000

# %% [markdown]
# ### • After hyperparameter tuning, the model accuracy has significantly increased relative to our previous model.

# %% [markdown]
# # Saving the pipeline

# %%
pickle.dump(model_best, open('model_best.pkl', 'wb'))

# %%
pickle.load(open('model_best.pkl', 'rb'))
# Out:
# Pipeline(steps=[('Grayscale Transform', rgb2gray_transform()),
#                 ('HOG Transform',
#                  hogtransformer(cells_per_block=(2, 2), orientations=8,
#                                 pixels_per_cell=(8, 8))),
#                 ('Standardization', StandardScaler()),
#                 ('SGD Classifier',
#                  SGDClassifier(alpha=0.001, early_stopping=True, eta0=0.01,
#                                loss='perceptron'))])

# %%
pipeline1 = make_pipeline(
    rgb2gray_transform(),
    hogtransformer(orientations=8, pixels_per_cell=(8,8), cells_per_block=(2,2))
)

# %%
feature_vector = pipeline1.fit_transform(X_train)

# %%
# Standard Scaler
scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(feature_vector)

# %%
model = SGDClassifier(learning_rate='optimal', loss='perceptron', alpha=0.001, early_stopping=True)

# %%
model.fit(scaled_X_train, y_train)
# Out:
# SGDClassifier(alpha=0.001, early_stopping=True, loss='perceptron')

# %%
# Evaluate model
feature_vector = pipeline1.fit_transform(X_test)
scaled_X_test = scaler.transform(feature_vector)
y_pred_test = model.predict(scaled_X_test)

# %%
pd.DataFrame(classification_report(y_test, y_pred_test, output_dict=True)).T
# Out:
#               precision    recall  f1-score     support
# Bear           0.761905  0.800000  0.780488   20.000000
# Cat            0.725000  0.906250  0.805556   32.000000
# Chicken        0.760000  0.950000  0.844444   20.000000
# Cow            0.750000  0.714286  0.731707   21.000000
# Deer           0.913043  1.000000  0.954545   21.000000
# Dog            0.640000  0.615385  0.627451   26.000000
# Duck           0.750000  0.571429  0.648649   21.000000
# Eagle          0.684211  0.650000  0.666667   20.000000
# Elephant       0.888889  0.800000  0.842105   20.000000
# Human          1.000000  0.900000  0.947368   20.000000
# Lion           0.523810  0.550000  0.536585   20.000000
# Monkey         0.736842  0.700000  0.717949   20.000000
# Mouse          0.647059  0.550000  0.594595   20.000000
# Natural        0.000000  0.000000  0.000000    1.000000
# Panda          0.913043  0.875000  0.893617   24.000000
# Pigeon         0.760000  0.826087  0.791667   23.000000
# Rabbit         0.588235  0.500000  0.540541   20.000000
# Sheep          0.583333  0.700000  0.636364   20.000000
# Tiger          0.739130  0.739130  0.739130   23.000000
# Wolf           0.833333  0.750000  0.789474   20.000000
# accuracy       0.745146  0.745146  0.745146    0.745146
# macro avg      0.709892  0.704878  0.704445  412.000000
# weighted avg   0.745290  0.745146  0.742017  412.000000

# %% [markdown]
# # Saving the scaler and SGD model for Flask application

# %%
pickle.dump(model, open('model_final.pkl', 'wb'))

# %%
pickle.dump(scaler, open('scaler.pkl', 'wb'))

# %%
model_best

# %% [markdown]
# # Testing the model with a new image

# %%
image = imread('images/eagle.jpg')
image_scaled = resize(image, (80,80), preserve_range=True).astype(np.uint8)
image_gray = rgb2gray(image_scaled)
feature_vector, image_hog = hog(image_gray, orientations=8, pixels_per_cell=(8,8), cells_per_block=(2,2), visualize=True)

# %%
images = [image, image_scaled, image_gray, image_hog]
titles = ['Original Image', 'Scaled Image', 'Grayscale Image', 'Hog-Transformed Image']
cmaps = [None, None, 'gray', 'gray']
index = 0

fig, ax = plt.subplots(2,2,figsize=(10,8))
for x in range(2):
    for y in range(2):
        ax[x,y].imshow(images[index], cmap=cmaps[index])
        ax[x,y].set_title(titles[index], fontsize=25)
        index += 1
fig.suptitle('New Image Transformation', fontsize=30, fontweight='semibold')
fig.tight_layout()
plt.show()

# %% [markdown]
# # Load the model

# %%
model = pickle.load(open('model_final.pkl', 'rb'))
scaler = pickle.load(open('scaler.pkl', 'rb'))

# %%
model.get_params()
# Out:
# {'alpha': 0.001,
#  'average': False,
#  'class_weight': None,
#  'early_stopping': True,
#  'epsilon': 0.1,
#  'eta0': 0.0,
#  'fit_intercept': True,
#  'l1_ratio': 0.15,
#  'learning_rate': 'optimal',
#  'loss': 'perceptron',
#  'max_iter': 1000,
#  'n_iter_no_change': 5,
#  'n_jobs': None,
#  'penalty': 'l2',
#  'power_t': 0.5,
#  'random_state': None,
#  'shuffle': True,
#  'tol': 0.001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
scalex = scaler.transform(feature_vector.reshape(1,-1))
results = model.predict(scalex)

# %%
decision_values = model.decision_function(scalex).flatten()
classes = model.classes_
index = list(classes).index('Eagle')

fig, ax = plt.subplots(figsize=(10,6))
ax.barh(classes, decision_values)
ax.barh(classes[index], decision_values[index])
ax.grid()
ax.text(decision_values[index]+20, index-0.3, np.round(decision_values[index], 2), fontsize=14, fontweight='semibold')
ax.set_xlim(ax.get_xlim()[0], ax.get_xlim()[1] + 100)
ax.tick_params(labelsize=13)
ax.set_title('Decision Values for Each Class', fontsize=25, fontweight='semibold')
plt.show()

# %%
z = stats.zscore(decision_values)
z
# Out:
# array([-0.47644677, -0.14818746,  0.86773795, -0.17369479, -0.6311391 ,
#        -0.13483903,  0.88531153,  2.27910937, -0.89553789,  0.04454711,
#        -1.35169079,  0.86629171, -1.13993717, -0.23353022,  1.3624641 ,
#         1.15782313,  0.23149675, -0.24260272, -0.14403785, -2.12313783])

# %%
prob_values = softmax(z)
prob_values
# Out:
# array([0.01846817, 0.02564396, 0.07082652, 0.02499812, 0.01582129,
#        0.02598856, 0.0720822 , 0.2905004 , 0.01214549, 0.03109486,
#        0.0076968 , 0.07072416, 0.00951204, 0.02354622, 0.11615897,
#        0.09466257, 0.03748693, 0.02333356, 0.02575059, 0.00355857])

# %%
index = list(classes).index('Eagle')

fig, ax = plt.subplots(figsize=(10,6))
ax.barh(classes, prob_values)
ax.barh(classes[index], prob_values[index])
ax.grid()
ax.text(prob_values[index]+0.002, index-0.2, np.round(prob_values[index], 2), fontsize=14, fontweight='semibold')
ax.set_xlim(ax.get_xlim()[0], ax.get_xlim()[1] + .01)
ax.tick_params(labelsize=13)
ax.set_title('Probability Values for Each Class', fontsize=25, fontweight='semibold')
plt.show()

# %%
top_5_ind = prob_values.argsort()[::-1][:5]
top_5_probs = prob_values[top_5_ind]
top_5_classes = classes[top_5_ind]

# %%
top_dict = {key: np.round(value, 2) for key, value in zip(top_5_classes, top_5_probs)}
top_dict
# Out:
# {'Eagle': 0.29, 'Panda': 0.12, 'Pigeon': 0.09, 'Duck': 0.07, 'Chicken': 0.07}

# %% [markdown]
# # Final model pipeline

# %%
def pipeline_model(path, scaler, model):
    # Reading Image
    image = imread(path)
    # Resizing Image
    image_transformed = resize(image, (80,80), preserve_range=True).astype(np.uint8)
    # Grayscale Image
    if len(image.shape) == 3:
        if image.shape[-1] == 3:
            image_gray = rgb2gray(image_transformed)
        elif image.shape[-1] == 4:
            image_gray = rgb2gray(rgba2rgb(image_transformed))
    elif len(image.shape) == 2:
        image_gray = image_transformed
        
    # Hog Features
    feature_vector = hog(image_gray, orientations=8, pixels_per_cell=(8,8), cells_per_block=(2,2))
    # Scaling Image
    scalex = scaler.transform(feature_vector.reshape(1, -1))
    # Predicting Class
    result = model.predict(scalex)
    # Decision Function
    decision_values = model.decision_function(scalex).flatten()
    classes = model.classes_
    # Z-Scores
    z_scores = stats.zscore(decision_values)
    # Probabilities
    prob_values = softmax(z_scores)
    # Top 5 Results
    top_5_ind = prob_values.argsort()[::-1][:5]
    top_5_classes = classes[top_5_ind]
    top_5_probs = prob_values[top_5_ind]
    top_dict = {key: np.round(value, 2) for key, value in zip(top_5_classes, top_5_probs)}
    
    return top_dict
